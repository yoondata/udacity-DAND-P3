# %%
import shape as SP

data = SP.make_dict("oxford_england.osm")

# %%
len(data)
# Out:
# 324550

# %%
data[257500:257550]
# Out:
# [{'category': 'node',
#   'created': {'changeset': '32638525',
#    'timestamp': '2015-07-14T21:05:26Z',
#    'uid': '34555',
#    'user': 'Max--',
#    'version': '1'},
#   'id': '3651326663',
#   'pos': [51.8130451, -1.265004]},
#  {'category': 'node',
#   'created': {'changeset': '32638525',
#    'timestamp': '2015-07-14T21:05:26Z',
#    'uid': '34555',
#    'user': 'Max--',
#    'version': '1'},
#   'id': '3651326664',
#   'pos': [51.8130984, -1.2671815]},
#  {'category': 'node',
#   'created': {'changeset': '32638525',
#    'timestamp': '2015-07-14T21:05:26Z',
#    'uid': '34555',
#    'user': 'Max--',
#    'version': '1'},
#   'id': '3651326665',
#   'pos': [51.8131462, -1.2588886]},
#  {'category': 'node',
#   'created': {'changeset': '32638525',
#    'timestamp': '2015-07-14T21:05:26Z',
#    'uid': '34555',
#    'user': 'Max--',
#    'version': '1'},
#   'id': '3651326666',
#   'pos': [51.8131859, -1.2661615]},
#  {'category': 'node',
#   'created': {'changeset': '32638525',
# ...

# %%
# Transform and save into JSON
SP.process_map("oxford_england.osm")
