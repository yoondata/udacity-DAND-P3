# %% [markdown]
# ### Adapted from *oxford_sample_audit.ipynb* for more effective auditing of "k" and "v" values

# %%
import os
os.chdir("..")

# %%
from audit import audit_k_v

SAMPLE = "oxford_sample.osm"

all_k_v_dict = audit_k_v(SAMPLE, ["node", "way", "relation"])

# %%
# Examining all "k" values
all_k_list = all_k_v_dict.keys()
all_k_list.sort()
all_k_list
# Out:
# ['BUFF_DIST',
#  'CAB:User_restictions',
#  'FIXME',
#  'FIXME:nsl',
#  'Fixme',
#  'IBGE:GEOCODIGO',
#  'Id',
#  'NPLG:USRN:1',
#  'ORIG_FID',
#  'Site:use',
#  'Support_service',
#  'TMC:cid_58:tabcd_1:Class',
#  'TMC:cid_58:tabcd_1:LCLversion',
#  'TMC:cid_58:tabcd_1:LocationCode',
#  'abutters',
#  'access',
#  'access:disabled',
#  'access:hgv',
#  'accessfrom',
#  'addr:city',
#  'addr:city:simc',
#  'addr:country',
#  'addr:county',
#  'addr:door',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:inclusion',
#  'addr:interpolation',
#  'addr:place',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'addr:substreet',
#  'addr:substreet1',
#  'addr:substreet:1',
#  'addr:substreet:2',
#  'addr:town',
#  'addr:unit',
#  'adjacent',
#  'admin_level',
#  'aeroway',
#  'alt_name',
#  'amenity',
#  'amenity:disused',
#  'answer',
#  'area',
#  'area:highway',
#  'artwork_type',
#  'ascent',
#  'atm',
#  'attribution',
#  'authoritative',
#  'backrest',
#  'barrier',
#  'basin',
#  'bicycle',
#  'bicycle:no:times',
#  'bicycle:note',
#  'bicycle_parking',
#  'board_type',
#  'boat',
#  'boundary',
#  'brand',
#  'bridge',
#  'bridge_name',
#  'bridge_over',
#  'bridge_ref',
#  'building',
#  'building:levels',
#  'building:levels:underground',
#  'building:material',
#  'building:part',
#  'building:roof',
#  'building:ruian:type',
#  'building:type',
#  'building:use',
#  'bus',
#  'bus:lanes:forward',
#  'bus_routes',
#  'busway:left',
#  'cables',
#  'capacity',
#  'capacity:disabled',
#  'capacity:private',
#  'circuits',
#  'clothes',
#  'collection_times',
#  'color',
#  'colour',
#  'colour:arrow',
#  'colour:back',
#  'colour:text',
#  'comment',
#  'construction',
#  'contact:phone',
#  'contact:website',
#  'continental_geometry',
#  'converted_by',
#  'covered',
#  'created_by',
#  'crossing',
#  'crossing_ref',
#  'cuisine',
#  'currency',
#  'cutting',
#  'cyclability',
#  'cycleway',
#  'cycleway:hazard',
#  'cycleway:left',
#  'cycleway:left:priority',
#  'cycleway:left:width',
#  'cycleway:note',
#  'cycleway:otherside:width',
#  'cycleway:right',
#  'cycleway:right:priority',
#  'cycleway:right:width',
#  'damage:colision',
#  'denomination',
#  'denotation',
#  'description',
#  'designation',
#  'destination',
#  'direction',
#  'disabled',
#  'disconnected',
#  'dismantled',
#  'display',
#  'distance',
#  'distribute_to',
#  'disused',
#  'disused:amenity',
#  'disused:highway',
#  'disused:shop',
#  'dog',
#  'door',
#  'drive_through',
#  'ele',
#  'electrified',
#  'email',
#  'embankment',
#  'emergency',
#  'entrance',
#  'est_width',
#  'except',
#  'fax',
#  'fed_from',
#  'fee',
#  'female',
#  'fence_type',
#  'fixme',
#  'floor',
#  'food',
#  'foot',
#  'footway',
#  'footway:left',
#  'frequency',
#  'frequency:4A',
#  'from',
#  'fuel:diesel',
#  'fuel:octane_95',
#  'fuel:octane_98',
#  'garden',
#  'garden:type',
#  'gate',
#  'gauge',
#  'genus',
#  'gluten_free',
#  'gnis:county_id',
#  'gnis:created',
#  'gnis:edited',
#  'gnis:feature_id',
#  'gnis:state_id',
#  'goods',
#  'headsign_0',
#  'headsign_1',
#  'height',
#  'hgv',
#  'highway',
#  'highways_agency:area',
#  'historic',
#  'history',
#  'horse',
#  'identification',
#  'incline',
#  'indoor',
#  'indoor_1',
#  'infomation:1',
#  'infomation:2',
#  'information',
#  'inscription',
#  'int_ref',
#  'intermittent',
#  'internet_access',
#  'is_in',
#  'is_in:state',
#  'isced:level',
#  'journeys',
#  'junction',
#  'kerb',
#  'lamp',
#  'lamp_mount',
#  'lamp_operator',
#  'lamp_type',
#  'landuse',
#  'landuse:former',
#  'lanes',
#  'lanes:bus:backward',
#  'lanes:bus:forward',
#  'lanes:forward',
#  'lanes:psv:backward',
#  'layer',
#  'lcn',
#  'lcn2',
#  'lcn2:left',
#  'lcn2:right',
#  'lcn:left',
#  'lcn:right',
#  'leaf_cycle',
#  'leaf_type',
#  'learning',
#  'leisure',
#  'level',
#  'level:name',
#  'levels',
#  'lift',
#  'links_higher',
#  'links_lower',
#  'lit',
#  'loading_gauge',
#  'loc_name',
#  'loc_ref',
#  'local:Bearing',
#  'local_ref',
#  'location',
#  'lock',
#  'lock_name',
#  'lock_ref',
#  'loop:left',
#  'loop:right',
#  'male',
#  'man_made',
#  'manhole',
#  'material',
#  'maxlength',
#  'maxspeed',
#  'maxspeed:note',
#  'maxspeed:source',
#  'maxspeed:spec',
#  'maxspeed:type',
#  'maxstay',
#  'maxweight',
#  'maxweight:hgv:conditional',
#  'mcn',
#  'memorial',
#  'modifier',
#  'mooring',
#  'mormon',
#  'motor_vehicle',
#  'motor_vehicle:backward',
#  'motor_vehicle:disabled',
#  'motor_vehicle:loading',
#  'motor_vehicle:loading:yes:times',
#  'motor_vehicle:no:times',
#  'motorboat',
#  'motorcar',
#  'motorcycle',
#  'name',
#  'name:be',
#  'name:cy',
#  'name:de',
#  'name:en',
#  'name:fr',
#  'name:fy',
#  'name:it',
#  'name:nl',
#  'name:note',
#  'name:ru',
#  'name:th',
#  'name_1',
#  'naptan:AtcoCode',
#  'naptan:Bearing',
#  'naptan:BusStopType',
#  'naptan:CommonName',
#  'naptan:Crossing',
#  'naptan:Indicator',
#  'naptan:Landmark',
#  'naptan:NaptanCode',
#  'naptan:Notes',
#  'naptan:PlusbusZoneRef',
#  'naptan:ShortCommonName',
#  'naptan:StopAreaCode',
#  'naptan:StopAreaType',
#  'naptan:Street',
#  'naptan:verified',
#  'natural',
#  'ncn:left',
#  'ncn:quiet',
#  'ncn_ref',
#  'network',
#  'not:name',
#  'not:name:note',
#  'note',
#  'note2',
#  'note:2',
#  'note:3',
#  'note:4',
#  'note:5',
#  'note:alt_name',
#  'note:frequency',
#  'note:name',
#  'note:reply',
#  'number',
#  'odbl',
#  'office',
#  'old_name',
#  'old_railway_operator',
#  'oneway',
#  'oneway:bicycle',
#  'oneway:note',
#  'oneway:reverse',
#  'opening_hours',
#  'opening_hours:morning',
#  'openplaques:id',
#  'operator',
#  'operator:be',
#  'operator:catagory',
#  'operator:fr',
#  'operator:lux',
#  'operator:nl',
#  'operator:type',
#  'operator:uk',
#  'organic',
#  'organisaition',
#  'organisation:affiliation:National',
#  'organisation:affiliation:region',
#  'orienteering',
#  'osmc:symbol',
#  'outdoor_seating',
#  'overtaking',
#  'owner',
#  'ownership',
#  'park_and_ride',
#  'park_ride',
#  'parking',
#  'parking:condition:both',
#  'parking:condition:both:garage_users',
#  'parking:lane:left',
#  'parking:lane:right',
#  'parking:left',
#  'parking:note',
#  'passenger_lines',
#  'payment:bitcoin',
#  'payment:card',
#  'payment:cards',
#  'payment:coins',
#  'phone',
#  'place',
#  'platforms',
#  'playground',
#  'polling_station',
#  'post_box:design',
#  'post_box:mounting',
#  'post_box:type',
#  'postal_code',
#  'power',
#  'proposed',
#  'proposed:electrified',
#  'proposed:frequency',
#  'proposed:voltage',
#  'protect_class',
#  'protection_title',
#  'prow:ref',
#  'prow_ref',
#  'psv',
#  'public_transport',
#  'public_transport:version',
#  'raba:id',
#  'railway',
#  'railway:traffic_mode',
#  'rcn:left',
#  'rcn:right',
#  'real_ale',
#  'recycling:batteries',
#  'recycling:cans',
#  'recycling:clothes',
#  'recycling:glass',
#  'recycling:paper',
#  'recycling:shoes',
#  'recycling_type',
#  'ref',
#  'ref:NPLG:UPRN:1',
#  'ref:UAI',
#  'ref:bag',
#  'ref:ruian:building',
#  'ref:sandre',
#  'ref:woonplaatscode',
#  'ref_group',
#  'religion',
#  'residential',
#  'restriction',
#  'roof:levels',
#  'roof:material',
#  'roof:shape',
#  'room',
#  'roundtrip',
#  'route',
#  'route_master',
#  'route_ref',
#  'route_sections',
#  'royal_cypher',
#  'sac_scale',
#  'school:FR',
#  'school:entry',
#  'school:female',
#  'seasonal',
#  'second_hand',
#  'segment',
#  'segregated',
#  'service',
#  'service_times',
#  'shelter',
#  'shop',
#  'short_name',
#  'short_route_ref',
#  'sidewalk',
#  'sign',
#  'signposted',
#  'site',
#  'smoking',
#  'smoothness',
#  'social_facility',
#  'source',
#  'source:access',
#  'source:addr',
#  'source:addr:housenumber',
#  'source:addr:postcode',
#  'source:alt_name',
#  'source:bicycle',
#  'source:building',
#  'source:capacity',
#  'source:covered',
#  'source:date',
#  'source:designation',
#  'source:geometry',
#  'source:highway',
#  'source:maxspeed',
#  'source:name',
#  'source:oneway',
#  'source:operator',
#  'source:position',
#  'source:postcode',
#  'source:ref',
#  'source_1',
#  'source_ref',
#  'species',
#  'sport',
#  'stars',
#  'start_date',
#  'step_count',
#  'steps',
#  'substation',
#  'supervised',
#  'support',
#  'surface',
#  'survey:date',
#  'suspened',
#  'symbol',
#  'takeaway',
#  'telephone',
#  'text',
#  'text_color',
#  'through_route',
#  'ticket',
#  'tiger:cfcc',
#  'tiger:county',
#  'tiger:name_base',
#  'tiger:name_base_1',
#  'tiger:name_type',
#  'tiger:reviewed',
#  'tiger:separated',
#  'tiger:source',
#  'tiger:tlid',
#  'tiger:zip_left',
#  'tiger:zip_right',
#  'to',
#  'toilets:disposal',
#  'toilets:wheelchair',
#  'toll:hgv',
#  'tourism',
#  'tourist_bus',
#  'tourist_bus:conditional',
#  'tower:type',
#  'towpath',
#  'track_detail',
#  'tracks',
#  'tracktype',
#  'traffic_calming',
#  'traffic_sign',
#  'traffic_sign:2',
#  'trail_visibility',
#  'tunnel',
#  'type',
#  'uk_postcode_centroid',
#  'unisex',
#  'url',
#  'usage',
#  'user',
#  'vehicle',
#  'vending',
#  'via',
#  'voltage',
#  'wall',
#  'water',
#  'waterway',
#  'waterway_category:NDS',
#  'website',
#  'wetland',
#  'wheelchair',
#  'wheelchair:description',
#  'width',
#  'wikidata',
#  'wikipedia',
#  'wires',
#  'xcn']

# %%
# Looking up "v" values for each "k"
all_k_v_dict["building:part"]
# Out:
# {'spire_tower', 'yes'}
