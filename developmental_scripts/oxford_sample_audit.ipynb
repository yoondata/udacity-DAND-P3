# %%
import os
os.chdir("..")

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import pprint
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
lower_colon_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*:([a-z]|_)*$')

SAMPLE = "oxford_sample.osm"

# %%
## Writing a function that returns unique tags and their 
## respective occurrence in an XML document


def check_tags(file_name):
    
    osm_file = open(file_name, "r")
    
    events = ET.iterparse(osm_file, events=("start",))
    _, root = next(events)  # Grabbing the root element
    
    tags = {}
    for event, elem in events:
        if (event == "start"):
            if elem.tag in tags.keys():
                tags[elem.tag] += 1
                root.clear()  # Freeing up memory by clearing the root element
            else:
                tags[elem.tag] = 1
                root.clear()  # Freeing up memory by clearing the root element
    
    osm_file.close()
    
    return tags

# %%
check_tags(SAMPLE)
# Out:
# {'member': 1332,
#  'nd': 39364,
#  'node': 27319,
#  'relation': 101,
#  'tag': 20963,
#  'way': 5035}

# %%
# Writing a function that returns unique attribute keys for each tag


def check_attributes(file_name):
    
    osm_file = open(file_name, "r")
    
    events = ET.iterparse(osm_file, events=("start",))
    _, root = next(events)  # Grabbing the root element
    
    attrib_dict = defaultdict(set)
    for event, elem in events:
        if (event == "start"):
            for attribute_name in elem.keys():
                attrib_dict[elem.tag].add(attribute_name)
                root.clear()  # Freeing up memory by clearing the root element
    
    osm_file.close()
    
    return attrib_dict

# %%
check_attributes(SAMPLE)
# Out:
# defaultdict(set,
#             {'member': {'ref', 'role', 'type'},
#              'nd': {'ref'},
#              'node': {'changeset',
#               'id',
#               'lat',
#               'lon',
#               'timestamp',
#               'uid',
#               'user',
#               'version'},
#              'relation': {'changeset',
#               'id',
#               'timestamp',
#               'uid',
#               'user',
#               'version'},
#              'tag': {'k', 'v'},
#              'way': {'changeset',
#               'id',
#               'timestamp',
#               'uid',
#               'user',
#               'version'}})

# %%
# Writing a function that returns unique "k" and "v" values in a dictionary form


def audit_k_v(file_name, parent_tag_list):
    
    osm_file = open(file_name, "r")
    
    events = ET.iterparse(osm_file, events=("start",))
    _, root = next(events)  # Grabbing the root element
    
    k_v_dict = {}
    for event, elem in events:
        if (event == "start"):
            if elem.tag in parent_tag_list:
                for tag in elem.iter("tag"):
                    k_val = tag.attrib["k"]
                    v_val = tag.attrib["v"]
                    if k_val not in k_v_dict.keys():
                        k_v_dict[k_val] = set()
                        k_v_dict[k_val].add(v_val)
                    else:
                        k_v_dict[k_val].add(v_val)
                root.clear()  # Freeing up memory by clearing the root element
    
    osm_file.close()
    
    return k_v_dict

# %% [markdown]
# ### Unique "k" and "v" values in "node" tags

# %%
node_k_v_dict = audit_k_v(SAMPLE, ["node"])
pprint.pprint(node_k_v_dict)
# Out:
# {'CAB:User_restictions': set(['Limited to patients of practice.']),
#  'FIXME': set(['continue', 'please confrim exact location']),
#  'Site:use': set(['Outreach surgery']),
#  'Support_service': set(['Citizans Advice Bureau']),
#  'access': set(['customers', 'no', 'permissive', 'private']),
#  'access:hgv': set(['@ (18:00-10:00)']),
#  'accessfrom': set(['Hawkins Street']),
#  'addr:city': set(['Eynsham, Witney', 'Oxford']),
#  'addr:country': set(['GB']),
#  'addr:county': set(['Oxfordshire']),
#  'addr:door': set(['Flats 13-24']),
#  'addr:housename': set(['Courtney Pianos',
#                         'Flat 4',
#                         'Foundry House',
#                         'Furnace House',
#                         'M&S',
#                         'North Parade Chambers',
#                         'Oxford Railway Station',
#                         'SoJo',
#                         'Stroud Court Lodge',
#                         'Summertown Pavilion']),
#  'addr:housenumber': set(['1',
#                           '1,2,5,6,7,9,10',
#                           '1-5',
#                           '10',
#                           '101',
#                           '104',
#                           '104A',
#                           '105',
#                           '107',
#                           '108',
#                           '108-/190',
#                           '11',
#                           '110',
#                           '111',
#                           '112',
#                           '113',
#                           '114',
#                           '117',
#                           '11a',
#                           '12',
#                           '122',
#                           '124',
#                           '129',
#                           '13',
#                           '131',
#                           '133',
#                           '135',
#                           '136a',
#                           '137',
#                           '139a',
#                           '13B',
#                           '14',
#                           '146',
#                           '14;14A',
#                           '15',
#                           '158',
#                           '15a',
#                           '16',
#                           '165',
#                           '17',
#                           '175-177',
#                           '18',
#                           '18-24',
#                           '18-44',
#                           '183',
#                           '19',
#                           '194',
#                           '195',
#                           '197',
#                           '1B',
#                           '2',
#                           '20',
#                           '207',
#                           '20a',
#                           '21',
#                           '215',
#                           '22',
#                           '222',
#                           '223',
#                           '23',
#                           '23C',
#                           '24',
#                           '24-26',
#                           '24-66',
#                           '25',
#                           '25-30',
#                           '250',
#                           '25c',
#                           '26',
#                           '262',
#                           '27',
#                           '28',
#                           '29',
#                           '2;4',
#                           '2B',
#                           '2a',
#                           '3',
#                           '30',
#                           '304',
#                           '31',
#                           '315,315A,315B',
#                           '32',
#                           '33',
#                           '34',
#                           '36',
#                           '366',
#                           '37;37A',
#                           '38',
#                           '389',
#                           '39',
#                           '4',
#                           '40',
#                           '42',
#                           '43',
#                           '436',
#                           '44',
#                           '45',
#                           '46',
#                           '463A',
#                           '47',
#                           '473',
#                           '48A-48D',
#                           '49',
#                           '498',
#                           '5',
#                           '50',
#                           '51',
#                           '53',
#                           '56a',
#                           '57',
#                           '59',
#                           '6',
#                           '6-8',
#                           '6-9',
#                           '61',
#                           '62',
#                           '62-72',
#                           '64',
#                           '65',
#                           '65b',
#                           '67',
#                           '68',
#                           '7',
#                           '70',
#                           '72',
#                           '75A',
#                           '77',
#                           '77-79',
#                           '77c',
#                           '78',
#                           '79;79A',
#                           '8',
#                           '80',
#                           '87',
#                           '9',
#                           '92',
#                           '93',
#                           '94',
#                           '95,96',
#                           'County Hall']),
#  'addr:interpolation': set(['even']),
#  'addr:place': set(['Cowley']),
#  'addr:postcode': set(['OX1 1BP',
#                        'OX1 1HS',
#                        'OX1 1LT',
#                        'OX1 1ND',
#                        'OX1 1PP',
#                        'OX1 2BQ',
#                        'OX1 2DU',
#                        'OX1 2EW',
#                        'OX1 2NA',
#                        'OX1 4DF',
#                        'OX2 0BN',
#                        'OX2 0ES',
#                        'OX2 6AQ',
#                        'OX2 6AX',
#                        'OX2 6GF',
#                        'OX2 6HJ',
#                        'OX2 7LG',
#                        'OX2 8AL',
#                        'OX29 4DA',
#                        'OX3 7RD',
#                        'OX3 9PX',
#                        'OX3 9QW',
#                        'OX4 1DG',
#                        'OX4 1JJ',
#                        'OX4 1RQ',
#                        'OX4 1UT',
#                        'OX4 1XB',
#                        'OX4 1XF',
#                        'OX4 2BS',
#                        'OX4 2HE',
#                        'OX5 1RZ',
#                        '\x7fOX4 1UH']),
#  'addr:street': set(['Acre Close',
#                      'Awgar Stone Road',
#                      'Banbury Road',
#                      'Barton Road',
#                      'Beaumont Street',
#                      'Becket Street',
#                      'Benson Road',
#                      'Bevington Road',
#                      'Botley Road',
#                      'Brasenose Driftway',
#                      'Broad Street',
#                      'Bulan Road',
#                      'Bullingdon Road',
#                      'Bullstake Close',
#                      'Chorefields',
#                      'Complins Close',
#                      'Copse Lane',
#                      'Cornmarket Street',
#                      'Corunna Crescent',
#                      'Cowley Road',
#                      "Cox's Ground",
#                      'Croxford Gardens',
#                      'Cumberland Road',
#                      'Cumnor Hill',
#                      'Dene Road',
#                      'Divinity Road',
#                      'Don Bosco Close',
#                      'Edgeway Road',
#                      'Fern Hill Drive',
#                      'Fletcher Road',
#                      'Forest Road',
#                      'Frenchay Road',
#                      'Fyfield Road',
#                      'George Street',
#                      'Glanville Road',
#                      'Glebe Street',
#                      'Gordon Woodward Way',
#                      'Great Clarendon Street',
#                      'Green Street',
#                      'Harley Road',
#                      'Harpes Road',
#                      'Hawkins Street',
#                      'Headley Way',
#                      'Hernes Road',
#                      'High Street',
#                      'Hollow Way',
#                      'Holyoake Road',
#                      'Hornbeam Drive',
#                      'Hugh Allen Crescent',
#                      'Hurst Street',
#                      'Hythe Bridge Street',
#                      'Iffley Road',
#                      "Jack Straw's Lane",
#                      'James Street',
#                      'John Parker Close',
#                      'Lathbury Road',
#                      'Leander Way',
#                      'Leopold Street',
#                      'Little Clarendon Street',
#                      'London Road',
#                      'Magdalen Road',
#                      'Manor Road',
#                      'Maple Avenue',
#                      'Mark Road',
#                      'Marlborough Court',
#                      'Middle Way',
#                      'New Road',
#                      'North Parade Avenue',
#                      'Old Road',
#                      'Osler Road',
#                      'Osney Lane',
#                      'Osney Mead',
#                      'Oxford Castle Quarter',
#                      'Oxford Road',
#                      'Park End Street',
#                      'Pembroke Street',
#                      'Polstead Road',
#                      'Quarry Hollow',
#                      'Quarry Road',
#                      'Queen Street',
#                      'Raleigh Park Road',
#                      'Randolph Street',
#                      'Rawlinson Road',
#                      'Regent Street',
#                      'Riverside Road',
#                      'Sandfield Road',
#                      'Silkdale Close',
#                      'South Avenue',
#                      'South Close',
#                      "St Aldate's",
#                      'St Clements Street',
#                      'St Ebbes Street',
#                      "St Leonard's Road",
#                      "St Margaret's Road",
#                      "St Mary's Road",
#                      "St Michael's Street",
#                      'Stapleton Road',
#                      'Staunton Road',
#                      'Staverton Road',
#                      'Stone Meadow',
#                      'Temple Street',
#                      'The Broadway',
#                      'The Phelps',
#                      'Valentia Road',
#                      'Walton Well Road',
#                      'Weymann Terrace',
#                      'Wilsdon Way',
#                      'Winchester Road',
#                      'Woodstock Road',
#                      'York Road']),
#  'addr:substreet': set(['Manzil Way', 'Wingfield Court']),
#  'addr:substreet:1': set(['12', 'Hilltop Court']),
#  'addr:town': set(['Headington']),
#  'alt_name': set(['DPAG',
#                   'North Hinksey Lane',
#                   'Rose Hill Parade',
#                   'ToysRUs']),
#  'amenity': set(['advice_service',
#                  'arts_centre',
#                  'atm',
#                  'bank',
#                  'bench',
#                  'bicycle_parking',
#                  'bicycle_rental',
#                  'bureau_de_change',
#                  'cafe',
#                  'clock',
#                  'community_centre',
#                  'dentist',
#                  'doctors',
#                  'fast_food',
#                  'fountain',
#                  'fuel',
#                  'hide',
#                  'library',
#                  'motorcycle_parking',
#                  'parking',
#                  'parking_entrance',
#                  'pharmacy',
#                  'place_of_worship',
#                  'post_box',
#                  'post_office',
#                  'pub',
#                  'recycling',
#                  'restaurant',
#                  'school',
#                  'scout_hut',
#                  'telephone',
#                  'theatre',
#                  'toilets',
#                  'vending_machine',
#                  'washingline',
#                  'waste_basket']),
#  'amenity:disused': set(['pub']),
#  'answer': set(['GIN', 'GJB']),
#  'artwork_type': set(['sculpture', 'statue']),
#  'atm': set(['no', 'yes']),
#  'backrest': set(['no', 'yes']),
#  'barrier': set(['bollard',
#                  'chicane',
#                  'cycle_barrier',
#                  'entrance',
#                  'gate',
#                  'kissing_gate',
#                  'no_entry',
#                  'stile',
#                  'ticket_barrier']),
#  'bicycle': set(['designated', 'no', 'yes']),
#  'bicycle_parking': set(['bollard', 'stands', 'wall_loops']),
#  'board_type': set(['board']),
#  'brand': set(['Esso']),
#  'building': set(['entrance', 'house']),
#  'bus_routes': set(['15;U5',
#                     '16;16B',
#                     '16A',
#                     '3;3A',
#                     '3;4;4A;4B;4C',
#                     '3;4;4A;4B;4C;12C;105;106;115;116']),
#  'capacity': set(['10',
#                   '12',
#                   '14',
#                   '16',
#                   '2',
#                   '24',
#                   '26',
#                   '3',
#                   '30',
#                   '32',
#                   '4',
#                   '40',
#                   '5',
#                   '54',
#                   '6',
#                   '8']),
#  'clothes': set(['wedding']),
#  'collection_times': set(['Mo-Fr 09:00;Sa 07:00',
#                           'Mo-Fr 15:15; Sa 11:30',
#                           'Mo-Fr 16:00; Sa 09:00',
#                           'Mo-Fr 16:00; Sa 10:00',
#                           'Mo-Fr 16:00; Sa off',
#                           'Mo-Fr 16:15; Sa 10:00',
#                           'Mo-Fr 16:30; Sa 08:30',
#                           'Mo-Fr 16:30; Sa 10:00',
#                           'Mo-Fr 16:30; Sa 12:00',
#                           'Mo-Fr 16:45; Sa 10:00',
#                           'Mo-Fr 16:45; Sa 12:00',
#                           'Mo-Fr 17:00; Sa 10:00',
#                           'Mo-Fr 17:00; Sa 11:30',
#                           'Mo-Fr 17:00; Sa 11:45',
#                           'Mo-Fr 17:00; Sa 12:00',
#                           'Mo-Fr 17:15; Sa 10:00',
#                           'Mo-Fr 17:15; Sa 10:45',
#                           'Mo-Fr 17:15; Sa 11:30',
#                           'Mo-Fr 17:15; Sa 12:00',
#                           'Mo-Fr 17:30; Sa 11:00',
#                           'Mo-Fr 17:30; Sa 11:45',
#                           'Mo-Fr 17:30; Sa 12:00',
#                           'Mo-Fr 18:30; Sa 12:00']),
#  'covered': set(['no', 'yes']),
#  'created_by': set(['JOSM',
#                     'Merkaartor 0.13',
#                     'Potlatch 0.10b',
#                     'Potlatch 0.10f',
#                     'Potlatch 0.9c',
#                     'osm2go v0.5-5',
#                     'osm2go v0.6-6',
#                     'osm2go v0.6-8',
#                     'osm2go v0.6-8debian1',
#                     'osm2go v0.6.13',
#                     'osm2go v0.6.13-maemo1',
#                     'osm2go v0.6.14']),
#  'crossing': set(['island',
#                   'no',
#                   'toucan',
#                   'traffic_signals',
#                   'uncontrolled',
#                   'unmarked',
#                   'zebra']),
#  'crossing_ref': set(['pelican', 'toucan', 'zebra']),
#  'cuisine': set(['burger',
#                  'burger;sausage',
#                  'burgers;snacks;full_english',
#                  'chicken',
#                  'chinese',
#                  'coffee_shop',
#                  'ice_cream',
#                  'indian',
#                  'italian',
#                  'mexican',
#                  'sausage']),
#  'currency': set(['pounds']),
#  'cycleway:left': set(['asl']),
#  'denomination': set(['anglican', 'catholic', 'methodist']),
#  'denotation': set(['urban']),
#  'description': set(['Regular burger and hot dog van', 'basement door']),
#  'designation': set(['2015', 'Access to parkland', 'Market Street *2317874*']),
#  'direction': set(['E', 'N', 'S', 'clockwise', 'w;e']),
#  'disconnected': set(['yes']),
#  'dismantled': set(['yes']),
#  'display': set(['sundial']),
#  'disused': set(['yes']),
#  'disused:amenity': set(['bank']),
#  'disused:highway': set(['bus_stop']),
#  'disused:shop': set(['convenience']),
#  'door': set(['sliding']),
#  'drive_through': set(['no']),
#  'email': set(['littlemore.library@oxfordshire.gov.uk']),
#  'emergency': set(['life_ring']),
#  'entrance': set(['Pedestrian',
#                   'back',
#                   'emergancy',
#                   'fire_exit',
#                   'garden',
#                   'home',
#                   'main',
#                   'service',
#                   'staircase',
#                   'yes']),
#  'fax': set(['+44-1865-248606']),
#  'fee': set(['no']),
#  'female': set(['yes']),
#  'fixme': set(['Survey for detail',
#                'capacity approximate',
#                'incomplete',
#                'need to check it moves to let the lorries though',
#                'position']),
#  'food': set(['yes']),
#  'foot': set(['designated', 'no', 'private', 'yes']),
#  'frequency': set(['0', '1']),
#  'fuel:diesel': set(['yes']),
#  'fuel:octane_95': set(['yes']),
#  'fuel:octane_98': set(['yes']),
#  'gate': set(['kissing']),
#  'genus': set(['Taxus']),
#  'gluten_free': set(['yes']),
#  'highway': set(['bus_stand',
#                  'bus_stop',
#                  'crossing',
#                  'elevator',
#                  'give_way',
#                  'mini_roundabout',
#                  'rest_area',
#                  'speed_camera',
#                  'street_lamp',
#                  'traffic_signals',
#                  'turning_circle']),
#  'historic': set(['memorial', 'monument', 'tower']),
#  'history': set(['retrieved using undelete JOSM plugin']),
#  'horse': set(['no', 'permissive', 'yes']),
#  'identification': set(['108']),
#  'indoor': set(['HVAC_plant', 'door', 'yes']),
#  'information': set(['board']),
#  'inscription': set(['J.R.R. TOLKIEN Author of The Lord of the Rings Lived here 1930-1947']),
#  'internet_access': set(['wlan']),
#  'is_in': set(['Oxford, Oxfordshire, England, UK',
#                'Oxfordshire, England, UK']),
#  'journeys': set(['6', 'some']),
#  'kerb': set(['lowered']),
#  'lamp': set(['post']),
#  'lamp_mount': set(['straight mast']),
#  'lamp_operator': set(['Oxford County Council',
#                        'Oxfordshire County Council',
#                        'Oxfordshire County Council streetlighting department']),
#  'lamp_type': set(['electric', 'mercury']),
#  'landuse': set(['construction', 'farm']),
#  'layer': set(['-1', '3']),
#  'leaf_cycle': set(['evergreen']),
#  'leaf_type': set(['broadleaved', 'needleleaved']),
#  'learning': set(['oxford_department']),
#  'leisure': set(['garden', 'nature_reserve', 'playground']),
#  'level': set(['-1', '0', '0.2', '0.5', '1', '2', '3']),
#  'lift': set(['yes']),
#  'local:Bearing': set(['N', 'S']),
#  'local_ref': set(['4',
#                    'A1',
#                    'E3',
#                    'F3',
#                    'H3',
#                    'H4',
#                    'I3',
#                    'J5 SET',
#                    'J8',
#                    'R2']),
#  'male': set(['no', 'yes']),
#  'man_made': set(['obelisk', 'silo']),
#  'manhole': set(['vertical shaft to deep sewer']),
#  'material': set(['wood']),
#  'maxspeed': set(['20 mph', '30']),
#  'maxspeed:note': set(['Oxford 20 mph zone']),
#  'maxspeed:spec': set(['A point 67m N of its jn w/ Little Clarendon St, S to...',
#                        "Banbury Rd's junction with St Giles",
#                        'a point 7m NW of its jn w/ Southfield Rd']),
#  'memorial': set(['blue_plaque']),
#  'motor_vehicle': set(['no', 'permissive']),
#  'motorcar': set(['no', 'yes']),
#  'motorcycle': set(['yes']),
#  'name': set(['12',
#               '1st Phone City',
#               '24',
#               '6',
#               '9',
#               '9 to 9',
#               'AMT Coffee',
#               'Abingdon Arms PH',
#               'Alan Aston Roofing Supplies Ltd',
#               'Allen Ward and Medical Library',
#               'American Nails',
#               'Atkinson Close',
#               'Batholomew School',
#               'Bayswater Road',
#               'Becket House B&B',
#               'Beech Croft Road',
#               'Beeline Bicycles',
#               'Betfred',
#               "Bill's",
#               'Blacksmiths Meadow',
#               'Blue Plaque - J.R.R. Tolkien',
#               'Blue plaque: Dyson Perrins Laboratory',
#               'Boots',
#               'Boswells & Co',
#               'Bradlands',
#               'Brasenose Woods',
#               'Broad Close',
#               'Broadgates',
#               'Brothers',
#               'Burger King',
#               'CO-OP Market Street 2317874',
#               'Canal Street',
#               'Cargo',
#               'Carpenter Close',
#               'Cassington Turn',
#               'Castle Street',
#               'Cecil Jackson-Cole',
#               'Chancellors',
#               'Chelsea',
#               'Church Cowley School',
#               'Churchill Road',
#               'Clock House',
#               'Co-op',
#               'Copse Lane West',
#               'Cornwallis Close',
#               'Cots Gardens',
#               'Courtney Pianos',
#               'Coutts',
#               'Covered Market',
#               'Cowley Workers Social Club',
#               'Crescent Hall',
#               'Dashwood Road',
#               'David Spicer Optician',
#               'Deanfield Road',
#               'Department of Physiology, Anatomy and Genetics',
#               'Derwent Avenue',
#               'Dovehouse Close',
#               'Dragon Bowl',
#               'East Avenue',
#               'Ede & Ravenscroft',
#               'Edgecombe Road',
#               'Egrove Park',
#               'Elsfield',
#               "Elton's Gate",
#               'Esso',
#               'Fairacre Farm',
#               'Firs Meadow',
#               'First Class Cuisine',
#               'First Turn',
#               'Fitrite',
#               'Florence Park Road',
#               'Forest Hill Turn A40',
#               'Foxdown Close',
#               'Freelands Road',
#               'Garden Quad',
#               'George Street',
#               'George and Danver',
#               'Girdlestone Close',
#               'Glebe Street',
#               'Globe Newsmarkets',
#               'Gloucester Green Car Park',
#               'Gypsy Lane Site',
#               'Hamilton Road',
#               'Headington',
#               'Headington Royal British Legion Club',
#               'Headington School',
#               'Herschel Crescent',
#               'Heyford Hill Lane',
#               'High Street',
#               'Hinksey Hill Top',
#               'Holland & Barrett',
#               'Horseman Close',
#               'Howard Street',
#               'J. E. Pill & Son',
#               "Jamie's Italian",
#               'Jeans West',
#               'John Watson School',
#               'Jordan Hill',
#               'Kendal Cresent Shops',
#               'Kennington Health Centre',
#               'Kennington Methodist Church',
#               'La Croissanterie',
#               'Lal Newsagent',
#               'Lincombe Lane',
#               'Littlemore Library',
#               'Littlemore Mental Health Centre',
#               'Littlemore Shops',
#               'Lloyds Bank',
#               'Lloyds Pharmacy',
#               'Londis',
#               'London Road',
#               'Long Hanborough Post Office',
#               "Lucky 777's",
#               'Maidcroft Road',
#               'Main Gate',
#               'Main Road',
#               'Manual Spring',
#               'Margaret Road',
#               'Marks & Spencer',
#               "Martin's",
#               'Masons Road North',
#               "McDonald's",
#               'Mickle Way',
#               'Mill Street Shops',
#               'Millwood Vale',
#               'Minns Industrial Estate',
#               'Mission Burrito',
#               'Modern Art Oxford',
#               "Nando's",
#               'Nawabi',
#               'Netherton Road',
#               u'New Biochemistry Caf\xe9',
#               'New Hinksey',
#               'New Testament Church of God',
#               'Newton Road',
#               'Norham Manor',
#               'Northmoor',
#               'Nuffield Orthopaedic Reception',
#               "O'Neill's",
#               'O2',
#               'Oaks',
#               'Oasis Dental Care',
#               'Old Marston Library',
#               'Orthopaedic Centre',
#               'Oxford',
#               'Oxford (Cowley) Driving Test Centre',
#               'Oxford Bus Company',
#               'Oxford City Boundary Stone',
#               'Oxford FE College',
#               'Oxford Print Centre',
#               'Oxford Rail Station',
#               'Pandora',
#               'Park and Ride',
#               'Pebblehill Mob Pk',
#               'Pen to Paper',
#               'Podarok',
#               'Portabello',
#               'Post Office',
#               'Prezzo',
#               'Queen Street',
#               'Queens Lane',
#               'Radcliffe Infirmary',
#               'Reception',
#               'Red Lion',
#               'Red Lion PH',
#               'Rippington Drive',
#               'Roads heavily reconfigured for construction.',
#               'Roger Bannister',
#               'Rogers Auto Factors LTD',
#               'Roosevelt Road',
#               'Rose Hill Community Centre',
#               'Rose Hill Parade',
#               'Royal Sun',
#               'Sacred Heart Church',
#               "Sainsbury's Local",
#               'Sandy Lane',
#               'Santander',
#               'Seacourt P&R',
#               'Senli Cash & Go',
#               'Shotover Hill',
#               'Simpkins Lee Theatre',
#               'SmallWorld Montessori School',
#               'Sobell House Hospice Shop',
#               'Sojo',
#               'South Hinksey Turn Northbound',
#               'Spar',
#               'Ss. Peter and Paul',
#               'St Aldates',
#               "St Andrew's",
#               "St Bartholomew's Medical Centre",
#               "St Margaret's Road",
#               "St Peter's",
#               'St Swithuns Primary School',
#               'Staircase 1',
#               'Staircase 11',
#               'Staircase 2',
#               'Staircase 3',
#               'Stowford Farm',
#               'Subway',
#               'Sugworth Lane',
#               'Sun Me',
#               'Supa Sava',
#               'Swan Hotel',
#               'Swinford Bridge',
#               'TP0596',
#               'TP3833',
#               'TP6574',
#               'Tackley Place',
#               "Tattoo Club of Great Britain / Lionel's Tattoo Studio",
#               "Taylor's",
#               'Teddy Edwards',
#               'The Bear and Ragged Staff',
#               'The Big Bang',
#               'The Cycle Shop & General Store',
#               'The Excelsior',
#               'The Fox',
#               'The Iffley Yew',
#               'The Magic Cafe',
#               'The Nosebag',
#               'The Nuffield Needle',
#               'The Oxford Hotel',
#               'The Plough PH',
#               'The Royal Sun',
#               'The University of Oxford Shop',
#               'The Wheatsheaf',
#               'The White Horse',
#               'The Willows',
#               'Thomas White Staircase 7',
#               'Thornhill Park and Ride',
#               'Three',
#               'Tilbury Lane',
#               'To Restrauant',
#               'Tumbling Bay Cafe',
#               'Union Street',
#               'Versus',
#               'Virgin Money',
#               'WHSmith',
#               'Waitrose',
#               'Warneford Hospital',
#               'Ways Farm',
#               'West Cornwall Pasty Co',
#               'West End',
#               'West Wing',
#               'Westminster Way',
#               'Wharton Road',
#               'Worcester Street Car Park',
#               'Worton',
#               'Y',
#               'Your Local Top Up Store',
#               'Zoal Phone Clinic',
#               'basement door',
#               'iwantgreatcare.org',
#               'temple street dentist']),
#  'name:cy': set(['Rhydychen']),
#  'naptan:AtcoCode': set(['34000000004',
#                          '340000002CAR',
#                          '340000004H3',
#                          '340000004H4',
#                          '340000006R2',
#                          '34000000703',
#                          '340000008JR8',
#                          '340000015FOX',
#                          '340000022MOR',
#                          '340000033OFC',
#                          '340000056F3',
#                          '340000084OUT',
#                          '340000168TO',
#                          '340000320OPP',
#                          '340000335SCH',
#                          '340000487MIL',
#                          '340000583RL',
#                          '340000732MR',
#                          '340000864A1',
#                          '340000874CR',
#                          '340000930ORV',
#                          '340000967CNR',
#                          '340000988CNR',
#                          '340000992WR1',
#                          '340000997CNR',
#                          '340001002OPP',
#                          '340001042OPP',
#                          '340001047OPP',
#                          '340001052OPV',
#                          '34000105792',
#                          '340001068CNR',
#                          '340001091ENT',
#                          '340001095OUT',
#                          '340001103CNR',
#                          '340001109CNR',
#                          '340001127CNR',
#                          '340001132DSH',
#                          '340001135SOU',
#                          '340001138OUT',
#                          '340001143OUT',
#                          '340001156OXC',
#                          '340001161OUT',
#                          '340001174ENT',
#                          '340001179OPP',
#                          '340001197CNR',
#                          '340001203KIN',
#                          '340001211CNR',
#                          '340001219CNR',
#                          '340001228OPP',
#                          '340001235OPP',
#                          '340001240LNG',
#                          '340001245OUT',
#                          '340001247OPO',
#                          '340001252OPR',
#                          '340001265OPP',
#                          '340001272CNR',
#                          '340001278ODA',
#                          '340001283CNR',
#                          '340001284OPP',
#                          '340001292OPP',
#                          '340001302CNR',
#                          '340001312OPP',
#                          '340001317OPP',
#                          '340001318CNR',
#                          '340001325OPP',
#                          '340001326ENT',
#                          '340001328OPA',
#                          '340001336OPP',
#                          '340001345OBR',
#                          '340001352OPP',
#                          '340001360OPP',
#                          '340001368MAR',
#                          '340001377OPP',
#                          '340001526OUT',
#                          '340001534OUT',
#                          '340001539CNR',
#                          '340001701WST',
#                          '340001812WWC',
#                          '340001851OPP',
#                          '340001903OUT',
#                          '340001992J5',
#                          '340002011OPP',
#                          '340002016CNR',
#                          '340002053VS',
#                          '340003014E',
#                          '340003022N',
#                          '340003058WES',
#                          '340003061OPP',
#                          '340003074OPP',
#                          '340003100OUT',
#                          '340003111OPP',
#                          '340003204OPP',
#                          '340003262NOR',
#                          '340003313OPP',
#                          '340004133BRD',
#                          '9100OXFD']),
#  'naptan:Bearing': set(['E', 'N', 'NE', 'NW', 'S', 'SE', 'SW', 'W']),
#  'naptan:BusStopType': set(['CUS']),
#  'naptan:CommonName': set(['Abingdon Arms PH',
#                            'Atkinson Close',
#                            'Batholomew School',
#                            'Bayswater Road',
#                            'Beech Croft Road',
#                            'Blacksmiths Meadow',
#                            'Bradlands',
#                            'Broad Close',
#                            'Canal Street',
#                            'Carfax',
#                            'Carpenter Close',
#                            'Cassington Turn',
#                            'Castle Street',
#                            'Church Cowley Sch',
#                            'Churchill Road',
#                            'Clock House',
#                            'Copse Lane West',
#                            'Cornwallis Close',
#                            'Cots Gardens',
#                            'Crescent Hall',
#                            'Dashwood Road',
#                            'Deanfield Road',
#                            'Derwent Avenue',
#                            'Dovehouse Close',
#                            'East Avenue',
#                            'Edgecombe Road',
#                            'Egrove Park',
#                            'Firs Meadow',
#                            'First Turn',
#                            'Florence Park Road',
#                            'Forest Hill Turn A40',
#                            'Foxdown Close',
#                            'Freelands Road',
#                            'George Street',
#                            'Girdlestone Close',
#                            'Glebe Street',
#                            'Gloucester Green Bus Station',
#                            'Hamilton Road',
#                            'Headington School',
#                            'Heyford Hill Lane',
#                            'Hinksey Hill Top',
#                            'Horseman Close',
#                            'Howard Street',
#                            'Jordan Hill',
#                            'Kendal Cresent Shops',
#                            'Lincombe Lane',
#                            'Littlemore Mental Health Centre',
#                            'Littlemore Shops',
#                            'Maidcroft Road',
#                            'Main Road',
#                            'Margaret Road',
#                            'Masons Road North',
#                            'Mickle Way',
#                            'Mill Street Shops',
#                            'Millwood Vale',
#                            'Minns Ind Est',
#                            'Netherton Road',
#                            'Newton Road',
#                            'Old Marston Library',
#                            'Orthopaedic Centre',
#                            'Oxford FE College',
#                            'Park and Ride',
#                            'Pebblehill Mob Pk',
#                            'Post Office',
#                            'Queen Street',
#                            'Queens Lane',
#                            'Radcliffe Infirmary',
#                            'Railway Station',
#                            'Red Lion PH',
#                            'Rippington Drive',
#                            'Roosevelt Road',
#                            'Rose Hill Parade',
#                            'Sandy Lane',
#                            'Seacourt Park & Ride',
#                            'South Hinksey Turn Northbound',
#                            'St Aldates',
#                            "St Margaret's Road",
#                            'St Swithuns Primary School',
#                            'Stowford Farm',
#                            'Sugworth Lane',
#                            'Swan Hotel',
#                            'Swinford Bridge',
#                            'Tackley Place',
#                            'The Bear and Ragged Staff',
#                            'The Plough PH',
#                            'The Willows',
#                            'Tilbury Lane',
#                            'Union Street',
#                            'Warneford Hospital',
#                            'Ways Farm',
#                            'West Wing',
#                            'Westminster Way',
#                            'Wharton Road']),
#  'naptan:Crossing': set(['Mill Lane']),
#  'naptan:Indicator': set(['90 Banbury Road',
#                           'A34 Northbound Bus Shelter',
#                           'Banbury Road Southbound',
#                           'Bay 4',
#                           'Church',
#                           'Corner',
#                           'Cranesbill Way Corner',
#                           'Entrance',
#                           'Flats',
#                           'Foxcombe Road Corner',
#                           'Long Lane corner',
#                           'Marshall Road',
#                           'N bound',
#                           'Northbound',
#                           'Opp Chapel Way',
#                           'Opp Evenlode Tower',
#                           'Opposite',
#                           'Opposite Bicester Road',
#                           'Opposite Farm',
#                           'Opposite Rahere Road',
#                           'Opposite Victoria Road',
#                           'Outside',
#                           'Outside Allotments',
#                           'Outside Entrance',
#                           'Outside Post Office',
#                           'Southbound',
#                           'Sparsey Place Corner',
#                           'Stand J8',
#                           'Stop A1',
#                           'Stop E3',
#                           'Stop F3',
#                           'Stop H3',
#                           'Stop H4',
#                           'Stop I3 Set Down',
#                           'Stop J5 Set Down',
#                           'Stop R2',
#                           'West end of road',
#                           'Westbound',
#                           'adj',
#                           'corner',
#                           'corner Sandy Lane',
#                           'opp',
#                           'opposite',
#                           'out']),
#  'naptan:Landmark': set(['A40 Turn',
#                          'Abingdon Arms',
#                          'Ashurst Way',
#                          'Bay 4',
#                          'Bayworth Manor',
#                          'Beech Croft Road',
#                          'Broad Close',
#                          'Bus Shelter',
#                          'Bus Shelters',
#                          'Bypass Bridge',
#                          'Canal Street',
#                          'Car Garage',
#                          'Church',
#                          'Community Centre',
#                          'Copse Lane',
#                          'Cornwallis Road School',
#                          'Cots Gardens',
#                          'Crescent Hall',
#                          'Deanfield Road',
#                          'Derwent Avenue',
#                          'Dovehouse Close',
#                          'E.F. School',
#                          'East Avenue',
#                          'Edgecombe Road',
#                          'Evenlode Tower',
#                          'Farm',
#                          'Fettiplace Road',
#                          'Field Farm',
#                          'Firs Meadow',
#                          'Freelands Road',
#                          'Girdlestone Road',
#                          'Hamilton Road',
#                          'Headington School',
#                          'Heyford Hill Lane',
#                          'High Street',
#                          'Horseman Close',
#                          'Hospital',
#                          'Hotel',
#                          'Howard Street',
#                          'Library',
#                          'Lincombe Lane',
#                          'Maidcroft Road',
#                          'Main Road',
#                          'Margaret Road',
#                          'Mickle Way',
#                          'Minns Industrial Estate',
#                          'Mobile Park',
#                          'Motorcycle Showroom',
#                          'Newton Road',
#                          'No 16',
#                          'Nuffield Orthopaedic Centre',
#                          'Opp Bus Shelter',
#                          'Oxford Business Park',
#                          'Park and Ride Entrance',
#                          'Post Office',
#                          'Priory Road',
#                          'Radcliffe Infirmary',
#                          'Red Lion',
#                          'Rippington Drive',
#                          'Roosevelt Road',
#                          'Rose Hill Shops',
#                          'Royal Sun PH',
#                          'Sandy Lane',
#                          'School',
#                          'Seacourt Park and Ride',
#                          'Shops',
#                          "St Margaret's Road",
#                          'St Swithuns Primary School',
#                          'Stop A1',
#                          'Stop E3',
#                          'Stop F3',
#                          'Stop H3',
#                          'Stop H4',
#                          'Stop I3',
#                          'Stop J5',
#                          'Stop R2',
#                          'Stowford Farm',
#                          'Swan Hotel',
#                          'Tackley Place',
#                          'Templeton College',
#                          'The Bear and Ragged Staff',
#                          'The Plough PH',
#                          'The Willows',
#                          'Tilbury Lane',
#                          'Union Street',
#                          'Warneford Hospital',
#                          'Ways Farm',
#                          'West Wing Entrance',
#                          'Wharton Road',
#                          'Woodstock Road']),
#  'naptan:NaptanCode': set(['oxfadaga',
#                            'oxfadagw',
#                            'oxfadamg',
#                            'oxfadatm',
#                            'oxfadawj',
#                            'oxfadgaw',
#                            'oxfadgjd',
#                            'oxfadgmp',
#                            'oxfadjaj',
#                            'oxfadjwt',
#                            'oxfadmdt',
#                            'oxfadmjw',
#                            'oxfadmtg',
#                            'oxfadmwg',
#                            'oxfadmwt',
#                            'oxfadpmj',
#                            'oxfadpta',
#                            'oxfadptg',
#                            'oxfadptw',
#                            'oxfadwtm',
#                            'oxfagadw',
#                            'oxfagaja',
#                            'oxfagatj',
#                            'oxfagdmd',
#                            'oxfagdpm',
#                            'oxfagmgj',
#                            'oxfagpat',
#                            'oxfagtpt',
#                            'oxfagwtm',
#                            'oxfajagw',
#                            'oxfajaja',
#                            'oxfajapm',
#                            'oxfajatm',
#                            'oxfajawa',
#                            'oxfajdgt',
#                            'oxfajdjg',
#                            'oxfajdmd',
#                            'oxfajdpa',
#                            'oxfajdtw',
#                            'oxfajgaj',
#                            'oxfajgat',
#                            'oxfajgaw',
#                            'oxfajgpw',
#                            'oxfajgtj',
#                            'oxfajgwt',
#                            'oxfajmjp',
#                            'oxfajmjw',
#                            'oxfajmta',
#                            'oxfamawm',
#                            'oxfamdwa',
#                            'oxfamgmd',
#                            'oxfamgmt',
#                            'oxfamgmw',
#                            'oxfamgtj',
#                            'oxfamjad',
#                            'oxfamjam',
#                            'oxfamjdt',
#                            'oxfamjmj',
#                            'oxfampwm',
#                            'oxfapdag',
#                            'oxfapdta',
#                            'oxfapgwd',
#                            'oxfapjat',
#                            'oxfapmja',
#                            'oxfapwtw',
#                            'oxfatdjg',
#                            'oxfatgjp',
#                            'oxfatgmw',
#                            'oxfatgwj',
#                            'oxfatmgp',
#                            'oxfatmjg',
#                            'oxfatpat',
#                            'oxfatpgt',
#                            'oxfatpwa',
#                            'oxfatwtm',
#                            'oxfawatp',
#                            'oxfawdmj',
#                            'oxfgadjm',
#                            'oxfgadjt',
#                            'oxfgajpd',
#                            'oxfgapmj',
#                            'oxfgatda',
#                            'oxfgdjtm',
#                            'oxfgdpga',
#                            'oxfgdwtm',
#                            'oxfgjdjp',
#                            'oxfgjdmj',
#                            'oxfgjgja',
#                            'oxfgjgwm',
#                            'oxfgjmpj',
#                            'oxfgmdag',
#                            'oxfgmjwm',
#                            'oxfgmtad']),
#  'naptan:Notes': set(['Road Markings Only']),
#  'naptan:PlusbusZoneRef': set(['OXFD']),
#  'naptan:ShortCommonName': set(['Egrove Park', 'Glebe Street']),
#  'naptan:Street': set(['A34 Southern By Pass',
#                        'A40',
#                        'Abingdon Road',
#                        'Acre End Street',
#                        'Appleton Road',
#                        'Ashurst Way',
#                        'Balfour Road',
#                        'Banbury Road',
#                        'Bartholomew Road',
#                        'Bayswater Road',
#                        'Blackbird Leys Road',
#                        'Blacksmiths Meadow',
#                        'Botley Road',
#                        'Bradlands',
#                        'Canal Street',
#                        'Castle Street',
#                        'Church Road',
#                        'Copse Lane',
#                        'Cornwallis Road',
#                        'Cowley Road',
#                        'Crossroads',
#                        'Cumnor Road',
#                        'East Avenue',
#                        'Enstone Road',
#                        'Eynsham Road',
#                        'Fettiplace Road',
#                        'Florence Park Road',
#                        'Fox Lane',
#                        'Foxcombe Road',
#                        'George Street',
#                        'Gidley Way',
#                        'Girdlestone Close',
#                        'Gloucester Green',
#                        'Grenoble Road',
#                        'Hanborough Road',
#                        'Headley Way',
#                        'High Street',
#                        'Hollow Way',
#                        'Iffley Road',
#                        'John Radcliffe Hospital',
#                        'Kennington Road',
#                        'Kingston Road',
#                        'Littlehay Road',
#                        'London Rd A40',
#                        'Long Ground',
#                        'Marsh Lane',
#                        'Masons Road',
#                        'Mill Street',
#                        'Netherton Road',
#                        'Old Marston Road',
#                        'Oxford Road',
#                        'Queen Street',
#                        'Sandford Road',
#                        'St Aldates',
#                        'St Clements Street',
#                        'St Nicholas Road',
#                        'Standlake Road',
#                        'Stanton Road',
#                        'Station Forecourt',
#                        'Sugworth Lane',
#                        'Sutton Lane',
#                        'Templar Road',
#                        'The Avenue',
#                        'Trapper Tom Way',
#                        'Union Street',
#                        'Warneford Lane',
#                        'Westminster Way',
#                        'Wharton Road',
#                        'Windmill Road',
#                        'Witney Road',
#                        'Woodstock Road',
#                        'Yarnton Road']),
#  'naptan:verified': set(['no', 'yes']),
#  'natural': set(['peak', 'spring', 'tree']),
#  'network': set(['Link', 'Oxonbikes']),
#  'note': set(['"morning through to 11:30pm o\'clock-ish". geographic location varies along the long parking lane on the parkside of the road.',
#               '1 bed bungalow on a campus for residents of 55 years of age or older.',
#               '3 Wheeler Robinson House',
#               'Access to Science Park: locked at night and weekends',
#               'Disabled access to Taylorian',
#               'FIXME: "squeezer" shoulder gate thingy (difficult to describe)',
#               'FIXME: position approximate',
#               'Free motorcycle parking in bays',
#               "I'm going to work out the missing details for this in the next edit..",
#               'Inside the bank',
#               'It looks more like a wooden gate you have to climb over (2 rungs) rather than a traditional stile with steps.',
#               'Monday to Friday in term time only',
#               'Needs future update',
#               'On a strip of tactile paving in the "cycles" direction. Inconsistent with signage.',
#               "Representing 2 sets, since we don't distringuish lanes on the side roads. They *are* toucans, right?",
#               'S5 omitted since very infrequent extension',
#               'Saturday opening term time only and subject to staff availability',
#               'Sheffield stands x2',
#               'Steps up to entrance.',
#               "There's two of them, and that's what they look like.",
#               'These tags are for a advice service that uses this building used also by other organisations. I tied them to a node on the building so they be separately machine read more easily until a scheme for all the users of the building is arranged. pointcan=logo',
#               'This entrance is for the 2 businesses upstairs',
#               'This side is merely a little alphanumeric code sign.',
#               'Unofficial link to Southfield Golf Course diverges here',
#               'Up for sale as of 20090829',
#               'Wall type in brick pillar',
#               'being rebuilt',
#               'bus_stand is like a stop but allows in oxford a bus to park awaiting a later return to service.',
#               'checked ref it rlates to the whole double sided hoop sign stand.',
#               'does this stop exist?',
#               'entrance level but narrow; needs to be checked',
#               'frontof garage point between 40&38',
#               'no longer served',
#               'no pole; name assumed same as others; services inferred',
#               'padlocked open currently',
#               "remove this tag and the interpolated way when road resurveyed - too many houses suggest an 'a' somewhere in the middle.",
#               'shared escape route.',
#               'side pillers removed and wohle side left open in the last 15 years',
#               'sign marking extent of place',
#               'signpost marking place boundary',
#               'two bus companies, two names...',
#               'user-operated',
#               'was Chelsea bank currently looking to be converted to reastuant under planning permission: 14/01091/FUL its been apprved but may be in an appel phase. Oxford.gov.uk']),
#  'note:reply': set(["j5 dosn't but other moves possible see note:reply on stope j4 to the east of here."]),
#  'number': set(['OX29 780']),
#  'old_name': set(['The Friar']),
#  'opening_hours': set(['Mo 14:00-18:00; Tu 14:00-16:30; Th 09:30-12:30,14:00-16:30; Fr 09:30-12:30; Sa 09:30-13:30',
#                        'Mo-Fr 07:00-17:30; Sa 07:30-12:00',
#                        'Mo-Fr 09:00-17:00; Sa 10:00-14:00',
#                        'Mo-Sa 07:00-20:00; Su 07:00-18:00',
#                        'Mo-Su 06:00-18:00',
#                        'Mo-Su 07:00-23:00',
#                        'Mo-Su 08:00-24:00',
#                        'Mo-We 11:00-22:00; Th-Sa 11:00-23:00; Su 11:00-22:00',
#                        'Tu-Fr 09:00-17:00; Sa-Su 10:00-15:00',
#                        'Tu-Sa 11:00-18:00; Su 12:00-17:00',
#                        'Tu-Th 09:30-17:30; Sa 09:30-18:00']),
#  'opening_hours:morning': set(['yes']),
#  'openplaques:id': set(['1012', '1020', '30602']),
#  'operator': set(['BP / Budgens',
#                   'Barclays Bank PLC',
#                   'Esso',
#                   "G&D's",
#                   'GSBikeshare',
#                   'GreenSquare',
#                   'Greene King',
#                   'Halifax',
#                   'KFC',
#                   'Lloyds',
#                   'Lloyds Bank',
#                   "McDonald's",
#                   "Nando's",
#                   'National Grid',
#                   'One Stop',
#                   'Oxford City Council',
#                   'Oxfordshire Blue Plaques Board',
#                   'RBS',
#                   'RBSs',
#                   'Royal Mail',
#                   'Royal Society of Chemistry',
#                   "Sainsbury's",
#                   'Santander',
#                   'Shell',
#                   'Southern Electric Company',
#                   'The Hotel Collection',
#                   'Turf Tavern']),
#  'organic': set(['yes']),
#  'organisaition': set(['Oxford CAB']),
#  'organisation:affiliation:National': set(['The Citizens Advice service/Mae gwasanaeth Cyngor ar Bopeth']),
#  'organisation:affiliation:region': set(['Consortium of Oxfordshire CAB']),
#  'orienteering': set(['pole']),
#  'outdoor_seating': set(['yes']),
#  'park_and_ride': set(['300', '500']),
#  'parking': set(['entrance', 'surface']),
#  'payment:card': set(['yes']),
#  'payment:cards': set(['yes']),
#  'payment:coins': set(['no', 'yes']),
#  'phone': set(['+44 1865 202016',
#                '+44 1865 202888',
#                '+44 1865 247144',
#                '+44 1865 248731',
#                '+44 1865 351201',
#                '+44 1865 516992',
#                '+44 1865 711228',
#                '+44 1865 714309',
#                '+44 1865 718477',
#                '+44 1865 721033',
#                '+44 1865 722733',
#                '+44 1865 739891',
#                '+44 1865 761425',
#                '+44 1865 790400',
#                '+44-1865-204666',
#                '+44-1865-245952',
#                '+44-1865-246-615',
#                '+44-1865-248604',
#                '+44-1865-559653',
#                '+44-1865-721156',
#                '+44-1865-724675',
#                '+44-1865-727465',
#                '+44-1865-838383']),
#  'place': set(['hamlet', 'suburb', 'village']),
#  'platforms': set(['3']),
#  'playground': set(['acoustic_mirror']),
#  'post_box:design': set(['type_a']),
#  'post_box:mounting': set(['brick_pillar']),
#  'post_box:type': set(['lamp', 'pillar', 'wall']),
#  'postal_code': set(['OX1 5JX', 'OX2', 'OX3', 'OX33', 'OX5']),
#  'power': set(['cable_distribution_cabinet', 'pole', 'sub_station', 'tower']),
#  'public_transport': set(['station']),
#  'railway': set(['buffer_stop', 'crossing', 'level_crossing', 'station']),
#  'real_ale': set(['yes']),
#  'recycling:batteries': set(['yes']),
#  'recycling:cans': set(['yes']),
#  'recycling:clothes': set(['yes']),
#  'recycling:glass': set(['yes']),
#  'recycling:paper': set(['yes']),
#  'recycling:shoes': set(['yes']),
#  'recycling_type': set(['container']),
#  'ref': set(['11',
#              '13B',
#              '19',
#              '2015',
#              '4TE 27',
#              '5',
#              '6',
#              '69323242',
#              '69325292',
#              '69325428',
#              '69325498',
#              '69325659',
#              '69326469',
#              '69326526',
#              '69327528',
#              '69329287',
#              '69345357',
#              '7',
#              '8',
#              '8S',
#              '9',
#              'O1',
#              'O3',
#              'O4',
#              'OX1 100',
#              'OX1 118',
#              'OX1 131',
#              'OX1 215',
#              'OX1 319',
#              'OX1 622',
#              'OX2 204',
#              'OX2 234',
#              'OX2 290',
#              'OX2 38',
#              'OX2 443',
#              'OX2 61',
#              'OX2 628',
#              'OX2 65',
#              'OX2 693',
#              'OX29 15',
#              'OX29 400',
#              'OX3 211',
#              'OX3 351',
#              'OX3 41',
#              'OX3 541',
#              'OX3 546',
#              'OX3 576',
#              'OX3 594',
#              'OX3 63',
#              'OX3 662',
#              'OX3 704',
#              'OX3 861',
#              'OX33 209',
#              'OX33 736',
#              'OX4 10',
#              'OX4 195',
#              'OX4 216',
#              'OX4 42',
#              'OX4 50',
#              'OX4 583',
#              'OX4 713',
#              'OX4 802',
#              'OX4 816',
#              'OX5 729',
#              'OX5 758',
#              'OX5 785',
#              'OX5 930',
#              'OXF']),
#  'religion': set(['christian']),
#  'route': set(['14A;17C']),
#  'route_ref': set(['10;600;700',
#                    '10;U4;U5',
#                    '12;12A',
#                    '14;14A;17;17A;17C;218;S2;S3',
#                    '14A;17C',
#                    '16',
#                    '16;16A;116;115',
#                    '16;16A;35',
#                    '17',
#                    '1;5;10',
#                    '1;N1;3;N3;8;N8;9;10;12;12C;101;103;104;106;106C;108;116;118;275',
#                    '31;N31;34;X30',
#                    '44',
#                    '4C;11;S1',
#                    '5',
#                    '7C;N17;8;9;13;15;108;118;261;275;280;U1;NU1;X13',
#                    '8;9;N8']),
#  'royal_cypher': set(['EIIR', 'EVIIR', 'GVIR', 'VR']),
#  'segregated': set(['no']),
#  'service': set(['parts']),
#  'shelter': set(['no', 'yes']),
#  'shop': set(['alcohol',
#               'beauty',
#               'bicycle',
#               'bookmaker',
#               'books',
#               'butcher',
#               'car',
#               'charity',
#               'chemist',
#               'clothes',
#               'convenience',
#               'copyshop',
#               'doityourself',
#               'estate_agent',
#               'gift',
#               'hairdresser',
#               'jewelry',
#               'kitchen',
#               'mobile_phone',
#               'musical_instrument',
#               'newsagent',
#               'optician',
#               'shoes',
#               'stationery',
#               'supermarket',
#               'tanning;beauty',
#               'tattoo',
#               'ticket',
#               'tourist',
#               'yes']),
#  'short_route_ref': set(['16 35', '8/9']),
#  'sign': set(['no_entry']),
#  'smoking': set(['yes']),
#  'source': set(['Bing',
#                 'Bing;gps_survey',
#                 'Bing;local_knowledge',
#                 'Bing;photograph;local_knowledge',
#                 'Bing;survey;yahoo_imagery',
#                 'Local Knowledge',
#                 'NPE',
#                 'OS Opendata Streetview',
#                 'OS_OpenData_StreetView',
#                 'Oxford City Parks Department',
#                 'Yahoo',
#                 'audio+gps_survey;Bing',
#                 'gps_survey',
#                 'gps_survey;Bing',
#                 'gps_survey;inference',
#                 'gps_survey;naptan_import',
#                 'local_knowledge',
#                 'naptan_import',
#                 'naptan_import;photograph',
#                 'naptan_import;survey',
#                 'npe',
#                 'photograph',
#                 'photograph;Bing',
#                 'photograph;gps_survey',
#                 'photograph;local_knowledge',
#                 "reastaunt's website",
#                 'site_survey',
#                 'supplied to OSM from Oxford CAB',
#                 'survery',
#                 'survey',
#                 'www.npemap.org.uk',
#                 'yahoo_imagery',
#                 'yahoo_imagery;inference']),
#  'source:addr': set(['survey']),
#  'source:name': set(['photograph']),
#  'source:position': set(['Bing']),
#  'source:postcode': set(['OS_OpenData_CodePoint']),
#  'source_1': set(['https://www.oxfordshire.gov.uk/cms/sites/default/files/folders/documents/roadsandtransport/traffic/lorryaccessmap.pdf']),
#  'species': set(['Taxus baccata']),
#  'sport': set(['orienteering', 'soccer']),
#  'start_date': set(['24 September 2004']),
#  'substation': set(['distribution']),
#  'support': set(['wall_mounted']),
#  'survey:date': set(['2013-03-01',
#                      '2013-03-02',
#                      '2013-03-09',
#                      '2013-04-06',
#                      '2013-06-08',
#                      '2015-10-27',
#                      '2016-02-04']),
#  'suspened': set(['likely']),
#  'takeaway': set(['only']),
#  'telephone': set(['+44 (0)1865 750299']),
#  'ticket': set(['bus']),
#  'toilets:wheelchair': set(['yes']),
#  'tourism': set(['artwork', 'guest_house', 'hotel', 'information', 'museum']),
#  'traffic_calming': set(['bump',
#                          'chicane',
#                          'choker',
#                          'cushion',
#                          'hump',
#                          'table']),
#  'traffic_sign': set(['UK:610', 'yes']),
#  'traffic_sign:2': set(['UK:610']),
#  'type': set(['conifer', 'lift']),
#  'uk_postcode_centroid': set(['OX33']),
#  'url': set(['http://www.beelinebicycles.co.uk',
#              'http://www.gdcafe.com/website/index.php/Locations/SA',
#              'http://www.tattoo.co.uk/']),
#  'vehicle': set(['no']),
#  'vending': set(['parking_tickets']),
#  'waterway': set(['lock_gate', 'weir']),
#  'website': set(['http://sojooxford.co.uk/',
#                  'http://theroyalsunbegbroke.co.uk/',
#                  'http://www.amtcoffee.co.uk/locations/oxford_st.html',
#                  'http://www.courtneypianos.co.uk/',
#                  'http://www.dpag.ox.ac.uk',
#                  'http://www.jamieoliver.com/italian/restaurants/oxford',
#                  'http://www.magd.ox.ac.uk/wallinger/',
#                  'http://www.missionburritos.co.uk/',
#                  'https://www.iwantgreatcare.org',
#                  'www.modernartoxford.org.uk',
#                  'www.nandos.co.uk',
#                  'www.westcornwallpasty.co.uk']),
#  'wheelchair': set(['limited', 'no', 'on request', 'yes']),
#  'wheelchair:description': set(['Automatic doors. Accessible toilet on main level, other toilets downstairs.']),
#  'wikipedia': set(["en:G&D's",
#                    'en:Modern Art Oxford',
#                    'en:Oxford railway station',
#                    'en:Port Meadow Halt railway station',
#                    'en:Worton (hamlet), Oxfordshire'])}

# %% [markdown]
# ### Unique "k" and "v" values in "way" tags

# %%
way_k_v_dict = audit_k_v(SAMPLE, ["way"])
pprint.pprint(way_k_v_dict)
# Out:
# {'BUFF_DIST': set(['-1.0']),
#  'FIXME': set(['Tag with more precise incline value',
#                'incomplete',
#                'needs a multi-source alignment check',
#                'needs naming',
#                'stub']),
#  'FIXME:nsl': set(['inferred dual-carriageway NSL - remove this tag once verified; if this is a Special Road, remove the source:maxspeed tag and add motorroad=yes',
#                    'inferred dual-carriageway NSL - remove this tag once verified;if this is a Special Road, remove the source:maxspeed tag and add motorroad=yes']),
#  'Fixme': set(['New building here needing a survey',
#                'this a cycle lane if there at all now.']),
#  'Id': set(['0']),
#  'NPLG:USRN:1': set(['29724068']),
#  'ORIG_FID': set(['0', '282']),
#  'abutters': set(['garages', 'industrial', 'residential', 'retail']),
#  'access': set(['customer',
#                 'customers',
#                 'destination',
#                 'no',
#                 'permissive',
#                 'private',
#                 'public',
#                 'steps',
#                 'unknown',
#                 'yes']),
#  'access:disabled': set(['yes']),
#  'access:hgv': set(['delivery']),
#  'addr:city': set(['<different>',
#                    'Bergheim',
#                    'Besko',
#                    'Genthin',
#                    'Headington, Oxfordshire',
#                    'Jardee',
#                    'Lexington',
#                    'Neuss',
#                    'Oxford',
#                    'Puconci',
#                    'Saint-Julien-des-Landes',
#                    'San Sebastian',
#                    'Villa Nueva',
#                    'Virginia Beach',
#                    'Woodbridge',
#                    u'Zuj\u016bnai']),
#  'addr:city:simc': set(['0440325']),
#  'addr:country': set(['DE', 'GB', 'US']),
#  'addr:housename': set(['25',
#                         '33',
#                         'BLOCK J',
#                         'BLOCK V',
#                         'Barnwood Ho',
#                         'Bishops Gate',
#                         'CANTELOUP HOUSE',
#                         'Chestnut Place',
#                         'Damson House',
#                         'Edith Road Workshops',
#                         'Fitzgerald House',
#                         'Flat 11',
#                         'G371',
#                         'Hayward House',
#                         'Jubilee House',
#                         'Knowle Cottage',
#                         'Mary Powell House',
#                         'Matthew Arnold School',
#                         'Norham End',
#                         'Ouryard',
#                         'Pembers',
#                         'Sandswood Farm',
#                         'St Barnabas Vicarage',
#                         "St Luke's Church",
#                         'The Byre',
#                         'The Grange',
#                         'The Old Barn',
#                         'The Old School',
#                         'The Old School Hall',
#                         'Tinsley Building',
#                         'Uplands',
#                         'Valuation Office Agency',
#                         'Willow Cottage',
#                         'Yellow Wood']),
#  'addr:housenumber': set(['1',
#                           '1 & 2',
#                           '1,2',
#                           '1-4',
#                           '10',
#                           '10,12',
#                           '10-52',
#                           '100',
#                           '101',
#                           '1017',
#                           '102',
#                           '103',
#                           '104a',
#                           '105',
#                           '106',
#                           '107',
#                           '108',
#                           '109',
#                           '11',
#                           '111',
#                           '112',
#                           '113',
#                           '114',
#                           '115',
#                           '119',
#                           '11A',
#                           '11a',
#                           '12',
#                           '121',
#                           '121-135',
#                           '122',
#                           '123',
#                           '124',
#                           '127',
#                           '129',
#                           '13',
#                           '132',
#                           '132-133',
#                           '1320',
#                           '134',
#                           '135',
#                           '136a',
#                           '137',
#                           '139',
#                           '14',
#                           '14-18',
#                           '1404',
#                           '1406',
#                           '142',
#                           '142-144',
#                           '142-155',
#                           '145',
#                           '14a',
#                           '15',
#                           '151',
#                           '152',
#                           '153',
#                           '16',
#                           '160',
#                           '165',
#                           '167',
#                           '17',
#                           '17-18',
#                           '17-27',
#                           '172',
#                           '179',
#                           '18',
#                           '182',
#                           '186',
#                           '186-212',
#                           '188',
#                           '189',
#                           '18a',
#                           '19',
#                           '19-24',
#                           '192',
#                           '1;2',
#                           '1A',
#                           '2',
#                           '2-7',
#                           '20',
#                           '20,18',
#                           '20,22',
#                           '20,49',
#                           '201-207',
#                           '203',
#                           '207',
#                           '208',
#                           '21',
#                           '21 - 24',
#                           '212',
#                           '22',
#                           '2213',
#                           '2245',
#                           '23',
#                           '23,24',
#                           '232',
#                           '237',
#                           '239',
#                           '24',
#                           '240',
#                           '2444',
#                           '25',
#                           '25,27,29',
#                           '2504',
#                           '254',
#                           '259',
#                           '26',
#                           '27',
#                           '27,28',
#                           '273,275',
#                           '28',
#                           '29',
#                           '292',
#                           '2A',
#                           '2a',
#                           '2h',
#                           '3',
#                           '3, 5',
#                           '30',
#                           '30,32',
#                           '303',
#                           '305',
#                           '31',
#                           '311',
#                           '32',
#                           '32-36',
#                           '3209',
#                           '321',
#                           '33',
#                           '33,35',
#                           '3324',
#                           '34',
#                           '34-36',
#                           '3404',
#                           '3437',
#                           '3475',
#                           '34a',
#                           '35',
#                           '3508',
#                           '352',
#                           '354',
#                           '3545',
#                           '36',
#                           '366',
#                           '37',
#                           '37,38',
#                           '38',
#                           '38,40',
#                           '380',
#                           '39',
#                           '39,40',
#                           '39-41',
#                           '39a',
#                           '3B',
#                           '3a;3b',
#                           '4',
#                           '4,6',
#                           '40',
#                           '400',
#                           '404',
#                           '406',
#                           '41',
#                           '41a',
#                           '42',
#                           '43',
#                           '43,45,47',
#                           '434',
#                           '44',
#                           '44-50',
#                           '44-60',
#                           '4400',
#                           '4468',
#                           '45',
#                           '46',
#                           '46,48',
#                           '47',
#                           '47-48',
#                           '47a',
#                           '48',
#                           '489',
#                           '49',
#                           '49,50',
#                           '49-51',
#                           '4943',
#                           '495',
#                           '5',
#                           '5-6',
#                           '50',
#                           '51',
#                           '51-54',
#                           '52',
#                           '53',
#                           '54',
#                           '54,56',
#                           '54-55',
#                           '55',
#                           '55, 65',
#                           '5510',
#                           '56',
#                           '57',
#                           '58',
#                           '58,60',
#                           '59',
#                           '6',
#                           '60',
#                           '60,62',
#                           '61',
#                           '62',
#                           '62,64',
#                           '63',
#                           '64',
#                           '64-64a',
#                           '641',
#                           '65',
#                           '657',
#                           '66',
#                           '67',
#                           '67,68',
#                           '68',
#                           '68,69',
#                           '68-69',
#                           '69',
#                           '7',
#                           '7,8',
#                           '7-19',
#                           '70',
#                           '70,72',
#                           '71',
#                           '71A',
#                           '72',
#                           '73',
#                           '74',
#                           '75',
#                           '75, 77',
#                           '76',
#                           '763',
#                           '78',
#                           '79',
#                           '79A',
#                           '8',
#                           '80',
#                           '807',
#                           '81',
#                           '813',
#                           '82,84',
#                           '83',
#                           '83,85',
#                           '84',
#                           '85',
#                           '85-90',
#                           '86',
#                           '86-88',
#                           '87',
#                           '88',
#                           '89',
#                           '9',
#                           '9,10',
#                           '9-14',
#                           '90',
#                           '90-94',
#                           '91',
#                           '92',
#                           '93',
#                           '94',
#                           '95',
#                           '96',
#                           '97',
#                           '971',
#                           '98',
#                           '99',
#                           '99,101',
#                           'G301',
#                           'G352',
#                           'G366',
#                           'G413',
#                           'Greentiles',
#                           'William Baker House']),
#  'addr:inclusion': set(['potential']),
#  'addr:interpolation': set(['all', 'even', 'odd']),
#  'addr:place': set([u'Niederau\xdfem', u'Stara Wie\u015b']),
#  'addr:postcode': set(['22193',
#                        '23451',
#                        '23452',
#                        '23454',
#                        '34-600',
#                        '38-524',
#                        '39307',
#                        '41462',
#                        '50129',
#                        '6258',
#                        '85150',
#                        '9201',
#                        'Cotswold Road',
#                        'OX1 1 HP',
#                        'OX1 1EP',
#                        'OX1 2HP',
#                        'OX1 2JG',
#                        'OX1 3AE',
#                        'OX1 3AF',
#                        'OX1 3DU',
#                        'OX1 3DX',
#                        'OX1 3DY',
#                        'OX1 3DZ',
#                        'OX1 3LU',
#                        'OX1 3LW',
#                        'OX1 3SE',
#                        'OX1 4EH',
#                        'OX1 4UT',
#                        'OX2 0AL',
#                        'OX2 0BS',
#                        'OX2 0ED',
#                        'OX2 0HA',
#                        'OX2 0LF',
#                        'OX2 0XJ',
#                        'OX2 6AE',
#                        'OX2 6BG',
#                        'OX2 6EA',
#                        'OX2 6EB',
#                        'OX2 6EG',
#                        'OX2 6EH',
#                        'OX2 6HL',
#                        'OX2 6HT',
#                        'OX2 6HW',
#                        'OX2 6HX',
#                        'OX2 6HY',
#                        'OX2 6HZ',
#                        'OX2 6JA',
#                        'OX2 6JB',
#                        'OX2 6JE',
#                        'OX2 6JG',
#                        'OX2 6JQ',
#                        'OX2 6NB',
#                        'OX2 6NN',
#                        'OX2 6PS',
#                        'OX2 6QH',
#                        'OX2 6RA',
#                        'OX2 6RB',
#                        'OX2 6RD',
#                        'OX2 6RF',
#                        'OX2 6RH',
#                        'OX2 6RJ',
#                        'OX2 6RL',
#                        'OX2 6RN',
#                        'OX2 6RP',
#                        'OX2 6RQ',
#                        'OX2 6RR',
#                        'OX2 6RS',
#                        'OX2 6RT',
#                        'OX2 6RU',
#                        'OX2 6RW',
#                        'OX2 6RX',
#                        'OX2 6SF',
#                        'OX2 6SJ',
#                        'OX2 6SN',
#                        'OX2 6SQ',
#                        'OX2 6SY',
#                        'OX2 6UT',
#                        'OX2 6UY',
#                        'OX2 7BY',
#                        'OX2 9JE',
#                        'OX2 9LH',
#                        'OX26LE',
#                        'OX29 4HR',
#                        'OX29 8DJ',
#                        'OX3 0BY',
#                        'OX3 0DH',
#                        'OX3 0EE',
#                        'OX3 0JQ',
#                        'OX3 0LY',
#                        'OX3 7BX',
#                        'OX3 7XB',
#                        'OX3 7XE',
#                        'OX3 7XF',
#                        'OX3 7XG',
#                        'OX3 7XH',
#                        'OX3 7XQ',
#                        'OX3 8AN',
#                        'OX3 8DH',
#                        'OX3 8FX',
#                        'OX3 8LH',
#                        'OX3 9AB',
#                        'OX3 9AE',
#                        'OX3 9AJ',
#                        'OX3 9AX',
#                        'OX3 9BU',
#                        'OX3 9BX',
#                        'OX3 9BY',
#                        'OX3 9DA',
#                        'OX3 9DL',
#                        'OX3 9DN',
#                        'OX3 9DP',
#                        'OX3 9DW',
#                        'OX3 9HN',
#                        'OX3 9HP',
#                        'OX3 9HT',
#                        'OX3 9HW',
#                        'OX3 9HZ',
#                        'OX3 9PU',
#                        'OX3 9PZ',
#                        'OX3 9QS',
#                        'OX3 9QW',
#                        'OX3 9QY',
#                        'OX3 9RB',
#                        'OX3 9RD',
#                        'OX3 9RE',
#                        'OX3 9RF',
#                        'OX3 9RG',
#                        'OX3 9RQ',
#                        'OX3 9RT',
#                        'OX4 1AH',
#                        'OX4 1AR',
#                        'OX4 1DG',
#                        'OX4 1DQ',
#                        'OX4 1JT',
#                        'OX4 1NE',
#                        'OX4 1PY',
#                        'OX4 1RB',
#                        'OX4 1RE',
#                        'OX4 1RW',
#                        'OX4 2BB/2BQ',
#                        'OX4 2BG',
#                        'OX4 2BQ',
#                        'OX4 2DS',
#                        'OX4 2DT',
#                        'OX4 2DU',
#                        'OX4 2DZ',
#                        'OX4 2ED',
#                        'OX4 2EE',
#                        'OX4 2EN',
#                        'OX4 2EP',
#                        'OX4 2ER',
#                        'OX4 2ES',
#                        'OX4 2ET',
#                        'OX4 2EU',
#                        'OX4 2EZ',
#                        'OX4 2HB',
#                        'OX4 2HD',
#                        'OX4 2HE',
#                        'OX4 2HH',
#                        'OX4 2HS',
#                        'OX4 2HT',
#                        'OX4 2JT',
#                        'OX4 2LG',
#                        'OX4 2LH',
#                        'OX4 2NZ',
#                        'OX4 2PB',
#                        'OX4 2RU',
#                        'OX4 2RX',
#                        'OX4 3EG',
#                        'OX4 3EH',
#                        'OX4 3EJ',
#                        'OX4 3EL',
#                        'OX4 3EN',
#                        'OX4 3EP',
#                        'OX4 3EQ',
#                        'OX4 3ER',
#                        'OX4 3EW',
#                        'OX4 3HA',
#                        'OX4 3HB',
#                        'OX4 3HD',
#                        'OX4 3HH',
#                        'OX4 3HJ',
#                        'OX4 3HL',
#                        'OX4 3HN',
#                        'OX4 3HT',
#                        'OX4 3HU',
#                        'OX4 3HW',
#                        'OX4 3HX',
#                        'OX4 3HY',
#                        'OX4 3HZ',
#                        'OX4 3JA',
#                        'OX4 3JR',
#                        'OX4 3JS',
#                        'OX4 3JT',
#                        'OX4 3JU',
#                        'OX4 3JY',
#                        'OX4 3LA',
#                        'OX4 3LB',
#                        'OX4 3LD',
#                        'OX4 3LE',
#                        'OX4 3LF',
#                        'OX4 3LG',
#                        'OX4 3LH',
#                        'OX4 3LJ',
#                        'OX4 3LL',
#                        'OX4 3LN',
#                        'OX4 3LQ',
#                        'OX4 3LW',
#                        'OX4 3ND',
#                        'OX4 3NH',
#                        'OX4 3NJ',
#                        'OX4 3NL',
#                        'OX4 3NN',
#                        'OX4 3NP',
#                        'OX4 3NR',
#                        'OX4 3NS',
#                        'OX4 3NT',
#                        'OX4 3NU',
#                        'OX4 3NW',
#                        'OX4 3NX',
#                        'OX4 3NY',
#                        'OX4 3NZ',
#                        'OX4 3PA',
#                        'OX4 3PB',
#                        'OX4 3PD',
#                        'OX4 3PE',
#                        'OX4 3PF',
#                        'OX4 3PG',
#                        'OX4 3PH',
#                        'OX4 3PL',
#                        'OX4 3PQ',
#                        'OX4 3QA',
#                        'OX4 3QB',
#                        'OX4 3QF',
#                        'OX4 3QG',
#                        'OX4 3QH',
#                        'OX4 3QJ',
#                        'OX4 3QL',
#                        'OX4 3QP',
#                        'OX4 3QQ',
#                        'OX4 3QR',
#                        'OX4 3QS',
#                        'OX4 3QT',
#                        'OX4 3QU',
#                        'OX4 3QY',
#                        'OX4 3QZ',
#                        'OX4 3RA',
#                        'OX4 3RD',
#                        'OX4 3RF',
#                        'OX4 3RG',
#                        'OX4 3RH',
#                        'OX4 3RJ',
#                        'OX4 3RL',
#                        'OX4 3RN',
#                        'OX4 3RZ',
#                        'OX4 3SA',
#                        'OX4 3SE',
#                        'OX4 3SF',
#                        'OX4 3SG',
#                        'OX4 3SH',
#                        'OX4 3SJ',
#                        'OX4 3SL',
#                        'OX4 3SN',
#                        'OX4 3SQ',
#                        'OX4 3SR',
#                        'OX4 3SS',
#                        'OX4 3ST',
#                        'OX4 3SU',
#                        'OX4 3SW',
#                        'OX4 3SX',
#                        'OX4 3TA',
#                        'OX4 3TH',
#                        'OX4 3TJ',
#                        'OX4 3TL',
#                        'OX4 3TN',
#                        'OX4 3TR',
#                        'OX4 3TS',
#                        'OX4 3TT',
#                        'OX4 3TU',
#                        'OX4 3TW',
#                        'OX4 3TX',
#                        'OX4 3TY',
#                        'OX4 3TZ',
#                        'OX4 3UA',
#                        'OX4 3UB',
#                        'OX4 3UD',
#                        'OX4 3UE',
#                        'OX4 3UJ',
#                        'OX4 3UU',
#                        'OX4 3YJ',
#                        'OX4 4AT',
#                        'OX4 4DS',
#                        'OX4 4HN',
#                        'OX4 4HS',
#                        'OX4 4JP',
#                        'OX4 4JR',
#                        'OX4 4QP',
#                        'OX4 4QS',
#                        'OX5 1DB',
#                        'OX5 1RX']),
#  'addr:state': set(['KY', 'VA']),
#  'addr:street': set(['1a Avenida Zona 2',
#                      '3a Calle',
#                      'Abbey Street',
#                      'Abingdon Road',
#                      'Acland Close',
#                      'Addison Drive',
#                      'Aldershot Drive',
#                      'Alfred Street',
#                      'Amory Close',
#                      'Appleton Road',
#                      "Arnold's Way",
#                      'Arnolds Way',
#                      'Ashcroft Close',
#                      'Atlantis Drive',
#                      'Avenue 2',
#                      'Avenue 4',
#                      'Bailey Road',
#                      'Banbury Road',
#                      'Barn Close',
#                      'Barns Road',
#                      'Bartholomew Road',
#                      'Bartlemas Close',
#                      'Beauchamp Lane',
#                      'Beaumont Street',
#                      'Belbroughton Road',
#                      'Benouville Close',
#                      'Benson Place',
#                      'Bertie Place',
#                      'Bertie Road',
#                      'Bevington Road',
#                      'Big Leaf Circle',
#                      'Birdneck Road',
#                      'Birkheide',
#                      'Bodley Road',
#                      'Boswell Road',
#                      'Botley Road',
#                      'Bradmore Road',
#                      'Brasenose Driftway',
#                      'Briarwood Point',
#                      'Bridle Court',
#                      'Brightleaf Court',
#                      'Broad Street',
#                      'Browns Close',
#                      'Bullingdon Road',
#                      'Burgan Close',
#                      'Burrows Close',
#                      'Bushy Close',
#                      'Calle Valencia',
#                      'Campbell Road',
#                      'Canning Crescent',
#                      'Cardinal Close',
#                      'Carrie Court',
#                      'Chadlington Road',
#                      'Channyberup Road',
#                      'Charlbury Road',
#                      'Chatham Road',
#                      'Chawley Lane',
#                      'Cherwell Drive',
#                      'Cholsey Close',
#                      u'Christian-Schaurte-Stra\xdfe',
#                      'Church Cowley Road',
#                      'Church Hill Road',
#                      'Church Walk',
#                      'Cleveland Drive',
#                      'Clive Road',
#                      'Clover Close',
#                      'Cochran Road',
#                      'Colegrove Down',
#                      'Compass Close',
#                      'Copse Lane',
#                      'Cornmarket Street',
#                      'Cornwallis Close',
#                      'Cornwallis Road',
#                      'Corunna Crescent',
#                      'Cowley Road',
#                      'Cranmer Road',
#                      'Crescent Road',
#                      'Crowell Road',
#                      'Cumnor Hill',
#                      'Deanfield Road',
#                      'Delamare Way',
#                      'Demesne Furze',
#                      'Denmark Street',
#                      'Divinity Road',
#                      'Dodgson Road',
#                      'Dora Carr Close',
#                      'Downside Road',
#                      'East Field Close',
#                      'Eastern Avenue',
#                      'Edgeway Road',
#                      'Edmund Road',
#                      'Eleanor Close',
#                      'Ellemoor Lane',
#                      'Eynsham Road',
#                      'Fairfax Mews',
#                      'Fairfax Road',
#                      'Fairlie Road',
#                      'Fanshawe Place',
#                      'Faringdon Rd',
#                      'Faringdon Road',
#                      'Farmington Road',
#                      'Farndon Road',
#                      'Fern Hill Road',
#                      'Ferry Hinksey Road',
#                      'Ferry Road',
#                      'Fletcher Road',
#                      'Florence Park Road',
#                      'Fogwell Road',
#                      'Forest Cove Lane',
#                      'Forster Lane',
#                      'Fox Crescent',
#                      'Frederick Road',
#                      'Frenchay Road',
#                      'Gaisford Road',
#                      'Garford Road',
#                      'Garsington Road',
#                      'Gerard Place',
#                      'Glebe Rd',
#                      'Glebe Street',
#                      'Halls Close',
#                      'Hampden Road',
#                      'Havelock Road',
#                      'Hendred Street',
#                      'Herschel Crescent',
#                      "Hid's Copse Road",
#                      'High St',
#                      'Hill Top Road',
#                      'Hillsborough Close',
#                      'Hillsborough Road',
#                      'Hockmore Street',
#                      'Hollow Way',
#                      'Holywell Street',
#                      'Honey Locust Way',
#                      'Horspath Road',
#                      'Hugh Allen Crescent',
#                      'Hume Bedford Pike',
#                      'Hundred Acres Close',
#                      'Hunter Close',
#                      'Hurst Lane',
#                      'Hutchcomb Farm Close',
#                      'Hyannisport Drive',
#                      'Ice House Way',
#                      'Iffley Road',
#                      'Iffley Turn',
#                      'Inott Furze',
#                      "Jack Straw's Lane",
#                      'James Street',
#                      'James Wolfe Road',
#                      'John A Andrew Street',
#                      'John Smith Drive',
#                      'JohnSmith Drive',
#                      'Kames Close',
#                      'Kelburne Road',
#                      'Kenilworth Avenue',
#                      'Kersington Crescent',
#                      'Kimmeridge Road',
#                      'Kingston Road',
#                      'Kirby Place',
#                      'Knolles Road',
#                      'Lathbury Road',
#                      'Laurenhaven Court',
#                      'Lawrence Road',
#                      'Leckford Place',
#                      'Lemerje',
#                      'Leys Road',
#                      'Liddell Road',
#                      'Lime Road',
#                      'Lincoln Road',
#                      'Linton Road',
#                      'Little Clarendon Street',
#                      'Littlehay Road',
#                      'Littlemore Road',
#                      'Lockheart Crescent',
#                      'Lohweg',
#                      'Londonderry Drive',
#                      'Long Close',
#                      'Long Lane',
#                      'Longworth Road',
#                      'Lytton Road',
#                      'Magdalen Road',
#                      'Magdalen Street',
#                      'Maidcroft Road',
#                      'Margaret Road',
#                      'Marsh Road',
#                      'Marston Road',
#                      'Mayfair Road',
#                      'Mcdowell Road',
#                      'Mediterranean Avenue',
#                      'Merton Street',
#                      'Meyseys Close',
#                      'Middle Plantation Quay',
#                      'Mileway Gardens',
#                      'Mill Street',
#                      'Monmouth Road',
#                      'Moody Road',
#                      'Morrell Avenue',
#                      'Museum Road',
#                      u'M\xfchlenfeld',
#                      'Napier Road',
#                      'New College Lane',
#                      'Newman Road',
#                      'Norham Gardens',
#                      'Norham Road',
#                      'Normandy Crescent',
#                      "Norrey's Road",
#                      'Norreys Road',
#                      'North Parade Avenue',
#                      'Northampton Road',
#                      'Northmoor Road',
#                      'Oakwood Way',
#                      'Observatory Street',
#                      'Oliver Road',
#                      'Orchard Grass Road',
#                      'Orchard Road',
#                      'Orchard Way',
#                      'Oswestry Road',
#                      'Outram Road',
#                      'Owlington Close',
#                      'Oxford Rd',
#                      'Oxford Road',
#                      'Park End Street',
#                      'Park Town',
#                      'Peel Place',
#                      'Perrin Street',
#                      'Phipps Road',
#                      'Pinnocks Way',
#                      'Plantation Road',
#                      'Plymouth Drive',
#                      'Potomac Drive',
#                      'Pottle Close',
#                      'Prestwich Place',
#                      'Prichard Road',
#                      'Pulker Close',
#                      'Pullens Lane',
#                      'Pusey Lane',
#                      'Quarry School Place',
#                      'Queen Elizabeth Drive',
#                      'Rahere Road',
#                      'Rawlinson Road',
#                      'Rectory Road',
#                      'Reliance Way',
#                      'Reliuance Way',
#                      'Richmond Road',
#                      'Riely Close',
#                      'Riverside Road',
#                      'Robsart Place',
#                      'Roosevelt Drive',
#                      'Rose Court',
#                      'Rose Hill',
#                      'Rue du Moulin',
#                      'Rymers Lane',
#                      'Saddle Club Way',
#                      "Saint Bernard's Road",
#                      "Saint Giles'",
#                      "Saint Margaret's Road",
#                      u'Scharmbecker Dorfstra\xdfe',
#                      'Scholar Place',
#                      'Seven Sisters Way',
#                      'Shady Springs Court',
#                      'Sheldon Way',
#                      'Sheraton Drive',
#                      'Shore View Court',
#                      'Silkdale Close',
#                      'Skene Close',
#                      'Songers Close',
#                      'South Hanover Avenue',
#                      'Southfield Park',
#                      'St Barnabas Street',
#                      "St Christopher's Place",
#                      'St Clements',
#                      'St Clements Street',
#                      "St Ebba's Close",
#                      'St Giles',
#                      "St Giles'",
#                      'St Lukes Road',
#                      "St Margaret's Road",
#                      "St Mary's Road",
#                      'St Omer Road',
#                      'Staverton Road',
#                      'Stile Road',
#                      "Stimpson's Close",
#                      'Stockmore Street',
#                      'Stone Close',
#                      'Sunningdale Drive',
#                      'Sunningwell Road',
#                      'Temple Road',
#                      'Temple Street',
#                      'Terrace Avenue',
#                      'The Glebe',
#                      'The Grates',
#                      'The Parade',
#                      'The Park',
#                      'The Roundway',
#                      'The Slade',
#                      'The Winnyards',
#                      'Third Acre Rise',
#                      'Trevor Place',
#                      'Turnpike Road',
#                      'Upper Meadow',
#                      "Van Dieman's Lane",
#                      'Walton Crescent',
#                      'Walton Street',
#                      'Weirs Lane',
#                      'Wellington Square',
#                      'West Lane',
#                      'Westbury Crescent',
#                      'Westwood Circle',
#                      'Weymann Terrace',
#                      'Wharton Road',
#                      'Wilkins Road',
#                      'William Street',
#                      'Winthrop Drive',
#                      'Woodfield',
#                      'Woodstock Road',
#                      'Wootten Drive',
#                      'Worcester Street',
#                      'Wytham Street',
#                      'Zielona',
#                      u'\u017dalioji g.',
#                      u'\u0443\u043b\u0438\u0446\u0430 \u0421\u0438\u043d\u0438\u0447\u043a\u0438\u043d\u0430']),
#  'addr:substreet': set(['Wingfield Court']),
#  'addr:substreet1': set(['Monard Terrace', 'Walters Row']),
#  'addr:substreet:1': set(['York Place']),
#  'addr:substreet:2': set(['Anchor Court']),
#  'addr:unit': set(['201', 'SU8']),
#  'adjacent': set(['primary', 'semi', 'trunk', 'yes']),
#  'admin_level': set(['10', '8']),
#  'aeroway': set(['taxiway']),
#  'alt_name': set(['65-67 St Giles',
#                   'Abbots Wood (West)',
#                   'Ahlul Bayt Centre',
#                   'Blood Donor Suite',
#                   'Cherwell Bridge',
#                   'Church Lane, Old Marston',
#                   'Cloisters Garden',
#                   'Hilltop Road',
#                   'Hillview Road',
#                   'Kendal Crescent',
#                   'London Place',
#                   'Louie Memorial (Upper) Playing Field',
#                   'Magdalen Street West',
#                   'Mesopotamia Walk',
#                   'New Copse',
#                   'OCDEM 2',
#                   'Powell & Moya',
#                   'Ramsey Road',
#                   u'Sa\xefd Business School (Phase 2)',
#                   'School Avenue',
#                   'Seacourt Stream',
#                   'St Aldates',
#                   "St Clement's Street",
#                   'St Peters Road',
#                   'The Broadway',
#                   'The High',
#                   'Warlands',
#                   'Woodins Way']),
#  'amenity': set(['Wellbeing_service',
#                  'ballot_box',
#                  'bank',
#                  'bar',
#                  'bench',
#                  'bicycle_parking',
#                  'biergarten',
#                  'binstore',
#                  'cafe',
#                  'childcare',
#                  'college',
#                  'community_centre',
#                  'compound',
#                  'fast_food',
#                  'grave_yard',
#                  'hospice',
#                  'hospital',
#                  'kindergarten',
#                  'library',
#                  'parking',
#                  'parking_space',
#                  'place_of_worship',
#                  'pub',
#                  'public_building',
#                  'restaurant',
#                  'school',
#                  'social_facility',
#                  'theatre',
#                  'toilets',
#                  'university',
#                  'veterinary']),
#  'area': set(['yes']),
#  'area:highway': set(['footway',
#                       'pedestrian',
#                       'residential',
#                       'service',
#                       'steps',
#                       'unclassified']),
#  'atm': set(['yes']),
#  'attribution': set(['BLM']),
#  'barrier': set(['block',
#                  'bollard',
#                  'central_reservation',
#                  'fence',
#                  'garden_wall',
#                  'gate',
#                  'hand_rail_fence',
#                  'hedge',
#                  'wall',
#                  'wire_fence',
#                  'yes']),
#  'basin': set(['retention']),
#  'bicycle': set(['designated',
#                  'dismount',
#                  'no',
#                  'permissive',
#                  'private',
#                  'tolerated',
#                  'yes']),
#  'bicycle:no:times': set(['10:00-18:00']),
#  'bicycle:note': set(['difficult_barrier']),
#  'bicycle_parking': set(['room', 'shed', 'stands']),
#  'boat': set(['no', 'yes']),
#  'boundary': set(['administrative', 'national_park', 'protected_area']),
#  'bridge': set(['swing', 'viaduct', 'yes']),
#  'bridge_name': set(['St Edwards Lift Bridge',
#                      'Stratfield Brake (footbridge)']),
#  'bridge_over': set(['highway']),
#  'bridge_ref': set(['229', '238']),
#  'building': set(['Fire Escape',
#                   'apartments',
#                   'bunker',
#                   'bus_station',
#                   'central_goverment',
#                   'church',
#                   'college',
#                   'commercial',
#                   'dormitory',
#                   'farm',
#                   'garage',
#                   'garages',
#                   'grandstand',
#                   'greenhouse',
#                   'hall',
#                   'hospital',
#                   'house',
#                   'hut',
#                   'industrial',
#                   'mall',
#                   'office',
#                   'offices',
#                   'place_of_worship',
#                   'police',
#                   'pub',
#                   'remodelled_church',
#                   'residential',
#                   'retail',
#                   'roof',
#                   'school',
#                   'shed',
#                   'shop',
#                   'stable',
#                   'static_caravan',
#                   'station',
#                   'swimming_pool',
#                   'terrace',
#                   'tower',
#                   'university',
#                   'university accommodation',
#                   'workshop',
#                   'yes']),
#  'building:levels': set(['1', '2', '3', '4']),
#  'building:levels:underground': set(['1']),
#  'building:material': set(['brick', 'stone']),
#  'building:part': set(['spire_tower', 'yes']),
#  'building:roof': set(['flat']),
#  'building:ruian:type': set(['19']),
#  'building:type': set(['Complex', 'residential']),
#  'building:use': set(['accommodation',
#                       'garages',
#                       'hospital',
#                       'office',
#                       'parking',
#                       'residential']),
#  'bus': set(['yes']),
#  'bus:lanes:forward': set(['1']),
#  'busway:left': set(['lane']),
#  'cables': set(['3', '6']),
#  'capacity': set(['1',
#                   '11',
#                   '110',
#                   '12',
#                   '130',
#                   '15',
#                   '2',
#                   '3',
#                   '30',
#                   '4',
#                   '60',
#                   '70',
#                   '8',
#                   '9']),
#  'capacity:disabled': set(['1', '3', '5', '6']),
#  'capacity:private': set(['1']),
#  'circuits': set(['1', '2']),
#  'comment': set(['temporary for works']),
#  'construction': set(['footway', 'primary', 'residential', 'steps', 'yes']),
#  'contact:phone': set(['+441865243361']),
#  'contact:website': set(['http://stthomasdaynursery.org.uk/']),
#  'continental_geometry': set(['yes']),
#  'converted_by': set(['mikes']),
#  'covered': set(['no', 'yes']),
#  'created_by': set(['JOSM',
#                     'Merkaartor 0.13',
#                     'Potlatch 0.10f',
#                     'Potlatch 0.5d',
#                     'Potlatch 0.6a',
#                     'Potlatch 0.6c',
#                     'Potlatch 0.8a',
#                     'Potlatch 0.8c',
#                     'Potlatch 0.9a',
#                     'Potlatch 0.9c',
#                     'Potlatch alpha',
#                     'osm2go v0.6-7',
#                     'osm2go v0.6-8',
#                     'osm2go v0.6.13-maemo1',
#                     'osm2go v0.6.14']),
#  'crossing': set(['island', 'traffic_signals', 'uncontrolled', 'unmarked']),
#  'crossing_ref': set(['pelican', 'toucan', 'zebra']),
#  'cuisine': set(['burger',
#                  'chinese',
#                  'coffee_shop',
#                  'lebanese',
#                  'sandwich',
#                  'seafood']),
#  'cutting': set(['yes']),
#  'cyclability': set(['3']),
#  'cycleway': set(['crossing',
#                   'lane',
#                   'no',
#                   'opposite',
#                   'shared_lane',
#                   'track']),
#  'cycleway:hazard': set(['narrow']),
#  'cycleway:left': set(['lane', 'opposite_track', 'share_busway', 'track']),
#  'cycleway:left:priority': set(['yes']),
#  'cycleway:left:width': set(['1.2', '1.25', '1.75', '3']),
#  'cycleway:note': set(['overall priority as good as for cars']),
#  'cycleway:otherside:width': set(['1.75']),
#  'cycleway:right': set(['lane', 'opposite_track', 'service', 'share_busway']),
#  'cycleway:right:priority': set(['no']),
#  'cycleway:right:width': set(['1.25', '1.75', '3']),
#  'damage:colision': set(['yea']),
#  'denomination': set(['anglican',
#                       'catholic',
#                       'christ_scientist',
#                       'church_of_england',
#                       'evangelical',
#                       'mormon',
#                       'shia',
#                       'united_reformed']),
#  'description': set(['Other land',
#                      'Plastic toys,Farm  and zoo figures & systems, & Playmobil',
#                      u'\u041c\u0430\u0440\u043a\u043e\u0432\u0441\u043a\u043e\u0435 - \u041a\u0430\u0440\u0442\u044b\u043d\u0438\u0447\u0438']),
#  'designation': set(['byway_open_to_all_traffic',
#                      'permissive_bridleway',
#                      'primary',
#                      'public_bridleway',
#                      'public_footpath',
#                      'public_footpath;permissive_bridleway',
#                      'restricted_byway']),
#  'direction': set(['clockwise']),
#  'disabled': set(['yes']),
#  'dismantled': set(['railway']),
#  'distribute_to': set(['local properties']),
#  'disused': set(['yes']),
#  'disused:amenity': set(['pub']),
#  'dog': set(['leashed']),
#  'ele': set(['262']),
#  'electrified': set(['contact_line', 'no']),
#  'embankment': set(['yes']),
#  'entrance': set(['main']),
#  'est_width': set(['1', '1.5', '1.75', '2.5']),
#  'fax': set(['+44-1865-241336']),
#  'fed_from': set(['FIX_ME']),
#  'fee': set(['mixed', 'no', 'yes']),
#  'fence_type': set(['wood']),
#  'fixme': set(['Capacity approximated from Bing',
#                u'Duplicate address in import (zdublowany adres w promieniu 100 metr\xf3w)',
#                'Geometry very approx.',
#                'do these steps exist? gates locked',
#                'find roof tags for thislater too',
#                'find utility details',
#                'incomplete',
#                'needs a precision check',
#                'not on Streetview??',
#                'resurvey',
#                'street name',
#                'street name - no sign on the ground!',
#                'stub']),
#  'floor': set(['1']),
#  'food': set(['yes']),
#  'foot': set(['designated',
#               'emergancy',
#               'no',
#               'permissive',
#               'private',
#               'yes']),
#  'footway': set(['crossing', 'no', 'sidewalk']),
#  'footway:left': set(['yes']),
#  'frequency': set(['0', '50']),
#  'frequency:4A': set(['3']),
#  'garden': set(['residential', 'yes']),
#  'garden:type': set(['pub']),
#  'gauge': set(['1435']),
#  'gnis:county_id': set(['089']),
#  'gnis:created': set(['01/23/1980']),
#  'gnis:edited': set(['08/15/2007']),
#  'gnis:feature_id': set(['976116']),
#  'gnis:state_id': set(['36']),
#  'goods': set(['no']),
#  'height': set(["19'",
#                 '23',
#                 "23'",
#                 "24'",
#                 "26'",
#                 "28'",
#                 "30'",
#                 "32'",
#                 "33'",
#                 "34'",
#                 "35'",
#                 "36'",
#                 "39'",
#                 "49'"]),
#  'hgv': set(['designated', 'destination', 'no']),
#  'highway': set(['bridleway',
#                  'construction',
#                  'corridor',
#                  'cycleway',
#                  'footway',
#                  'living_street',
#                  'manoeuvring_forecourt',
#                  'path',
#                  'pedestrian',
#                  'primary',
#                  'primary_link',
#                  'residential',
#                  'road',
#                  'secondary',
#                  'secondary_link',
#                  'service',
#                  'steps',
#                  'tertiary',
#                  'tertiary_link',
#                  'track',
#                  'trunk',
#                  'trunk_link',
#                  'unclassified']),
#  'highways_agency:area': set(['3']),
#  'historic': set(['castle', 'motte']),
#  'history': set(['Retrieved from v1']),
#  'horse': set(['designated', 'permissive', 'yes']),
#  'incline': set(['up']),
#  'indoor': set(['bay_window',
#                 'corridor',
#                 'door',
#                 'dweling',
#                 'dwelling',
#                 'entrance',
#                 'funiture',
#                 'liftshaft',
#                 'liftwell',
#                 'room',
#                 'shop:part',
#                 'stairwell',
#                 'yes']),
#  'indoor_1': set(['yes']),
#  'infomation:1': set(['A new temporary car park opened in Marston Road on Monday 8 April 2013']),
#  'infomation:2': set(["Parking is FREE for the first two hours and charges apply thereafter, see our Car Park Charges page. There is a FREE bus service to St Clement's from the car park. This is operated by Oxford Bus Company at 10 minute intervals in both directions."]),
#  'int_ref': set(['E 05']),
#  'intermittent': set(['yes']),
#  'internet_access': set(['wlan', 'yes']),
#  'is_in': set(["St John's College"]),
#  'isced:level': set(['0', '1', '1-3']),
#  'junction': set(['roundabout']),
#  'landuse': set(['allotments',
#                  'basin',
# ...
#  'railway:traffic_mode': set(['freight']),
#  'rcn:left': set(['track']),
#  'rcn:right': set(['track']),
#  'ref': set(['12',
#              '239',
#              '277',
#              '4TE',
#              'A11',
#              'A338',
#              'A34',
#              'A40',
#              'A4074',
#              'A4095',
#              'A4142',
#              'A4144',
#              'A4158',
#              'A4165',
#              'A420',
#              'A421',
#              'A423',
#              'A4260',
#              'A44',
#              'B 4',
#              'B13',
#              'B4017',
#              'B4027',
#              'B4150',
#              'B4495',
#              'B480',
#              'B5106',
#              'C A-1',
#              'FORES1ZZ',
#              'G360',
#              'G371',
#              'GA5',
#              'GW200',
#              'K 2',
#              'OXFD',
#              'Rymers Ln Allotments *2316534*',
#              'SOUTHFIELD PARK FLATS 1661',
#              u'\u041d4495']),
#  'ref:NPLG:UPRN:1': set(['100120819336', '100120845293']),
#  'ref:UAI': set(['0850818C']),
#  'ref:bag': set(['1883100000060844']),
#  'ref:ruian:building': set(['42133319']),
#  'religion': set(['christian', 'muslim']),
#  'residential': set(['garden', 'university']),
#  'roof:levels': set(['1']),
#  'roof:material': set(['tile']),
#  'roof:shape': set(['flat', 'hipped']),
#  'room': set(['reception', 'stairwell']),
#  'sac_scale': set(['mountain_hiking']),
#  'school:FR': set([u'\xe9l\xe9mentaire']),
#  'school:entry': set(['fee']),
#  'school:female': set(['yes']),
#  'seasonal': set(['yes']),
#  'second_hand': set(['yes']),
#  'segregated': set(['no', 'yes']),
#  'service': set(['alley',
#                  'drive-through',
#                  'driveway',
#                  'parking_aisle',
#                  'siding',
#                  'spur',
#                  'yard']),
#  'service_times': set(['Su 11:00+']),
#  'shop': set(['Bathroom_Fitters',
#               'bicycle',
#               'books',
#               'builders_merchant',
#               'butcher',
#               'car',
#               'charity',
#               'clothes',
#               'confectionery',
#               'convenience',
#               'copyshop',
#               'deli',
#               'frame',
#               'funeral_directors',
#               'garden_centre',
#               'gift',
#               'greengrocer',
#               'grocery',
#               'hairdresser',
#               'jewelry',
#               'mall',
#               'music',
#               'pet',
#               'stationery',
#               'supermarket',
#               'toys',
#               'vacant',
#               'yes']),
#  'short_name': set(['St Mary & St John',
#                     'Warlands',
#                     'West Oxford Primary School']),
#  'sidewalk': set(['both', 'no', 'none']),
#  'smoothness': set(['good', 'very_bad']),
#  'social_facility': set(['workshop']),
#  'source': set(['3dShapes',
#                 ';Oxford City Council/Oxfordshire County Council Transport publications;site surveys',
#                 'BAG',
#                 'Bing',
#                 'Bing and Local Knowledge',
#                 'Bing, 2007/4',
#                 'Bing, local knowledge',
#                 'Bing; OS_OpenData_StreetView',
#                 'Bing; local knowledge',
#                 'Bing; survey',
#                 'Bing; www.admin.ox.ac.uk',
#                 'Bing; www.oxfordshire.gov.uk',
#                 'Bing; www.pembrokebridgingcenturies.org',
#                 'Bing;OS OpenData StreetView',
#                 'Bing;OSM gps point cloud;Oxford City Council/Oxfordshire County Council Transport publications;site surveys',
#                 'Bing;OSM_gps_data',
#                 'Bing;OS_OpenData_StreetView',
#                 'Bing;OS_OpenData_StreetView;yahoo_imagery',
#                 'Bing;gps_survey',
#                 'Bing;inference',
#                 'Bing;local_knowledge',
#                 'Bing;local_knowledge;inference',
#                 'Bing;local_knowledge;website',
#                 'Bing;osm_gps_points',
#                 'Bing;osm_gps_points;local_knowledge',
#                 'Bing;photograph',
#                 'Bing;photograph;local_knowledge',
#                 'Bing;survey',
#                 'CANVEC',
#                 'DOP from WMS at geodaten.bayern.de',
#                 'GPS',
#                 'GPS Survey',
#                 'GPS; NPE',
#                 'GSI ortorectified',
#                 'Geoimage.at MaxRes',
#                 "I've used this room since the end of 1999AD",
#                 'Maps4BW, LGL, www.lgl-bw.de',
#                 'NPE',
#                 'NPE;survey;yahoo_imagery',
#                 'NPE;yahoo_imagery',
#                 'NRCan-CanVec-10.0',
#                 'Name plate',
#                 'OS OpenData StreetView',
#                 'OS OpenData StreetView/survey west end/interpolation',
#                 'OS Opendata Streetview',
#                 'OS_OpenData_Boundary-Line',
#                 'OS_OpenData_BoundaryLine',
#                 'OS_OpenData_Locator',
#                 'OS_OpenData_StreetView',
#                 'OS_OpenData_StreetView;Bing',
#                 'OS_OpenData_StreetView;yahoo_imagery;local_knowledge',
#                 'OS_OpenData_VectorMapDistrict',
#                 'PGS',
#                 'Personal knowledge',
#                 'RABA-KGZ',
#                 'Site visit today.',
#                 'Yahoo',
#                 'bing',
#                 'bing;survey',
#                 u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Finances Publiques - Cadastre. Mise \xe0 jour : 2016',
#                 'cuzk:ruian',
#                 u'data.gouv.fr:\xc9ducation Nationale - 04/2014',
#                 'gps',
#                 'gps_survey',
#                 'gps_survey;Bing',
#                 'gps_survey;photograph',
#                 'gps_survey;yahoo_imagery',
#                 'gps_trace',
#                 'historical',
#                 'http://www.ratchakitcha.soc.go.th/DATA/PDF/2550/A/031/33.PDF',
#                 'inference',
#                 'landsat',
#                 'landsat,memory',
#                 'local knowledge, Bing',
#                 'local_knowledge',
#                 'local_knowledge;Bing',
#                 'naptan_import',
#                 'nlc',
#                 'npe',
#                 'osm_gps_data;Bing',
#                 'osm_gps_points;Bing',
#                 'photograph',
#                 'photograph; gps_survey; photograph',
#                 'photograph;NPE;local_knowledge',
#                 'photograph;gps_survey',
#                 'photograph;yahoo_imagery',
#                 'servey; operator website.',
#                 'sign at N end, NPE + Yahoo',
#                 'sitevisit',
#                 'survey',
#                 'survey 2/2016',
#                 'survey and council',
#                 'survey;Bing',
#                 'survey;bing',
#                 'survey;inference',
#                 'survey;photograph',
#                 'survey;yahoo_imagery',
#                 'surveys;bing',
#                 'view.',
#                 'visit',
#                 'visual survey;bing',
#                 'website',
#                 'yahoo',
#                 'yahoo + gpx',
#                 'yahoo;Bing;gps_survey',
#                 'yahoo_imagery',
#                 'yahoo_imagery;Bing',
#                 'yahoo_imagery;OS_OpenData_StreetView',
#                 'yahoo_imagery;gps_survey',
#                 'yahoo_imagery;local_knowledge',
#                 'yahoo_imagery;photograph',
#                 'yahoo_imagery;photograph;inference',
#                 'yahoo_imagery;survey;Bing']),
#  'source:access': set(['local_knowledge', 'photograph']),
#  'source:addr': set(['besko.e-mapa.net', 'emuia.gugik.gov.pl', 'survey']),
#  'source:addr:housenumber': set(['survey']),
#  'source:addr:postcode': set(['OS Codepoint']),
#  'source:alt_name': set(['inference, Oxford 20mph zone RTO Schedule 1',
#                          'photograph (of bus stop);naptan_import']),
#  'source:bicycle': set(['photograph']),
#  'source:building': set(['Bing',
#                          'OS_OpenData_StreetView',
#                          'bing',
#                          'gps_survey']),
#  'source:capacity': set(['Bing+existing OSM data']),
#  'source:covered': set(['survey']),
#  'source:date': set(['2015-12-31', '2016-02-25', '2016-03-03']),
#  'source:designation': set(['definitive_statement']),
#  'source:geometry': set(['Bing',
#                          'geoportal.gov.pl, GPS',
#                          'maps4bw (LGL, www.lgl-be.de); Mapbox Satellite',
#                          'survey']),
#  'source:highway': set(['photograph', 'signpost']),
#  'source:maxspeed': set(['GB:nsl_dual',
#                          'GB:nsl_single',
#                          'Stats19/interpolation',
#                          'UK:nsl_dual',
#                          'UK:nsl_single',
#                          'sign']),
#  'source:name': set(['ITO OSL',
#                      'MT 2014 Staff newsletter and http://beomino.blogspot.co.uk/2010/01/getting-sorted.html',
#                      'NPE',
#                      'OS Locator',
#                      'OSL',
#                      'OS_OpenData_Locator',
#                      'OS_OpenData_StreetView',
#                      'OS_OpenData_Streetview',
#                      'gps_survey',
#                      'inference, Oxford 20mph zone RTO Schedule 1',
#                      'landsat',
#                      'local knowledge',
#                      'local_knowledge',
#                      'photograph',
#                      'photograph (street name sign)',
#                      'photograph;memory of an oddly-spelled name',
#                      'road sign']),
#  'source:oneway': set(['photograph']),
#  'source:operator': set(['photograph']),
#  'source:postcode': set(['Codepoint', 'OS_OpenData_CodePoint']),
#  'source:ref': set(['OS OpenData StreetView',
#                     'definitive_statement',
#                     'inference, Oxford 20mph zone RTO Schedule 1',
#                     'local knowledge']),
#  'source_ref': set(['<different>',
#                     'http://warper.geothings.net/maps/398',
#                     'http://warper.geothings.net/maps/399',
#                     'http://warper.geothings.net/maps/411',
#                     'http://warper.geothings.net/maps/412',
#                     'http://warper.geothings.net/maps/413',
#                     'http://warper.geothings.net/maps/414']),
#  'sport': set(['Rugby Fives',
#                'basketball',
#                'bowls',
#                'cricket',
#                'football',
#                'soccer',
#                'swimming',
#                'tennis']),
#  'stars': set(['4']),
#  'start_date': set(['1702',
#                     '1930',
#                     '1964',
#                     '1965',
#                     '1966',
#                     '1970',
#                     '1975',
#                     '1977',
#                     '1979',
#                     '1981',
#                     '1982',
#                     '1984',
#                     '1988',
#                     '2012']),
#  'step_count': set(['1', '2']),
#  'steps': set(['39', 'yes']),
#  'substation': set(['industrial', 'minor_distribution']),
#  'supervised': set(['no', 'yes']),
#  'surface': set(['asphalt',
#                  'asphalt?',
#                  'brick',
#                  'clay',
#                  'compacted',
#                  'concrete',
#                  'dirt',
#                  'earth',
#                  'fine_gravel',
#                  'grass',
#                  'gravel',
#                  'ground',
#                  'paved',
#                  'paving_stones',
#                  'pebblestone',
#                  'sand',
#                  'spaced brick',
#                  'tarmac',
#                  'unpaved',
#                  'wood']),
#  'telephone': set(['+44 (0)1865 604368', '01865 515808']),
#  'text': set(['[was a notice from the for Oxford City Council about no parking opersite any of the garages ahead]']),
#  'through_route': set(['yes']),
#  'tiger:cfcc': set(['A41', 'B11']),
#  'tiger:county': set(['Lincoln, OR',
#                       'Llano, TX',
#                       'Mayes, OK',
#                       'Oakland, MI',
#                       'Pendleton, WV']),
#  'tiger:name_base': set(['County Route 3',
#                          'Missouri-Kansas-Texas Railroad',
#                          'Natl Forest Develop Road 5283',
#                          'School']),
#  'tiger:name_base_1': set(['Sweedlin Valley']),
#  'tiger:name_type': set(['St']),
#  'tiger:reviewed': set(['no']),
#  'tiger:separated': set(['no']),
#  'tiger:source': set(['tiger_import_dch_v0.6_20070808']),
#  'tiger:tlid': set(['155945996:155945866:155945868:155945421:155945870:155945872:155945874']),
#  'tiger:zip_left': set(['48017']),
#  'tiger:zip_right': set(['48017']),
#  'toilets:disposal': set(['flush']),
#  'toll:hgv': set(['yes']),
#  'tourism': set(['attraction', 'bed_and_breakfast', 'guest_house', 'hotel']),
#  'tourist_bus': set(['destination', 'no']),
#  'tourist_bus:conditional': set(['no @ (10:00-18:00 AND occupants>8)']),
#  'tower:type': set(['firefighter_training']),
#  'towpath': set(['right', 'yes']),
#  'track_detail': set(['yes']),
#  'tracks': set(['1', '2', '3', '4']),
#  'tracktype': set(['grade1', 'grade2', 'grade3', 'grade4', 'grade5']),
#  'traffic_calming': set(['chicane', 'choker', 'cushion']),
#  'traffic_sign': set(['Text']),
#  'trail_visibility': set(['excellent', 'good']),
#  'tunnel': set(['building_passage', 'culvert', 'yes']),
#  'type': set(['airtight', 'drystone', 'multipolygon', 'slideing']),
#  'unisex': set(['yes']),
#  'url': set(['http://www.srchilds.co.uk/',
#              'http://www.sunningwell.oxon.sch.uk/']),
#  'usage': set(['main']),
#  'user': set(['Osney, St Thomas & New Botley Allotment Association']),
#  'vehicle': set(['yes']),
#  'voltage': set(['11000;415', '115000', '132000', '3000', '400000', '750']),
#  'wall': set(['no']),
#  'water': set(['canal']),
#  'waterway': set(['canal',
#                   'ditch',
#                   'drain',
#                   'river',
#                   'riverbank',
#                   'rollers',
#                   'stream',
#                   'weir']),
#  'waterway_category:NDS': set(['2']),
#  'website': set(['al-shami.co.uk',
#                  'http://csjb.org.uk/',
#                  'http://doverbroeks.com',
#                  'http://joeperksandco.co.uk/',
#                  'http://mrc-oxford.org',
#                  'http://osneykite.com/',
#                  'http://oxfordshire-mind.org.uk',
#                  'http://oxfordspiritualistchurch.com/',
#                  'http://persiahairdesign.co.uk',
#                  'http://stpeterseynsham.org.uk/',
#                  'http://www.coconoir.net/',
#                  'http://www.haldihof.ch/',
#                  'http://www.hanboroughmanor.co.uk/',
#                  'http://www.helenanddouglas.org.uk',
#                  'http://www.iffley.co.uk/',
#                  'http://www.imperica.com/',
#                  'http://www.kaplanaspect.com',
#                  'http://www.lac.ox.ac.uk',
#                  'http://www.lang.ox.ac.uk/',
#                  'http://www.mcmartihair.co.uk/',
#                  'http://www.mfeller.co.uk/',
#                  'http://www.oldblackhorse.com',
#                  'http://www.parklandsoxford.co.uk',
#                  'http://www.pegtopfarm.co.uk/',
#                  'http://www.ryestantony.co.uk/',
#                  'http://www.saintcolumbas.org/',
#                  'http://www.sbs.ox.ac.uk/',
#                  'http://www.stedwardsoxford.org/beyond-the-classroom/sports/other-sports/golf/',
#                  'http://www.theworkshopstudios.org.uk/',
#                  'http://www.warlands-cycles.co.uk/',
#                  'www.isiscreative.co.uk',
#                  'www.pegasustheatre.org.uk']),
#  'wetland': set(['wet_meadow']),
#  'wheelchair': set(['limited', 'no', 'yes']),
#  'width': set(['0.5', '1.5', '2', '2.5 m', '3']),
#  'wikipedia': set(['en:Convocation House',
#                    'en:Divinity School, Oxford',
#                    'en:Kellogg College, Oxford',
#                    'en:St Barnabas Church, Oxford',
#                    "en:St Hugh's College, Oxford"]),
#  'wires': set(['single'])}

# %% [markdown]
# ### Unique "k" and "v" values in "relation" tags

# %%
relation_k_v_dict = audit_k_v(SAMPLE, ["relation"])
pprint.pprint(relation_k_v_dict)
# Out:
# {'IBGE:GEOCODIGO': set(['2926707']),
#  'TMC:cid_58:tabcd_1:Class': set(['Road']),
#  'TMC:cid_58:tabcd_1:LCLversion': set(['8.00']),
#  'TMC:cid_58:tabcd_1:LocationCode': set(['35520']),
#  'addr:city': set(['Oxford']),
#  'addr:housenumber': set(['11']),
#  'addr:postcode': set(['OX1 1DW', 'OX1 1SS']),
#  'addr:street': set(['Floyds Row']),
#  'admin_level': set(['10', '8']),
#  'amenity': set(['school', 'training_and_support_centre', 'university']),
#  'area': set(['yes']),
#  'ascent': set(['1120 m']),
#  'authoritative': set(['yes']),
#  'boundary': set(['administrative', 'national_park', 'protected_area']),
#  'building': set(['university', 'yes']),
#  'color': set(['#000099']),
#  'colour': set(['#0000FF', '#F39200']),
#  'colour:arrow': set(['black']),
#  'colour:back': set(['white']),
#  'colour:text': set(['black']),
#  'construction': set(['roadworks']),
#  'description': set(['780 15 Mile Rd to Maple & Orchard Lake via Oakland Park Towers',
#                      'Abingdon - Cumnor - Botley - Oxford - Iffley - Rose Hill',
#                      'Blackbird Leys - Cowley Centre - Cowley Road - City Centre - Railway Station',
#                      'Kennington Jn to Morris Cowley',
#                      'OhreBus Verkehrsgesellschaft mbH',
#                      u'Patton <> Lyc\xe9e Br\xe9quigny']),
#  'designation': set(['civil_parish']),
#  'destination': set([u'Kl\xe4ranlage', 'Kuhbach']),
#  'distance': set(['34', '43.5 km']),
#  'except': set(['bicycle']),
#  'fixme': set(['This wooded area is not entirely correct as it includes the treeless area above the snowline!']),
#  'frequency': set(['0', '1', '10', '6']),
#  'from': set(['15 Mile & Gratiot', 'Cumnor', 'Terminal Aterro']),
#  'headsign_0': set(['780 15 MILE']),
#  'headsign_1': set(['780 to ORCHARD LAKE']),
#  'highway': set(['pedestrian']),
#  'historic': set(['yes']),
#  'intermittent': set(['yes']),
#  'is_in:state': set(['IL']),
#  'landuse': set(['forest', 'grass', 'meadow', 'residential']),
#  'lanes': set(['1', '2']),
#  'learning': set(['oxford_college']),
#  'leisure': set(['nature_reserve', 'pitch']),
#  'modifier': set(['Historic']),
#  'name': set(['233',
#               '4B',
#               '6',
#               'Alpenblick-Tour',
#               'Barton Lane',
#               'Bate Collection of Musical Instruments',
#               'Broadhead Place',
#               'Bus 780: 15 Mile & Gratiot => Maple & Orchard Lake via Oakland Park Towers',
#               'Bus Rennes Ligne 5',
#               'Bus S75',
#               'Cuddesdon and Denton',
#               'De_BHV_503',
#               'European long distance path E2 - part United Kingdom',
#               'Eynsham',
#               'Felipe Bauler (Circular)',
#               'Front Quad',
#               'GW260',
#               'Garden Quad',
#               'George Street',
#               'Gosford and Water Eaton CP',
#               'Historic US 66 (1926-30)',
#               'IJsselmeer',
#               'Kennington',
#               'Kennington-Redbridge',
#               'Kosciuszko National Park',
#               u'Kreisstra\xdfen Borken',
#               "Lazenbee's Pond",
#               'Le Tarn',
#               u'MTB Gro\xdfe Felsen-Runde',
#               'Medemblik',
#               'North Place',
#               'OhreBus',
#               'Oxford to Bicester Line',
#               'Oxford-Aynho',
#               'Pembroke College',
#               'Police Station',
#               'Radley',
#               'Restore',
#               'Rio de Contas',
#               'Sand Butte Wilderness Study Area',
#               'Sandfield Road',
#               'Sandford-on-Thames',
#               'Sandpit Walk',
#               u'Schweringh\xe4user Bach',
#               'Sheep Mountain Wilderness Study Area',
#               'Southern Zone',
#               'T94',
#               'The Old Court House',
#               'Wheatley CE Primary School',
#               'X33',
#               'roads affected by Plain Junction roadworks for diversions and tempoarly changed restrictions',
#               u'\u043e\u0441\u0442\u0440\u043e\u0432 \u0420\u0435\u0439\u043d\u0435\u043a\u0435']),
#  'name:be': set(['Europese wandelroute E2, UK']),
#  'name:de': set([u'Europ\xe4ischer Fernwanderweg E2, UK',
#                  'Kosciuszko-Nationalpark',
#                  'Reineke-Insel']),
#  'name:en': set(['European long distance path E2 - part United Kingdom',
#                  'Reyneke Island']),
#  'name:fr': set([u'Chemin de randonn\xe9e Europ\xe9en E2, UK']),
#  'name:fy': set(['Iselmar']),
#  'name:it': set(['Isola di Rejneke']),
#  'name:nl': set(['Europese wandelroute E2, UK', 'IJsselmeer']),
#  'name:ru': set([u'\u043e\u0441\u0442\u0440\u043e\u0432 \u0420\u0435\u0439\u043d\u0435\u043a\u0435']),
#  'naptan:StopAreaCode': set(['340G00001097', '340G00003138', '490G00011901']),
#  'naptan:StopAreaType': set(['GCLS', 'GPBS']),
#  'natural': set(['grassland', 'water', 'wood']),
#  'network': set(['BremerhavenBus',
#                  'Municipal',
#                  'Oxford',
#                  'Oxfordshire',
#                  'US:US',
#                  'VGM',
#                  'fr_star',
#                  'iwn',
#                  'lcn',
#                  'lwn',
#                  'public_transport',
#                  'tertiary',
#                  'xcn']),
#  'note': set(["I'll fill in these details in a while but look at its counterpart at the east end of the same High street oxford.",
#               u'Kl\xe4ranlage',
#               'Not an NCN RR (single-figure), but white-figures-on-a-blue-bg nonetheless; Not signposted beyond Redbridge',
#               'Not signposted',
#               'This relation is for roadways marked with Historic US 66 shields, whether or not they were actually US 66. If you want to mark that a road was US 66, use the old_ref tag.',
#               'Ways complete. Stops currently unnumbered and incomplete.',
#               'extra-city exercise route',
#               u'rela\xe7\xe3o est\xe1 de acordo com a nova lei em vig\xeancia no Estado e que diverge momentaneamente do IBGE, at\xe9 o mesmo se atualizar.',
#               'road permissions alter in differnt ways between day and night and bulding phases alert road users to look for signs early when headin north - West on B480, A4158 and A420 towards the plain early to look for the small roadside diversion signs.']),
#  'note:2': set(['Last night for example west traffic from the A420 was turned @ Dawson Street (made specilly one way);south-east upo the B480 to Circus St {specially one way} then let North west to the plain up the A4158.  Traffic running to the east  along the A420 was']),
#  'note:3': set(['diverted at Stockmore St {specialy one way}dogleged along the B480 and along Jeune St before resumeing to the A420 past the works.  This morning traffic flowed round the junction from all 5 routes with peddestiran diversions close to the junction.']),
#  'note:4': set(["Temple St was used last week to take northbound A4158 traffic via B480. and eralier still traffic was one wayed  though Dawson St and temple street to take trafic Westbound A4158 traffic andtraffic west bound for the B480 and A4158 along withNorthlyB480's"]),
#  'note:5': set(['Bus and taxi route equally affected, allowing some unusal scenes of them turning in and out of the small roads {hence parking restictions and one waying}']),
#  'note:frequency': set(['peak only afaics']),
#  'operator': set(['BLM',
#                   'Chiltern Railways',
#                   'DB Bahn Westfalenbus',
#                   'European Ramblers Association',
#                   'Kreis Borken',
#                   'Naturpark Schwarzwald Mitte/Nord e.V.',
#                   'Network Rail',
#                   'OhreBus Verkehrsgesellschaft mbH',
#                   'Oxford Bus Company',
#                   'STAR',
#                   'Siga',
#                   'Society of the Sacred Heart',
#                   'St Edmund Hall',
#                   'Stagecoach',
#                   'Thames Travel',
#                   'VBN']),
#  'operator:be': set(['Grote Routepaden']),
#  'operator:fr': set([u'F\xe9d\xe9ration Fran\xe7aise de la Randonn\xe9e P\xe9destre']),
#  'operator:lux': set([u'D\xe9partement Du Tourisme']),
#  'operator:nl': set(['Stichting Wandelplatform']),
#  'operator:uk': set(['Long Distance Walkers Association']),
#  'osmc:symbol': set(['red:white:red_triangle']),
#  'ownership': set(['national']),
#  'place': set(['island']),
#  'protect_class': set(['1b']),
#  'protection_title': set(['Wilderness Study Area']),
#  'public_transport': set(['stop_place']),
#  'public_transport:version': set(['2']),
#  'raba:id': set(['1300']),
#  'ref': set(['124',
#              '233',
#              '4B',
#              '5',
#              '503',
#              '6',
#              '66',
#              '7',
#              '780',
#              '9',
#              'AT',
#              'E2',
#              'GW260',
#              'S75',
#              'T94',
#              'X33']),
#  'ref:sandre': set(['O---0100']),
#  'ref:woonplaatscode': set(['3151']),
#  'ref_group': set(['1 Cowley Road services',
#                    '2 Other',
#                    '3 Queen St Loopers',
#                    '4 North']),
#  'restriction': set(['no_left_turn',
#                      'no_straight_on',
#                      'no_u_turn',
#                      'only_left_turn',
#                      'only_straight_on']),
#  'roundtrip': set(['no', 'yes']),
#  'route': set(['bicycle', 'bus', 'hiking', 'mtb', 'railway', 'road', 'train']),
#  'route_master': set(['Lorry', 'bus']),
#  'route_sections': set(['yes']),
#  'segment': set(['no']),
#  'service': set(['busway', 'city', 'country']),
#  'shop': set(['garden_centre']),
#  'signposted': set(['no']),
#  'site': set(['stop_area']),
#  'source': set(['BAG',
#                 'Bing',
#                 'IBGE',
#                 'LPI Base Map December 2015 for some!',
#                 u'NESA(Supplement No. 20 \u2013 07 September 2013)',
#                 'NRCan-CanVec-10.0',
#                 'RABA-KGZ',
#                 'http://wiki.openstreetmap.org/wiki/Import/Catalogue/Strassen_NRW',
#                 'naptan_import']),
#  'source:addr:postcode': set(['OS Codepoint']),
#  'source:date': set(['2015-12-31']),
#  'source:geometry': set(['Bing']),
#  'start_date': set(['2010-11-02 00:00:00']),
#  'symbol': set(['White numerals on blue background',
#                 'blaues Bike auf gelbem Grund',
#                 'red triangle']),
#  'text_color': set(['#000000']),
#  'to': set(['Maple & Orchard Lake', 'Rose Hill', 'Rua Felipe Bauler']),
#  'tourism': set(['attraction', 'museum']),
#  'tracks': set(['2']),
#  'type': set(['NESA:Routecode',
#               'associatedStreet',
#               'boundary',
#               'destination_sign',
#               'multipolygon',
#               'network',
#               'restriction',
#               'route',
#               'route_master',
#               'site',
#               'superroute',
#               'turnlanes:turns',
#               'waterway']),
#  'url': set(['http://www.naturparkschwarzwald.de/pdf_pool_tour/pdf1029911101288084760.pdf']),
#  'via': set(['Badenfurt', 'Oakland Park Towers']),
#  'water': set(['lake']),
#  'waterway': set(['ditch', 'river', 'riverbank']),
#  'website': set(['http://www.bate.ox.ac.uk/',
#                  'http://www.ramblers.org.uk/info/paths/name/e/e2']),
#  'wheelchair': set(['yes']),
#  'wikidata': set(['Q3303930']),
#  'wikipedia': set(['en:E2 European long distance path',
#                    'en:Pembroke College, Oxford',
#                    'nl:IJsselmeer',
#                    'nl:Medemblik (stad)']),
#  'xcn': set(['oxford'])}

# %% [markdown]
# ### Unique "k" and "v" values in all tags

# %%
all_k_v_dict = audit_k_v(SAMPLE, ["node", "way", "relation"])

# %%
# Examining all "k" values
all_k_list = all_k_v_dict.keys()
all_k_list.sort()
all_k_list
# Out:
# ['BUFF_DIST',
#  'CAB:User_restictions',
#  'FIXME',
#  'FIXME:nsl',
#  'Fixme',
#  'IBGE:GEOCODIGO',
#  'Id',
#  'NPLG:USRN:1',
#  'ORIG_FID',
#  'Site:use',
#  'Support_service',
#  'TMC:cid_58:tabcd_1:Class',
#  'TMC:cid_58:tabcd_1:LCLversion',
#  'TMC:cid_58:tabcd_1:LocationCode',
#  'abutters',
#  'access',
#  'access:disabled',
#  'access:hgv',
#  'accessfrom',
#  'addr:city',
#  'addr:city:simc',
#  'addr:country',
#  'addr:county',
#  'addr:door',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:inclusion',
#  'addr:interpolation',
#  'addr:place',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'addr:substreet',
#  'addr:substreet1',
#  'addr:substreet:1',
#  'addr:substreet:2',
#  'addr:town',
#  'addr:unit',
#  'adjacent',
#  'admin_level',
#  'aeroway',
#  'alt_name',
#  'amenity',
#  'amenity:disused',
#  'answer',
#  'area',
#  'area:highway',
#  'artwork_type',
#  'ascent',
#  'atm',
#  'attribution',
#  'authoritative',
#  'backrest',
#  'barrier',
#  'basin',
#  'bicycle',
#  'bicycle:no:times',
#  'bicycle:note',
#  'bicycle_parking',
#  'board_type',
#  'boat',
#  'boundary',
#  'brand',
#  'bridge',
#  'bridge_name',
#  'bridge_over',
#  'bridge_ref',
#  'building',
#  'building:levels',
#  'building:levels:underground',
#  'building:material',
#  'building:part',
#  'building:roof',
#  'building:ruian:type',
#  'building:type',
#  'building:use',
#  'bus',
#  'bus:lanes:forward',
#  'bus_routes',
#  'busway:left',
#  'cables',
#  'capacity',
#  'capacity:disabled',
#  'capacity:private',
#  'circuits',
#  'clothes',
#  'collection_times',
#  'color',
#  'colour',
#  'colour:arrow',
#  'colour:back',
#  'colour:text',
#  'comment',
#  'construction',
#  'contact:phone',
#  'contact:website',
#  'continental_geometry',
#  'converted_by',
#  'covered',
#  'created_by',
#  'crossing',
#  'crossing_ref',
#  'cuisine',
#  'currency',
#  'cutting',
#  'cyclability',
#  'cycleway',
#  'cycleway:hazard',
#  'cycleway:left',
#  'cycleway:left:priority',
#  'cycleway:left:width',
#  'cycleway:note',
#  'cycleway:otherside:width',
#  'cycleway:right',
#  'cycleway:right:priority',
#  'cycleway:right:width',
#  'damage:colision',
#  'denomination',
#  'denotation',
#  'description',
#  'designation',
#  'destination',
#  'direction',
#  'disabled',
#  'disconnected',
#  'dismantled',
#  'display',
#  'distance',
#  'distribute_to',
#  'disused',
#  'disused:amenity',
#  'disused:highway',
#  'disused:shop',
#  'dog',
#  'door',
#  'drive_through',
#  'ele',
#  'electrified',
#  'email',
#  'embankment',
#  'emergency',
#  'entrance',
#  'est_width',
#  'except',
#  'fax',
#  'fed_from',
#  'fee',
#  'female',
#  'fence_type',
#  'fixme',
#  'floor',
#  'food',
#  'foot',
#  'footway',
#  'footway:left',
#  'frequency',
#  'frequency:4A',
#  'from',
#  'fuel:diesel',
#  'fuel:octane_95',
#  'fuel:octane_98',
#  'garden',
#  'garden:type',
#  'gate',
#  'gauge',
#  'genus',
#  'gluten_free',
#  'gnis:county_id',
#  'gnis:created',
#  'gnis:edited',
#  'gnis:feature_id',
#  'gnis:state_id',
#  'goods',
#  'headsign_0',
#  'headsign_1',
#  'height',
#  'hgv',
#  'highway',
#  'highways_agency:area',
#  'historic',
#  'history',
#  'horse',
#  'identification',
#  'incline',
#  'indoor',
#  'indoor_1',
#  'infomation:1',
#  'infomation:2',
#  'information',
#  'inscription',
#  'int_ref',
#  'intermittent',
#  'internet_access',
#  'is_in',
#  'is_in:state',
#  'isced:level',
#  'journeys',
#  'junction',
#  'kerb',
#  'lamp',
#  'lamp_mount',
#  'lamp_operator',
#  'lamp_type',
#  'landuse',
#  'landuse:former',
#  'lanes',
#  'lanes:bus:backward',
#  'lanes:bus:forward',
#  'lanes:forward',
#  'lanes:psv:backward',
#  'layer',
#  'lcn',
#  'lcn2',
#  'lcn2:left',
#  'lcn2:right',
#  'lcn:left',
#  'lcn:right',
#  'leaf_cycle',
#  'leaf_type',
#  'learning',
#  'leisure',
#  'level',
#  'level:name',
#  'levels',
#  'lift',
#  'links_higher',
#  'links_lower',
#  'lit',
#  'loading_gauge',
#  'loc_name',
#  'loc_ref',
#  'local:Bearing',
#  'local_ref',
#  'location',
#  'lock',
#  'lock_name',
#  'lock_ref',
#  'loop:left',
#  'loop:right',
#  'male',
#  'man_made',
#  'manhole',
#  'material',
#  'maxlength',
#  'maxspeed',
#  'maxspeed:note',
#  'maxspeed:source',
#  'maxspeed:spec',
#  'maxspeed:type',
#  'maxstay',
#  'maxweight',
#  'maxweight:hgv:conditional',
#  'mcn',
#  'memorial',
#  'modifier',
#  'mooring',
#  'mormon',
#  'motor_vehicle',
#  'motor_vehicle:backward',
#  'motor_vehicle:disabled',
#  'motor_vehicle:loading',
#  'motor_vehicle:loading:yes:times',
#  'motor_vehicle:no:times',
#  'motorboat',
#  'motorcar',
#  'motorcycle',
#  'name',
#  'name:be',
#  'name:cy',
#  'name:de',
#  'name:en',
#  'name:fr',
#  'name:fy',
#  'name:it',
#  'name:nl',
#  'name:note',
#  'name:ru',
#  'name:th',
#  'name_1',
#  'naptan:AtcoCode',
#  'naptan:Bearing',
#  'naptan:BusStopType',
#  'naptan:CommonName',
#  'naptan:Crossing',
#  'naptan:Indicator',
#  'naptan:Landmark',
#  'naptan:NaptanCode',
#  'naptan:Notes',
#  'naptan:PlusbusZoneRef',
#  'naptan:ShortCommonName',
#  'naptan:StopAreaCode',
#  'naptan:StopAreaType',
#  'naptan:Street',
#  'naptan:verified',
#  'natural',
#  'ncn:left',
#  'ncn:quiet',
#  'ncn_ref',
#  'network',
#  'not:name',
#  'not:name:note',
#  'note',
#  'note2',
#  'note:2',
#  'note:3',
#  'note:4',
#  'note:5',
#  'note:alt_name',
#  'note:frequency',
#  'note:name',
#  'note:reply',
#  'number',
#  'odbl',
#  'office',
#  'old_name',
#  'old_railway_operator',
#  'oneway',
#  'oneway:bicycle',
#  'oneway:note',
#  'oneway:reverse',
#  'opening_hours',
#  'opening_hours:morning',
#  'openplaques:id',
#  'operator',
#  'operator:be',
#  'operator:catagory',
#  'operator:fr',
#  'operator:lux',
#  'operator:nl',
#  'operator:type',
#  'operator:uk',
#  'organic',
#  'organisaition',
#  'organisation:affiliation:National',
#  'organisation:affiliation:region',
#  'orienteering',
#  'osmc:symbol',
#  'outdoor_seating',
#  'overtaking',
#  'owner',
#  'ownership',
#  'park_and_ride',
#  'park_ride',
#  'parking',
#  'parking:condition:both',
#  'parking:condition:both:garage_users',
#  'parking:lane:left',
#  'parking:lane:right',
#  'parking:left',
#  'parking:note',
#  'passenger_lines',
#  'payment:bitcoin',
#  'payment:card',
#  'payment:cards',
#  'payment:coins',
#  'phone',
#  'place',
#  'platforms',
#  'playground',
#  'polling_station',
#  'post_box:design',
#  'post_box:mounting',
#  'post_box:type',
#  'postal_code',
#  'power',
#  'proposed',
#  'proposed:electrified',
#  'proposed:frequency',
#  'proposed:voltage',
#  'protect_class',
#  'protection_title',
#  'prow:ref',
#  'prow_ref',
#  'psv',
#  'public_transport',
#  'public_transport:version',
#  'raba:id',
#  'railway',
#  'railway:traffic_mode',
#  'rcn:left',
#  'rcn:right',
#  'real_ale',
#  'recycling:batteries',
#  'recycling:cans',
#  'recycling:clothes',
#  'recycling:glass',
#  'recycling:paper',
#  'recycling:shoes',
#  'recycling_type',
#  'ref',
#  'ref:NPLG:UPRN:1',
#  'ref:UAI',
#  'ref:bag',
#  'ref:ruian:building',
#  'ref:sandre',
#  'ref:woonplaatscode',
#  'ref_group',
#  'religion',
#  'residential',
#  'restriction',
#  'roof:levels',
#  'roof:material',
#  'roof:shape',
#  'room',
#  'roundtrip',
#  'route',
#  'route_master',
#  'route_ref',
#  'route_sections',
#  'royal_cypher',
#  'sac_scale',
#  'school:FR',
#  'school:entry',
#  'school:female',
#  'seasonal',
#  'second_hand',
#  'segment',
#  'segregated',
#  'service',
#  'service_times',
#  'shelter',
#  'shop',
#  'short_name',
#  'short_route_ref',
#  'sidewalk',
#  'sign',
#  'signposted',
#  'site',
#  'smoking',
#  'smoothness',
#  'social_facility',
#  'source',
#  'source:access',
#  'source:addr',
#  'source:addr:housenumber',
#  'source:addr:postcode',
#  'source:alt_name',
#  'source:bicycle',
#  'source:building',
#  'source:capacity',
#  'source:covered',
#  'source:date',
#  'source:designation',
#  'source:geometry',
#  'source:highway',
#  'source:maxspeed',
#  'source:name',
#  'source:oneway',
#  'source:operator',
#  'source:position',
#  'source:postcode',
#  'source:ref',
#  'source_1',
#  'source_ref',
#  'species',
#  'sport',
#  'stars',
#  'start_date',
#  'step_count',
#  'steps',
#  'substation',
#  'supervised',
#  'support',
#  'surface',
#  'survey:date',
#  'suspened',
#  'symbol',
#  'takeaway',
#  'telephone',
#  'text',
#  'text_color',
#  'through_route',
#  'ticket',
#  'tiger:cfcc',
#  'tiger:county',
#  'tiger:name_base',
#  'tiger:name_base_1',
#  'tiger:name_type',
#  'tiger:reviewed',
#  'tiger:separated',
#  'tiger:source',
#  'tiger:tlid',
#  'tiger:zip_left',
#  'tiger:zip_right',
#  'to',
#  'toilets:disposal',
#  'toilets:wheelchair',
#  'toll:hgv',
#  'tourism',
#  'tourist_bus',
#  'tourist_bus:conditional',
#  'tower:type',
#  'towpath',
#  'track_detail',
#  'tracks',
#  'tracktype',
#  'traffic_calming',
#  'traffic_sign',
#  'traffic_sign:2',
#  'trail_visibility',
#  'tunnel',
#  'type',
#  'uk_postcode_centroid',
#  'unisex',
#  'url',
#  'usage',
#  'user',
#  'vehicle',
#  'vending',
#  'via',
#  'voltage',
#  'wall',
#  'water',
#  'waterway',
#  'waterway_category:NDS',
#  'website',
#  'wetland',
#  'wheelchair',
#  'wheelchair:description',
#  'width',
#  'wikidata',
#  'wikipedia',
#  'wires',
#  'xcn']

# %%
# Looking up "v" values for each "k"
all_k_v_dict["source"]
# Out:
# {'3dShapes',
#  ';Oxford City Council/Oxfordshire County Council Transport publications;site surveys',
#  'BAG',
#  'Bing',
#  'Bing and Local Knowledge',
#  'Bing, 2007/4',
#  'Bing, local knowledge',
#  'Bing; OS_OpenData_StreetView',
#  'Bing; local knowledge',
#  'Bing; survey',
#  'Bing; www.admin.ox.ac.uk',
#  'Bing; www.oxfordshire.gov.uk',
#  'Bing; www.pembrokebridgingcenturies.org',
#  'Bing;OS OpenData StreetView',
#  'Bing;OSM gps point cloud;Oxford City Council/Oxfordshire County Council Transport publications;site surveys',
#  'Bing;OSM_gps_data',
#  'Bing;OS_OpenData_StreetView',
#  'Bing;OS_OpenData_StreetView;yahoo_imagery',
#  'Bing;gps_survey',
#  'Bing;inference',
#  'Bing;local_knowledge',
#  'Bing;local_knowledge;inference',
#  'Bing;local_knowledge;website',
#  'Bing;osm_gps_points',
#  'Bing;osm_gps_points;local_knowledge',
#  'Bing;photograph',
#  'Bing;photograph;local_knowledge',
#  'Bing;survey',
#  'Bing;survey;yahoo_imagery',
#  'CANVEC',
#  'DOP from WMS at geodaten.bayern.de',
#  'GPS',
#  'GPS Survey',
#  'GPS; NPE',
#  'GSI ortorectified',
#  'Geoimage.at MaxRes',
#  "I've used this room since the end of 1999AD",
#  'IBGE',
#  'LPI Base Map December 2015 for some!',
#  'Local Knowledge',
#  'Maps4BW, LGL, www.lgl-bw.de',
#  u'NESA(Supplement No. 20 \u2013 07 September 2013)',
#  'NPE',
#  'NPE;survey;yahoo_imagery',
#  'NPE;yahoo_imagery',
#  'NRCan-CanVec-10.0',
#  'Name plate',
#  'OS OpenData StreetView',
#  'OS OpenData StreetView/survey west end/interpolation',
#  'OS Opendata Streetview',
#  'OS_OpenData_Boundary-Line',
#  'OS_OpenData_BoundaryLine',
#  'OS_OpenData_Locator',
#  'OS_OpenData_StreetView',
#  'OS_OpenData_StreetView;Bing',
#  'OS_OpenData_StreetView;yahoo_imagery;local_knowledge',
#  'OS_OpenData_VectorMapDistrict',
#  'Oxford City Parks Department',
#  'PGS',
#  'Personal knowledge',
#  'RABA-KGZ',
#  'Site visit today.',
#  'Yahoo',
#  'audio+gps_survey;Bing',
#  'bing',
#  'bing;survey',
#  u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Finances Publiques - Cadastre. Mise \xe0 jour : 2016',
#  'cuzk:ruian',
#  u'data.gouv.fr:\xc9ducation Nationale - 04/2014',
#  'gps',
#  'gps_survey',
#  'gps_survey;Bing',
#  'gps_survey;inference',
#  'gps_survey;naptan_import',
#  'gps_survey;photograph',
#  'gps_survey;yahoo_imagery',
#  'gps_trace',
#  'historical',
#  'http://wiki.openstreetmap.org/wiki/Import/Catalogue/Strassen_NRW',
#  'http://www.ratchakitcha.soc.go.th/DATA/PDF/2550/A/031/33.PDF',
#  'inference',
#  'landsat',
#  'landsat,memory',
#  'local knowledge, Bing',
#  'local_knowledge',
#  'local_knowledge;Bing',
#  'naptan_import',
#  'naptan_import;photograph',
#  'naptan_import;survey',
#  'nlc',
#  'npe',
#  'osm_gps_data;Bing',
#  'osm_gps_points;Bing',
#  'photograph',
#  'photograph; gps_survey; photograph',
#  'photograph;Bing',
#  'photograph;NPE;local_knowledge',
#  'photograph;gps_survey',
#  'photograph;local_knowledge',
#  'photograph;yahoo_imagery',
#  "reastaunt's website",
#  'servey; operator website.',
#  'sign at N end, NPE + Yahoo',
#  'site_survey',
#  'sitevisit',
#  'supplied to OSM from Oxford CAB',
#  'survery',
#  'survey',
#  'survey 2/2016',
#  'survey and council',
#  'survey;Bing',
#  'survey;bing',
#  'survey;inference',
#  'survey;photograph',
#  'survey;yahoo_imagery',
#  'surveys;bing',
#  'view.',
#  'visit',
#  'visual survey;bing',
#  'website',
#  'www.npemap.org.uk',
#  'yahoo',
#  'yahoo + gpx',
#  'yahoo;Bing;gps_survey',
#  'yahoo_imagery',
#  'yahoo_imagery;Bing',
#  'yahoo_imagery;OS_OpenData_StreetView',
#  'yahoo_imagery;gps_survey',
#  'yahoo_imagery;inference',
#  'yahoo_imagery;local_knowledge',
#  'yahoo_imagery;photograph',
#  'yahoo_imagery;photograph;inference',
#  'yahoo_imagery;survey;Bing'}

# %% [markdown]
# ## Structural Issues

# %% [markdown]
# ### 1. Multilevel appearance

# %% [markdown]
# There are some "k" values that have both one-level and two-level appearances (e.g., "amenity", "amenity:disused"). Some resolution is necessary. First, let's check all values that are subject to this problem.

# %%
# Getting "k" values that have both one-level and two-level appearances

lower = re.compile(r'^([a-z]|_)*$')

k_multilevel = set()
for key_one in all_k_list:
    if lower.search(key_one):
        key_single_colon = key_one + ":"
        for key_two in all_k_list:
            if key_two.startswith(key_single_colon):
                k_multilevel.add(key_one)
                k_multilevel.add(key_two)
k_multilevel
# Out:
# {'access',
#  'access:disabled',
#  'access:hgv',
#  'amenity',
#  'amenity:disused',
#  'area',
#  'area:highway',
#  'bicycle',
#  'bicycle:no:times',
#  'bicycle:note',
#  'building',
#  'building:levels',
#  'building:levels:underground',
#  'building:material',
#  'building:part',
#  'building:roof',
#  'building:ruian:type',
#  'building:type',
#  'building:use',
#  'bus',
#  'bus:lanes:forward',
#  'capacity',
#  'capacity:disabled',
#  'capacity:private',
#  'colour',
#  'colour:arrow',
#  'colour:back',
#  'colour:text',
#  'cycleway',
#  'cycleway:hazard',
#  'cycleway:left',
#  'cycleway:left:priority',
#  'cycleway:left:width',
#  'cycleway:note',
#  'cycleway:otherside:width',
#  'cycleway:right',
#  'cycleway:right:priority',
#  'cycleway:right:width',
#  'disused',
#  'disused:amenity',
#  'disused:highway',
#  'disused:shop',
#  'footway',
#  'footway:left',
#  'frequency',
#  'frequency:4A',
#  'garden',
#  'garden:type',
#  'is_in',
#  'is_in:state',
#  'landuse',
#  'landuse:former',
#  'lanes',
#  'lanes:bus:backward',
#  'lanes:bus:forward',
#  'lanes:forward',
#  'lanes:psv:backward',
#  'lcn',
#  'lcn:left',
#  'lcn:right',
#  'level',
#  'level:name',
#  'maxspeed',
#  'maxspeed:note',
#  'maxspeed:source',
#  'maxspeed:spec',
#  'maxspeed:type',
#  'maxweight',
#  'maxweight:hgv:conditional',
#  'motor_vehicle',
#  'motor_vehicle:backward',
#  'motor_vehicle:disabled',
#  'motor_vehicle:loading',
#  'motor_vehicle:loading:yes:times',
#  'motor_vehicle:no:times',
#  'name',
#  'name:be',
#  'name:cy',
#  'name:de',
#  'name:en',
#  'name:fr',
#  'name:fy',
#  'name:it',
#  'name:nl',
#  'name:note',
#  'name:ru',
#  'name:th',
#  'note',
#  'note:2',
#  'note:3',
#  'note:4',
#  'note:5',
#  'note:alt_name',
#  'note:frequency',
#  'note:name',
#  'note:reply',
#  'oneway',
#  'oneway:bicycle',
#  'oneway:note',
#  'oneway:reverse',
#  'opening_hours',
#  'opening_hours:morning',
#  'operator',
#  'operator:be',
#  'operator:catagory',
#  'operator:fr',
#  'operator:lux',
#  'operator:nl',
#  'operator:type',
#  'operator:uk',
#  'parking',
#  'parking:condition:both',
#  'parking:condition:both:garage_users',
#  'parking:lane:left',
#  'parking:lane:right',
#  'parking:left',
#  'parking:note',
#  'proposed',
#  'proposed:electrified',
#  'proposed:frequency',
#  'proposed:voltage',
#  'public_transport',
#  'public_transport:version',
#  'railway',
#  'railway:traffic_mode',
#  'ref',
#  'ref:NPLG:UPRN:1',
#  'ref:UAI',
#  'ref:bag',
#  'ref:ruian:building',
#  'ref:sandre',
#  'ref:woonplaatscode',
#  'source',
#  'source:access',
#  'source:addr',
#  'source:addr:housenumber',
#  'source:addr:postcode',
#  'source:alt_name',
#  'source:bicycle',
#  'source:building',
#  'source:capacity',
#  'source:covered',
#  'source:date',
#  'source:designation',
#  'source:geometry',
#  'source:highway',
#  'source:maxspeed',
#  'source:name',
#  'source:oneway',
#  'source:operator',
#  'source:position',
#  'source:postcode',
#  'source:ref',
#  'tourist_bus',
#  'tourist_bus:conditional',
#  'traffic_sign',
#  'traffic_sign:2',
#  'wheelchair',
#  'wheelchair:description'}

# %% [markdown]
# Let's take a look at what "v" values each of these problem "k" values contains.

# %%
k_multilevel = list(k_multilevel)
k_multilevel.sort()

for problem_key in k_multilevel:
    print problem_key
    pprint.pprint( all_k_v_dict[problem_key] )
    print "\n"
# Out:
# access
# set(['customer',
#      'customers',
#      'destination',
#      'no',
#      'permissive',
#      'private',
#      'public',
#      'steps',
#      'unknown',
#      'yes'])
#
#
# access:disabled
# set(['yes'])
#
#
# access:hgv
# set(['@ (18:00-10:00)', 'delivery'])
#
#
# amenity
# set(['Wellbeing_service',
#      'advice_service',
#      'arts_centre',
#      'atm',
#      'ballot_box',
#      'bank',
#      'bar',
#      'bench',
#      'bicycle_parking',
#      'bicycle_rental',
#      'biergarten',
#      'binstore',
#      'bureau_de_change',
#      'cafe',
#      'childcare',
#      'clock',
#      'college',
#      'community_centre',
#      'compound',
#      'dentist',
#      'doctors',
#      'fast_food',
#      'fountain',
#      'fuel',
#      'grave_yard',
#      'hide',
#      'hospice',
#      'hospital',
#      'kindergarten',
#      'library',
#      'motorcycle_parking',
#      'parking',
#      'parking_entrance',
#      'parking_space',
#      'pharmacy',
#      'place_of_worship',
#      'post_box',
#      'post_office',
#      'pub',
#      'public_building',
#      'recycling',
#      'restaurant',
#      'school',
#      'scout_hut',
#      'social_facility',
#      'telephone',
#      'theatre',
#      'toilets',
#      'training_and_support_centre',
#      'university',
#      'vending_machine',
#      'veterinary',
#      'washingline',
#      'waste_basket'])
#
#
# amenity:disused
# set(['pub'])
#
#
# area
# set(['yes'])
#
#
# area:highway
# set(['footway',
#      'pedestrian',
#      'residential',
#      'service',
#      'steps',
#      'unclassified'])
#
#
# bicycle
# set(['designated',
#      'dismount',
#      'no',
#      'permissive',
#      'private',
#      'tolerated',
#      'yes'])
#
#
# bicycle:no:times
# set(['10:00-18:00'])
#
#
# bicycle:note
# set(['difficult_barrier'])
#
#
# building
# set(['Fire Escape',
#      'apartments',
#      'bunker',
#      'bus_station',
#      'central_goverment',
#      'church',
#      'college',
#      'commercial',
#      'dormitory',
#      'entrance',
#      'farm',
#      'garage',
#      'garages',
#      'grandstand',
#      'greenhouse',
#      'hall',
#      'hospital',
#      'house',
#      'hut',
#      'industrial',
#      'mall',
#      'office',
#      'offices',
#      'place_of_worship',
#      'police',
#      'pub',
#      'remodelled_church',
#      'residential',
#      'retail',
#      'roof',
#      'school',
#      'shed',
#      'shop',
#      'stable',
#      'static_caravan',
#      'station',
#      'swimming_pool',
#      'terrace',
#      'tower',
#      'university',
#      'university accommodation',
#      'workshop',
#      'yes'])
#
#
# building:levels
# set(['1', '2', '3', '4'])
#
#
# building:levels:underground
# set(['1'])
#
#
# building:material
# set(['brick', 'stone'])
#
#
# building:part
# set(['spire_tower', 'yes'])
#
#
# building:roof
# set(['flat'])
#
#
# building:ruian:type
# set(['19'])
#
#
# building:type
# set(['Complex', 'residential'])
#
#
# building:use
# set(['accommodation',
#      'garages',
#      'hospital',
#      'office',
#      'parking',
#      'residential'])
#
#
# bus
# set(['yes'])
#
#
# bus:lanes:forward
# set(['1'])
#
#
# capacity
# set(['1',
#      '10',
#      '11',
#      '110',
#      '12',
#      '130',
#      '14',
#      '15',
#      '16',
#      '2',
#      '24',
#      '26',
#      '3',
#      '30',
#      '32',
#      '4',
#      '40',
#      '5',
#      '54',
#      '6',
#      '60',
#      '70',
#      '8',
#      '9'])
#
#
# capacity:disabled
# set(['1', '3', '5', '6'])
#
#
# capacity:private
# set(['1'])
#
#
# colour
# set(['#0000FF', '#F39200'])
#
#
# colour:arrow
# set(['black'])
#
#
# colour:back
# set(['white'])
#
#
# colour:text
# set(['black'])
#
#
# cycleway
# set(['crossing', 'lane', 'no', 'opposite', 'shared_lane', 'track'])
#
#
# cycleway:hazard
# set(['narrow'])
#
#
# cycleway:left
# set(['asl', 'lane', 'opposite_track', 'share_busway', 'track'])
#
#
# cycleway:left:priority
# set(['yes'])
#
#
# cycleway:left:width
# set(['1.2', '1.25', '1.75', '3'])
#
#
# cycleway:note
# set(['overall priority as good as for cars'])
#
#
# cycleway:otherside:width
# set(['1.75'])
#
#
# cycleway:right
# set(['lane', 'opposite_track', 'service', 'share_busway'])
#
#
# cycleway:right:priority
# set(['no'])
#
#
# cycleway:right:width
# set(['1.25', '1.75', '3'])
#
#
# disused
# set(['yes'])
#
#
# disused:amenity
# set(['bank', 'pub'])
#
#
# disused:highway
# set(['bus_stop'])
#
#
# disused:shop
# set(['convenience'])
#
#
# footway
# set(['crossing', 'no', 'sidewalk'])
#
#
# footway:left
# set(['yes'])
#
#
# frequency
# set(['0', '1', '10', '50', '6'])
#
#
# frequency:4A
# set(['3'])
#
#
# garden
# set(['residential', 'yes'])
#
#
# garden:type
# set(['pub'])
#
#
# is_in
# set(['Oxford, Oxfordshire, England, UK',
#      'Oxfordshire, England, UK',
#      "St John's College"])
#
#
# is_in:state
# set(['IL'])
#
#
# landuse
# set(['allotments',
#      'basin',
#      'cemetery',
#      'churchyard',
#      'commercial',
#      'construction',
#      'farm',
#      'farmland',
#      'farmyard',
#      'forest',
#      'garages',
#      'grass',
#      'industrial',
#      'meadow',
#      'military',
#      'orchard',
#      'quarry',
#      'railway',
#      'recreation_ground',
#      'religious',
#      'reservoir',
#      'residential',
#      'retail',
#      'village_green'])
#
#
# landuse:former
# set(['recreation_ground'])
#
#
# lanes
# set(['1', '1.5', '2', '3'])
#
#
# lanes:bus:backward
# set(['1'])
#
#
# lanes:bus:forward
# set(['1'])
#
#
# lanes:forward
# set(['2'])
#
#
# lanes:psv:backward
# set(['1'])
#
#
# lcn
# set(['yes'])
#
#
# lcn:left
# set(['footway', 'lane', 'road', 'track'])
#
#
# lcn:right
# set(['track'])
#
#
# level
# set(['-1',
#      '-1,0',
#      '-1,0,1,2,3',
#      '-1,0,1,2,3,4',
#      '-2',
#      '0',
#      '0,1',
#      '0,1,2,3',
#      '0.2',
#      '0.5',
#      '0;1',
#      '1',
#      '2',
#      '3',
#      'secondary'])
#
#
# level:name
# set(['First', 'Second Floor'])
#
#
# maxspeed
# set(['10 mph',
#      '20 mph',
#      '20mph',
#      '25 mph',
#      '30',
#      '30 mph',
#      '30mph',
#      '40 mph',
#      '5 mph',
#      '50',
#      '50 mph',
#      '60 mph',
#      '60mph',
#      '70 mph',
#      '75 mph',
#      '90 mph',
#      'none'])
#
#
# maxspeed:note
# set(['Oxford 20 mph zone'])
#
#
# maxspeed:source
# set(['AT:urban'])
#
#
# maxspeed:spec
# set(['... SW to its jn w/ Headington Road',
#      '... to its junction with St Clements Street',
#      'A point 67m N of its jn w/ Little Clarendon St, S to...',
#      "Banbury Rd's junction with St Giles",
#      'From its junction w/ the A44/A40 roundabout, SW...',
#      'From its junction with the Eastern Bypass (A4142) southwards to its junction with the Cowley Road, Littlemore',
#      'NW to its jn w/ The Plain',
#      'The length of road between the A4142 Eastern bypass and Hollow Way',
#      'a point 7m NW of its jn w/ Southfield Rd'])
#
#
# maxspeed:type
# set(['GB:nsl_dual'])
#
#
# maxweight
# set(['3', '7.5'])
#
#
# maxweight:hgv:conditional
# set(['none @ destination'])
#
#
# motor_vehicle
# set(['agricultural', 'no', 'permissive', 'private', 'yes'])
#
#
# motor_vehicle:backward
# set(['private'])
#
#
# motor_vehicle:disabled
# set(['yes'])
#
#
# motor_vehicle:loading
# set(['yes'])
#
#
# motor_vehicle:loading:yes:times
# set(['18:00-10:00'])
#
#
# motor_vehicle:no:times
# set(['10:00-18:00'])
#
#
# name
# set(['1',
#      '10',
#      '110',
#      '12',
#      '13',
#      '16',
#      '17',
#      '1st Phone City',
#      '233',
#      '24',
#      '26',
#      '301',
#      '352',
#      '366',
#      '371',
#      '413',
#      '46',
#      '4B',
#      '6',
#      '63',
#      '66',
#      '7',
#      '70',
#      '78',
#      '9',
#      '9 to 9',
#      '?-?',
#      'A40 (South) Eynsham-Oxford Cycleway',
#      'AMT Coffee',
#      'Abbots Wood',
#      'Abingdon Arms PH',
#      'Abingdon Road',
#      'Ablett Close',
#      'Acacia Avenue',
#      'Access blocked currently (Aug 2013)',
#      'Al Shami',
#      'Alan Aston Roofing Supplies Ltd',
#      'Alhambra Lane',
#      'Alice Smith Square',
#      'Allen Ward and Medical Library',
#      'Alpenblick-Tour',
#      'American Nails',
#      'Andersons Close',
#      'Andrea & Achille',
#      'Apsley Road',
#      'Arlosh',
#      'Art',
#      'Ash Copse',
#      'Ashmole Place',
#      'Astrop Lane',
#      'Atkinson Close',
#      'Atkyns Court',
#      'Augustine Way',
#      'Avenue 1',
#      'Back Lane',
#      'Back Quad',
#      'Bainton Road',
#      'Baker Close',
#      'Balfour Road',
#      'Balliol College Recreation Ground',
#      'Baltic Wharf',
#      'Bampton Close',
#      'Banbury Road',
#      'Bannister Building',
#      'Bar',
#      'Barn Close',
#      'Barns Road Car Park',
#      u'Barreler Stra\xdfe',
#      'Bartlemas Close (Links) Allotments',
#      'Barton Lane',
#      'Bat Willow Meadow',
#      'Bate Collection of Musical Instruments',
#      'Batholomew School',
#      'Bayswater Brook',
#      'Bayswater Road',
#      'Bayworth Lane',
#      'Beagles Close',
#      'Beaumont Alley',
#      'Beaumont Buildings',
#      'Beaumont Veterinary Group',
#      'Becket House B&B',
#      'Beckley Village Hall',
#      'Beech Croft Road',
#      'Beeline Bicycles',
#      'Begbroke Lane',
#      'Belsyre Court',
#      'Benson Place',
#      'Beresford Place',
#      'Bergamot Place',
#      'Besse Buildings',
#      'Betfred',
#      'Betts Lane',
#      'Bicester Road',
#      'Bigwood Residential Park',
#      "Bill's",
#      'Binsey Lane',
#      'Bishop Kirk Place',
#      'Bishops Gate',
#      'Blackberry Lane',
#      'Blackbird Leys Park',
#      'Blacksmiths Meadow',
#      'Block B',
#      'Block D',
#      'Blue Boar Court',
#      'Blue Plaque - J.R.R. Tolkien',
#      'Blue plaque: Dyson Perrins Laboratory',
#      'Boathouses Walk',
#      'Bonners',
#      'Boots',
#      'Boswells & Co',
#      'Botley Interchange',
#      'Botley Meadow',
#      'Botley Road',
#      'Botley Stream',
#      'Boults Close',
#      'Boundary Brook',
#      'Boundary Brook House',
#      'Boundary Brook Nature Park',
#      'Bradlands',
#      'Brambling Way',
#      'Brasenose & Exeter Boathouses',
#      'Brasenose Driftway',
#      'Brasenose Woods',
#      'Broad Close',
#      'Broad Street',
#      'Broadgates',
#      'Broadhead Place',
#      'Broadway',
#      'Brockhues Lodge',
#      'Brook Way',
#      'Brothers',
#      'Bryony Close',
#      'Bulwarks Lane',
#      'Burger King',
#      'Burleigh Road',
#      'Burton Place',
#      'Bury Knowle Park',
#      'Bury Knowle Public Conveniences',
#      'Bus 780: 15 Mile & Gratiot => Maple & Orchard Lake via Oakland Park Towers',
#      'Bus Rennes Ligne 5',
#      'Bus S75',
#      'C block',
#      'CANTELOUP HOUSE',
#      'CO-OP Market Street 2317874',
#      'Caffe Toscano',
#      'Calves Close',
#      'Campbell Road',
#      'Canal Street',
#      'Carfax Tower',
#      'Cargo',
#      'Caroline Street',
#      'Carpenter Close',
#      'Cassington Road',
#      'Cassington Turn',
#      'Castle Mill Stream',
#      'Castle Street',
#      'Cathedral Garden',
#      'Cecil Jackson-Cole',
#      'Chaffinch Walk',
#      'Chancellors',
#      'Chapel Hill Cemetery',
#      'Charlbury Road',
#      'Chelsea',
#      'Cherry Close',
#      'Chestnut Lawn',
#      'Chestnut Place',
#      'Chilbridge Road',
#      'Chilswell Lane',
#      'Church Close',
#      'Church Cowley School',
#      'Church Lane',
#      'Church Road',
#      'Church Way',
#      'Churchill Drive',
#      'Churchill Hospital',
#      'Churchill Road',
#      u'Ch\xe2teau de Luzan',
#      'City of Oxford Silver Band Hall',
#      'Cleavers Square',
#      'Clive Booth Student Village',
#      'Clive Road',
#      'Clock House',
#      'Cloister Garden',
#      'Co-op',
#      'Coach House Mews',
#      'Coco Noir',
#      'Collice Street',
#      'Colonnade',
#      'Computer Room',
#      'Constance Norman Way',
#      'Convocation House',
#      'Copcot Close',
#      'Copse Lane',
#      'Copse Lane West',
#      'Corn Hoe',
#      'Cornmarket Street',
#      'Cornwallis Close',
#      'Cots Gardens',
#      'Cots Green',
#      'Cottage',
#      'Council Carpark (Gloucester Green)',
#      'County Library',
#      'County Route 3',
#      'Courtland Road',
#      'Courtney Pianos',
#      'Coutts',
#      'Covered Market',
#      'Cowley Road',
#      'Cowley Workers Social Club',
#      'Cowley Works freight line',
#      'Cranham Terrace',
#      'Crescent Hall',
#      'Crescent Road',
#      'Cresswell Close',
#      'Cricket Road',
#      'Croft Road',
#      'Cromwell Way',
#      'Cross Street',
#      'Cuckoo Lane',
#      'Cuddesdon and Denton',
#      'Cuddeston Road',
#      'Cumberbatch Building',
#      'Cumberland Road',
#      'Cumnor Village Hall',
#      "D'Overbroeck's College - '106'",
#      "D'Overbroeck's college",
#      'DJ -Down Jerico',
#      'DM - Down Main',
#      'DPL - Down Passenger Loop',
#      'Dashwood Road',
#      'David Edwards Way',
#      'David Spicer Optician',
#      'De_BHV_503',
#      "Deadman's Walk",
#      'Dean Court Road',
#      'Deanfield Road',
#      'Delbush Avenue',
#      'Dene Road',
#      'Department of Physiology, Anatomy and Genetics',
#      'Derwent Avenue',
#      'Disabled',
#      'Donnington Bridge Road',
#      'Donnington Bridge Slipway',
#      'Dora Carr Close',
#      'Dorothy Hodgkin Road',
#      'Dovehouse Close',
#      'Dover Close',
#      'Dragon Bowl',
#      'Duke of Cambridge',
#      'Dunstead Lane',
#      'Durham Building 2',
#      'East Avenue',
#      'East End District',
#      'Eastern By-pass Road',
#      'Eaton Road',
#      'Ede & Ravenscroft',
#      'Eden Drive',
#      'Edgecombe Road',
#      'Edith Road',
#      'Edith Road Workshops',
#      'Egrove Close',
#      'Egrove Park',
#      'Elder Stubbs Allotments',
#      'Eleanor Lodge',
#      'Electric Avenue',
#      'Elsfield',
#      'Elsfield Way',
#      "Elton's Gate",
#      'Enquiries Desk and Sackler Reading Room',
#      'Esso',
#      'European long distance path E2 - part United Kingdom',
#      'Evans Lane',
#      'Ewin Close',
#      'Exeter College Sports Ground',
#      'Exeter Hall',
#      'Eynsham',
#      'F Block',
#      'Fair View',
#      'Fairacre Farm',
#      'Falcon Close',
#      'Falstaff Close',
#      'Fane Road',
#      'Farm Close',
#      'Farndon Court',
#      'Feilden Grove',
#      'Felipe Bauler (Circular)',
#      "Fellow's Private Garden",
#      "Fellows' Garden",
#      "Fellows' Quad Staircase 2",
#      'Fernhill Close',
#      'Ferry Road',
#      'Field Close',
#      'Field House Drive',
#      'Finch Close',
#      'Firs Meadow',
#      'First Avenue',
#      'First Church of Christ, Scientist',
#      'First Class Cuisine',
#      'First Turn',
#      'Fitrite',
#      'Florence Park Road',
#      'Forest Hill Sewage Treatment Works',
#      'Forest Hill Turn A40',
#      "Founder's Building",
#      'Foxcombe Lane',
#      'Foxdown Close',
#      'Foxglove Road',
#      'Frank Cook Court',
#      'Franklin Road',
#      'Freelands Road',
#      'Frenchay Road',
#      'Frewin Court',
#      'Frideswide Square',
#      'Frieze Way',
#      'Frog Lane',
#      'Front Quad',
#      'GW260',
#      'Galpin Close',
#      'Garden Quad',
#      'Garsington Church of England Primary School',
#      'Garsington Road',
#      'Gateway Buildings',
#      'Gathorne Road',
#      u'Gem\xfcsehof Mi\xdffeldt',
#      'George Street',
#      'George and Danver',
#      'Gillians Way',
#      'Girdlestone Close',
#      'Glebe Street',
#      'Globe Newsmarkets',
#      'Gloucester Green Car Park',
#      'Glyme Way',
#      'Godstow Road',
#      'Golden Road',
#      'Gooseberry Garden',
#      'Gordon Close',
#      'Gorse Leas',
#      'Gosford and Water Eaton CP',
#      'Goslyn Close',
#      'Grants Mews',
#      'Green Ridges',
#      'Grenoble Road',
#      'Greystones Court',
#      'Grove Building A',
#      'Gypsy Lane Site',
#      'Hailwood',
#      'Haldihof Barnshop & Cafe',
#      'Half Basketball court',
#      'Hamilton Road',
#      'Hanborough Close',
#      'Hanborough Manor C of E School',
#      'Harebell Road',
#      'Harolde Close',
#      "Hart's footbridge",
#      u'Hauptstra\xdfe',
#      'Hawksmoor Road',
#      'Hawksmoor Towers',
#      'Hawkswell Gardens',
#      'Hawthorn Avenue',
#      'Hayward Building',
#      'Headington',
#      'Headington Bathrooms',
#      'Headington Car Park',
#      'Headington Conservative Club',
#      'Headington Quarry Foundation Stage School',
#      'Headington Road',
#      'Headington Royal British Legion Club',
#      'Headington School',
#      'Headley Way',
#      'Heath Lane',
#      'Helen and Douglas House',
#      'Henley Road',
#      'Heron Place',
#      'Herschel Crescent',
#      'Heycroft',
#      'Heyford Hill Lane',
#      "Higgins's Copse",
#      'High Street',
#      'Higher Hillgate',
#      'Highfield',
#      'Hill Top Road',
#      'Hill View Road',
#      'Hillside Farm',
#      'Hilltop Gardens',
#      'Hinksey Hill',
#      'Hinksey Hill Interchange',
#      'Hinksey Hill Top',
#      'Historic US 66 (1926-30)',
#      u'Hoffeldstra\xdfe',
#      'Hogacre Ditch',
#      'Hogrefe House',
#      'Holland & Barrett',
#      'Hollywell JCR',
#      'Holyoake Road',
#      'Holywell Quad Staircase 1',
#      'Horseman Close',
#      'Horspath Road',
#      'Howard Street',
#      'Hugh Price House',
#      "Hull's Copse",
#      'Hutchcombe Farm Close',
#      'IJsselmeer',
#      'IT Services',
#      'Iffley Road',
#      'Iffley Turn',
#      'Imperica',
#      'Ingle Close Allotments',
#      'Inscripcion Gratis Conection Web',
#      'Institute of Advanced Technology',
#      'Isis Creative Framing',
#      'J. E. Pill & Son',
#      'JCR and Bar',
#      'JJB Sports',
#      "Jack Straw's Lane",
#      'Jama Kunststoff',
#      'James Street',
#      'James Street Tavern',
#      "Jamie's Italian",
#      'Jeans West',
#      'Jenkin Building',
#      'Jessops Close',
#      'Jewson Site A yard',
#      "Jimbob's Baguettes",
#      'John Garne Way',
#      'John Radcliffe Academic',
#      'John Radcliffe Main Hospital',
#      'John Smith Drive',
#      'John Watson School',
#      'Jordan Hill',
#      'Joseph Perks & Co.',
#      'Jourdain Road',
#      'Jude the Obscure',
#      'Kaplan International Colleges',
#      'Kargil-Skardu Road',
#      'Kellogg College',
#      "Kelly's Road",
#      'Kemp Hall Passage',
#      'Kendal Cresent Shops',
#      'Kendall Crescent',
#      'Kennington',
#      'Kennington Health Centre',
#      'Kennington Methodist Church',
#      'Kennington Road',
#      'Kennington Roundabout',
#      'Kennington-Redbridge',
#      'Kenyon Building',
#      'Kidlington Green Lock',
#      'Kids Unlimited Day Nursery',
#      'Kiln Lane',
#      'Kingfisher Corner',
#      'Kings Mill Lane',
#      'Kitchen',
#      'Kitchens',
#      'Knights Car Park',
#      'Kosciuszko National Park',
#      u'Kreisstra\xdfen Borken',
#      'Kybald Twychen',
#      'La Croissanterie',
#      'Laburnum Crescent',
#      'Laburnum Road',
#      'Lakeside',
#      'Lal Newsagent',
#      'Lamarsh Road',
#      'Lamb and Flag Passage',
#      'Language Centre',
#      'Larch End',
#      'Lashford Lane',
#      'Latin American Centre',
#      'Law Library',
#      "Lazenbee's Ground Walk",
#      "Lazenbee's Pond",
#      'Le Tarn',
#      'Leckford Road',
#      'Leopard Press',
#      'Lewis Close',
#      'Leys Road',
#      'Library',
#      'Library Quad',
#      'Liddell',
#      'Liddell Road',
#      'Lime Walk',
#      'Lincombe Lane',
#      'Linton Quad',
#      'Little Brewery Street',
#      'Little Bury',
#      'Little Mill Pond Mead',
#      'Littlemore Library',
#      'Littlemore Mental Health Centre',
#      'Littlemore Road',
#      'Littlemore Roundabout',
#      'Littlemore Shops',
#      'Littleworth Park',
#      'Livingstone Close',
#      'Llanrwst Road',
#      'Lloyds Bank',
#      'Lloyds Pharmacy',
#      'Lobelia Road',
#      'Loch Fyne',
#      'Lodge',
#      'Londis',
#      'London Place',
#      'London Road',
#      'Long Close',
#      'Long Hanborough Post Office',
#      'Long Leys Farm',
#      'Longlands Road',
#      'Longwall Quad Staircase 3',
#      'Louie Memorial Playing Field',
#      'Lower Farm Lane',
#      'Lower Whitley Farm',
#      "Lucky 777's",
#      'Lyndworth Mews',
#      'Lynn Close',
#      'Lynton Lane',
#      'M. Feller, Son and Daughter',
#      'MCR',
#      u'MTB Gro\xdfe Felsen-Runde',
#      'Magdalen Road',
#      'Magdalen Road Church',
#      'Magdalen Street',
#      'Maidcroft Road',
#      'Main Gate',
#      'Main Road',
#      'Maitland',
#      'Mandelbrote Drive',
#      'Manor Close',
#      'Manor Road Building',
#      'Manual Spring',
#      'Margaret Road',
#      'Market Street',
#      'Marks & Spencer',
#      'Marston Cyclepath',
#      'Marston Field Sports Pavilion',
#      'Marston Road',
#      'Marston Road Bungalow',
#      'Marston Road Car Park (Temporary)',
#      'Marston United Reformed Church',
#      'Martin Close',
#      "Martin's",
#      'Mary Powell House',
#      'Mary Price Close',
#      'Masons Road North',
#      'Mathews Way',
#      'Matthew Arnold School',
#      'Mayfair Road',
#      'Mayfield Road',
#      'Maywood Road',
#      "McDonald's",
#      'McMarti Hair',
#      'Meadow Lane',
#      'Meadow Lane Recreation Ground',
#      'Meadow View Road',
#      'Meadow Way',
#      'Medemblik',
#      'Medical Sciences Teaching Centre',
#      'Merewood Avenue',
#      'Merton College Sports Ground',
#      'Merton Court',
#      'Mickle Way',
#      'Mill End',
#      'Mill Farm',
#      'Mill Lane',
#      'Mill Street',
#      'Mill Street Shops',
#      'Millwood Vale',
#      'Milton Crescent',
#      'Minns Industrial Estate',
#      'Mission Burrito',
#      'Mob Quad Staircase 1',
#      'Mob Quad Staircase 6',
#      'Modern Art Oxford',
#      'Moorbank',
#      'Moreton Road',
#      'Morgan Cole Solicitors',
#      'Morrell Avenue',
#      'Mortimer Drive',
#      'Mothercare',
#      'Mount Place',
#      'Mount Pleasant',
#      'Museum Road',
#      'Music',
#      'Music Room',
#      'Nalgeos',
#      "Nando's",
#      'Nash Court',
#      'National Forest Development Road 5283',
#      'National Grid Cowley-Seven Springs',
#      'Nawabi',
#      'Nether Durford Close',
#      'Netherton Road',
#      u'New Biochemistry Caf\xe9',
#      'New Building',
#      'New Building Lawns',
#      'New Buildings Quad Staircase 3',
#      'New College Sports Ground',
#      'New Cross Road',
#      'New Farm',
#      'New Hinksey',
#      'New Quad',
#      'New Radcliffe House',
#      'New Road',
#      'New Testament Church of God',
#      'Newland Close',
#      'Newlin Close',
#      'Newport Close',
#      'Newton Road',
#      'Nightingale Avenue',
#      'Nixon Road',
#      'Norham Gardens',
#      'Norham Manor',
#      'Normandy Crescent',
#      'Norreys Avenue',
#      'North Hinksey Lane',
#      'North Place',
#      'North Quad Staircase 5',
#      'North Way',
#      'Northern By-pass Road',
#      'Northfield Brook',
#      'Northmoor',
#      'Northway Workshops',
#      'Nothing',
#      'Nourse Close',
#      'Nowell Road',
#      'Nuffield Arms',
#      'Nuffield Orthopaedic Centre',
#      'Nuffield Orthopaedic Reception',
#      "O'Neill's",
#      'O2',
#      'Oak Avenue',
#      'Oak Drive',
#      'Oaks',
#      'Oaksmere',
#      'Oasis Dental Care',
#      'OhreBus',
#      'Old Black Horse Inn',
#      'Old Botley',
#      'Old Buildings',
#      'Old Greyfriars Street',
#      'Old Library',
#      'Old Lodge',
#      'Old Marston Library',
#      'Old Old Hall',
#      'Old Road',
#      'Old Stables',
#      'Orchard Way',
#      'Orthopaedic Centre',
#      'Osborne Close',
#      'Osler Road',
#      'Osney Mead',
#      'Otters Reach',
#      'Overbrook Gardens',
#      'Overmead Green',
#      'Owens Way',
#      'Oxfam Bookshop',
#      'Oxford',
#      'Oxford (Cowley) Driving Test Centre',
#      'Oxford Bus Company',
#      'Oxford Canal',
#      'Oxford Castle Mound',
#      'Oxford Centre for Mission Studies',
#      'Oxford Christian Spiritualist Church',
#      'Oxford City Boundary Stone',
#      'Oxford FE College',
#      'Oxford Print Centre',
#      'Oxford Rail Station',
#      'Oxford Road',
#      'Oxford Rugby Football Club',
#      'Oxford to Bicester Line',
#      'Oxford-Aynho',
#      'Oxfordshire History Centre',
#      'Oxpens Road',
#      'Oyapock',
#      'Palm House',
#      'Pandora',
#      'Park End Street',
#      'Park Lane',
#      'Park Town',
#      'Park and Ride',
#      'Parker Road',
#      'Parklands',
#      'Parry Close',
#      'Peartree Close',
#      'Pebblehill Mob Pk',
#      'Pegasus Road',
#      'Pegasus Theatre',
#      'Pegtop Farmhouse Bed and Breakfast',
#      'Pembroke College',
#      'Pen to Paper',
#      'Penny Farthing Place',
#      'Penny farthing Mall',
#      "Pepper's Burgers",
#      'Perkins',
#      'Persia Beauty',
#      'Pettiwell',
#      'Pheasant Walk',
#      'Pigeon House Lane',
#      'Pinkhill Lane',
#      'Playground',
#      'Ploughley Close',
#      'Podarok',
#      'Polecat End Lane',
#      'Police Station',
#      'Portabello',
#      'Porter',
#      "Porters' Lodge",
#      'Portland Road',
#      'Post Office',
#      'Pound Lane',
#      'Premier Inn',
#      'Prezzo',
#      'Primrose Place',
#      'Priory of Saint John Baptist',
#      'Prospect Park',
#      'Pryor Cement Industrial Lead',
#      'Public Car Park 3',
#      'Pullens Lane',
#      'Pure Indulgence',
#      'Quarry High Street',
#      'Quarry Hollow',
#      'Queen Street',
#      'Queens Lane',
#      'Radcliffe Camera Male',
#      'Radcliffe Infirmary',
#      'Radley',
#      "Ragnall's Lane",
#      'Ramsay Road',
#      'Reception',
#      "Rector's Lodgings",
#      'Red Lion',
#      'Red Lion PH',
#      'Red Opia',
#      'Redfield Pet Supplies',
#      'Reliance Way',
#      'Restore',
#      'Rewley Road',
#      'Rhodes Pavilion',
#      'Rickyard Close',
#      'Ridgeway Skoda',
#      'Ridley Road Play Area',
#      'Riley House',
#      'Rio de Contas',
#      'Rippington Drive',
#      'River Quad',
#      'River Thames',
#      'Roads heavily reconfigured for construction.',
#      'Roger Bannister',
#      'Rogers Auto Factors LTD',
#      'Roman Way',
#      'Roosevelt Road',
#      'Rosamund Road',
#      'Rose Gardens',
#      'Rose Hill',
#      'Rose Hill Cemetery',
#      'Rose Hill Community Centre',
#      'Rose Hill Parade',
#      'Rose Isle',
#      'Rose Place',
#      'Rosenblatt Pool',
#      "Rosie's Grocery",
#      'Rotha Field Road',
#      'Rowan Grove',
#      'Royal Sun',
#      'Russell Street',
#      'Russian and Eurasian Studies Centre',
#      'Rutten Lane',
#      'Rutters Close',
#      'Rye St Antony Oxford',
#      'Rymers Lane Allotments 1653',
#      'SCR',
#      'SOUTHFIELD PARK FLATS 1661',
#      'SR Childs Funeral Services',
#      'Sacred Heart Church',
#      'Sadler Building',
#      "Sainsbury's Local",
#      "Saint Edward's School Golf Course",
#      'Saint Nicholas',
#      "Saint Peter's",
#      "Saint Peter's Road",
#      'Salegate Lane',
#      'Salesian Gardens',
#      'Salter Close',
#      'Sand Butte Wilderness Study Area',
#      'Sandfield Road',
#      'Sandford Brook',
#      'Sandford Gate',
#      'Sandford-on-Thames',
#      'Sandpit Walk',
#      'Sands Court',
#      'Sandswood Farm',
#      'Sandy Lane',
#      'Sandy Lane West',
#      'Sang Hing House',
#      'Santander',
#      'Savile House',
#      'Saxon Tower',
#      'Saxon Way',
#      u'Sa\xefd Business School',
#      'Scholar Place',
#      'School of Archaeology and Institute of Archaeology',
#      'School of Interdisciplinary Area Studies',
#      u'Schweringh\xe4user Bach',
#      'Science',
#      'Scott Road',
#      'Seacourt P&R',
#      'Seacourt Road',
#      'Seasons Delicatessen',
#      'Senli Cash & Go',
#      'Sermon Close',
#      'Seven Sisters Way',
#      'Sewage Works',
#      'Shakespeare Way',
#      'Shanghai House',
#      'Sheep Mountain Wilderness Study Area',
#      'Sheepway Court',
#      'Shelley Close',
#      'Sherard Road',
#      'Shirelake Close',
#      'Shotover Country Park',
#      'Shotover Hill',
#      'Shotover Kilns',
#      'Sidney Street',
#      'Silver Birches',
#      'Silver Road',
#      'Simpkins Lee Theatre',
#      'Sinclair',
#      'Sir William Dunn School of Pathology',
#      'SmallWorld Montessori School',
#      'Sobell House Hospice Shop',
#      'Sojo',
#      'South Hinksey Turn Northbound',
#      'South Stairs',
#      'South Stand',
#      'Southern By-pass Road',
#      'Southern Zone',
#      'Southmoor Road',
#      'Spar',
#      'Spire View',
#      'Spooner Close',
#      'Ss. Peter and Paul',
#      "St Aldate's",
#      'St Aldates',
#      "St Andrew's",
#      "St Anne's College Bar",
#      'St Barnabas Church',
#      'St Barnabas Street',
#      "St Bartholomew's Medical Centre",
#      "St Christopher's Place",
#      'St Clements Street',
#      "St Clements's",
#      "St Columba's Church",
#      'St Cross Road',
#      "St Ebba's Close",
#      'St Francis Court',
#      "St Giles'",
#      "St Giles' House",
#      "St Hugh's College",
#      "St James's Church",
#      "St Margaret's Road",
#      'St Mary and St John CE Primary School (Hertford Street Site)',
#      "St Michael's Street",
#      'St Omer Road',
#      "St Paul's Crescent",
#      "St Peter's",
#      "St Peter's Close",
#      'St Swithuns Primary School',
#      'St Thomas Day Nursery',
#      'St Thomas More R.C. Primary School',
#      'St Thomas the Martyr Churchyard',
#      'St. Giles',
#      'St. Marys',
#      "St. Michael's CE Aided Primary School",
#      "St. Michael's Church Cumnor",
#      'Stainer Place',
#      'Staircase 1',
#      'Staircase 11',
#      'Staircase 12',
#      'Staircase 14',
#      'Staircase 15',
#      'Staircase 18',
#      'Staircase 19',
#      'Staircase 2',
#      'Staircase 24',
#      'Staircase 25',
#      'Staircase 3',
#      'Staircase 32',
#      'Staircase 33',
#      'Staircase 4',
#      'Staircase 6',
#      'Staircase 7',
#      'Staircase XVIII',
#      'Stanton Harcourt Road',
#      'Stanton Little Wood',
#      'Starbucks',
#      'Starwort Path',
#      'Station Road',
#      'Staunton Road',
#      'Sterling Close',
#      'Stocksdorfer Graben',
#      'Stowford Farm',
#      'Stowford Road',
#      'Stratfield Road',
#      'Strawberry Path',
#      'Subway',
#      'Sugworth Lane',
#      'Sun Me',
#      'Sunningwell CE Primary School',
#      'Supa Sava',
#      'Sutherland',
#      'Sutton Lane',
#      'Swan Hotel',
#      'Swinbourne Road',
#      'Swinford Bridge',
#      'T94',
#      'TP0596',
#      'TP3833',
#      'TP6574',
#      'Tackley Place',
#      'Talbot Road',
#      "Tattoo Club of Great Britain / Lionel's Tattoo Studio",
#      "Taylor's",
#      'Teal Close',
#      'Teddy Edwards',
#      'Tern Walk',
#      'Thames View Road',
#      'Thatcher Business Education Centre',
#      'The Avenue',
#      'The Bathers',
#      'The Bear and Ragged Staff',
#      'The Big Bang',
#      'The Byre',
#      'The Cedars',
#      'The Co-operative Food',
#      'The Cooperative',
#      'The Covered Market',
#      'The Crescent',
#      'The Croft',
#      'The Cycle Shop & General Store',
#      'The Divinity School',
#      'The Excelsior',
#      'The Fox',
#      'The Gatehouse',
#      'The Glebe',
#      'The Green',
#      'The Iffley Yew',
#      "The King's Centre",
#      'The Kite',
#      'The Lion Brewery',
#      'The Magic Cafe',
#      'The Nosebag',
#      'The Nuffield Needle',
#      'The Octagon',
#      'The Old Court House',
#      'The Oxford Academy',
#      'The Oxford Centre for Diabetes, Endocrinology and Metabolism 2',
#      'The Oxford Hotel',
#      'The Paddocks',
#      'The Park',
#      'The Plain',
#      'The Plough PH',
#      'The Roundway',
#      'The Royal Standard',
#      'The Royal Sun',
#      'The Slade',
#      'The Stables',
#      'The University of Oxford Shop',
#      'The Vine Inn',
#      'The Wheatsheaf',
#      'The White Horse',
#      'The Willows',
#      'The Workshop Studio',
#      'Theology Faculty Annexe',
#      'Thistle Drive',
#      'Thomas White Staircase 7',
#      'Thornhill Park and Ride',
#      'Three',
#      'Tilbury Lane',
#      'To Restrauant',
#      'Town Furlong',
#      'Toys R Us',
#      'Transport Way',
#      'Tree Lane',
#      u'Trilha Ecol\xf3gica Morro do Macaco',
#      'Trotter Branch',
#      'Truck Store',
#      'Tubney Wood',
#      'Tucker Road',
#      'Tumbling Bay Cafe',
#      'Turl Street',
#      'Twofoot Nothing',
#      'UM - Up Main',
#      'Ulfgar Road',
#      'Union Street',
#      'University Administration and Services',
#      'Upper Barr',
#      'Upper Meadow',
#      'VOA',
#      'Vallis Alley',
#      'Vanburgh',
#      'Verbena Way',
#      'Versus',
#      'Vicarage Road',
#      'Victoria Road',
#      'Virgin Money',
#      'Visitors Car Park',
#      'Vivienne Court',
#      'WHSmith',
#      'Wainright',
#      'Waitrose',
#      'Walton Building',
#      'Walton Lane',
#      'Walton Well Road',
#      'Warburg Crescent',
#      "Warden's Lodgings",
#      'Wareham Stream',
#      'Warlands Botley Road Cycles',
#      'Warneford Hospital',
#      'Warneford Lane',
#      'Water Eaton Manor',
#      'Waterstones',
#      'Watlington Road',
#      'Ways Farm',
#      'Webbs Way',
#      'Weirs Mill Stream',
#      'Wellington Street',
#      'West Cornwall Pasty Co',
#      'West Cottage',
#      'West End',
#      'West Oxford Community Primary School',
#      'West Way',
#      'West Wing',
#      'Western By-pass Road',
#      'Westminster Way',
#      'Weston Library',
#      'Wharf Road',
#      'Wharton Road',
#      'Wheatley CE Primary School',
#      'Wheatley Road',
#      'Whitehall Building',
#      'Wick Close',
#      'William Morris Close',
#      'Williamson Way',
#      'Willow Walk',
#      'Willows Edge',
#      u'Willy-Brandt-Stra\xdfe',
#      'Wilsdon Way',
#      'Windsor Street',
#      'Winston Close',
#      "Woodin's Way",
#      'Woodlands',
#      'Woodperry Road',
#      'Woodstock Road',
#      'Worcester Street Car Park',
#      'Worton',
#      'Wycombe Railway',
#      'Wyevale Garden Centres',
#      'Wykeham Crescent',
#      'Wytham Stream',
#      'Wytham View',
#      'Wytham Woods Sawmill',
#      'X33',
#      'Y',
#      'Yarnton Road',
#      'Your Local Top Up Store',
#      'Zoal Phone Clinic',
#      ']static post frieght platform line[',
#      'basement door',
#      'binstore',
#      'constuction Support huts',
#      "gardener's compound",
#      'iwantgreatcare.org',
#      'main meeting hall',
#      'roads affected by Plain Junction roadworks for diversions and tempoarly changed restrictions',
#      'stockyard',
#      'temple street dentist',
#      u'\xc9cole Primaire Priv\xe9e Sainte-Marie',
#      u'\u0394\u03b7\u03bc\u03bf\u03c4\u03b9\u03ba\u03cc \u03a3\u03c7\u03bf\u03bb\u03b5\u03af\u03bf',
#      u'\u041c\u0430\u043b\u044b\u0448',
#      u'\u0433\u0441\u043a \u041a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432 \u043f\u043e\u0434\u0437\u0435\u043c\u043d\u044b\u0445 \u043e\u0432\u043e\u0449\u0435\u0445\u0440\u0430\u043d\u0438\u043b\u0438\u0449 \u0423\u0440\u043e\u0436\u0430\u0439 (\u041a\u043e\u043c\u0441\u043e\u043c\u043e\u043b\u044c\u0441\u043a\u0438\u0439 \u043f\u0440-\u043a\u0442, 22)',
#      u'\u043e\u0441\u0442\u0440\u043e\u0432 \u0420\u0435\u0439\u043d\u0435\u043a\u0435',
#      u'\u0e2d\u0e38\u0e17\u0e22\u0e32\u0e19\u0e41\u0e2b\u0e48\u0e07\u0e0a\u0e32\u0e15\u0e34\u0e14\u0e2d\u0e22\u0e1c\u0e32\u0e01\u0e25\u0e2d\u0e07',
#      u'\u6b66\u6f22\u5730\u94352\u865f\u7dda'])
#
#
# name:be
# set(['Europese wandelroute E2, UK', u'\u041c\u0430\u043b\u044b\u0448'])
#
#
# name:cy
# set(['Rhydychen'])
#
#
# name:de
# set([u'Europ\xe4ischer Fernwanderweg E2, UK',
#      'Kosciuszko-Nationalpark',
#      'Reineke-Insel'])
#
#
# name:en
# set(['Croft Road',
#      'Doi Pha Klong National Park',
#      'European long distance path E2 - part United Kingdom',
#      'Ferry Road',
#      'Marston Road',
#      'Mortimer Drive',
#      'Oxford Road',
#      'Reyneke Island'])
#
#
# name:fr
# set([u'Chemin de randonn\xe9e Europ\xe9en E2, UK', "L'Oyapock"])
#
#
# name:fy
# set(['Iselmar'])
#
#
# name:it
# set(['Isola di Rejneke'])
#
#
# name:nl
# set(['Europese wandelroute E2, UK', 'IJsselmeer'])
#
#
# name:note
# set(['North side buildings/footway is "London Place". Name given to footway. Road is single carriageway in reality, so should have one name.',
#      'not Magdalen Street West on the street signs'])
#
#
# name:ru
# set([u'\u0423\u041b \u041c\u0410\u0420\u0422\u041e\u041d-\u0420\u041e\u0414',
#      u'\u0423\u041b \u041c\u041e\u0420\u0422\u0418\u041c\u0415\u0420-\u0414\u0420\u0410\u0418\u0412',
#      u'\u0423\u041b \u041e\u041a\u0421\u0424\u041e\u0420\u0414-\u0420\u041e\u0414',
#      u'\u0423\u041b \u0424\u0415\u0420\u0420\u0418-\u0420\u041e\u0414',
#      u'\u0423\u041b \u0425\u0420\u041e\u0424\u0422-\u0420\u041e\u0414',
#      u'\u043e\u0441\u0442\u0440\u043e\u0432 \u0420\u0435\u0439\u043d\u0435\u043a\u0435'])
#
#
# name:th
# set([u'\u0e2d\u0e38\u0e17\u0e22\u0e32\u0e19\u0e41\u0e2b\u0e48\u0e07\u0e0a\u0e32\u0e15\u0e34\u0e14\u0e2d\u0e22\u0e1c\u0e32\u0e01\u0e25\u0e2d\u0e07'])
#
#
# note
# set(['"morning through to 11:30pm o\'clock-ish". geographic location varies along the long parking lane on the parkside of the road.',
#      '1 bed bungalow on a campus for residents of 55 years of age or older.',
#      '2 metres',
#      '3 Wheeler Robinson House',
#      'A coral of container unit type buildings and a generator or two.',
#      'A lot of tree cover when addinthis feature .',
#      'A non-primary road with a primary reference (A420). After discussion it was decided that we map what is there and this anomolous situation *is* what is there. If you want to change this, please discuss on the talk-GB mailing list first.',
#      'Access not 24/7. See park opening times',
#      'Access to Science Park: locked at night and weekends',
#      'Currently being used as a place of worship with a retrospective change of use planning application in.  Will change name= if/when the big signs outside change.',
#      'DfT data had this as shared use - dubious',
#      'Disabled access to Taylorian',
#      'Does the SU cycle track / footpath continue here?',
#      'FIXME: "squeezer" shoulder gate thingy (difficult to describe)',
#      'FIXME: incomplete',
#      'FIXME: position approximate',
#      'FIXME: unchecked',
#      'Free motorcycle parking in bays',
#      'Has medical facilities.',
#      'House numbers follow Eynsham Road pattern',
#      'I assume that the right of way is supposed to head west from here, but there is no path visible across field of crops.',
#      'I remeber sing carparking rup to the road so the green patches just south are liketo have gone too.  The site is earmarked by the University for expansion.',
#      'I think the building line on the east side is a little to much offset and based on a parralax room so the side walk could be a bit thinner.  - Yep it is an alignment problem I tried to move parts pf the college buildings just now and it was getting messy ',
#      "I'll fill in these details in a while but look at its counterpart at the east end of the same High street oxford.",
#      "I'm describing this as primarily a footway because it is narrow, unlit, overgrown, and there are signs telling cyclists to dismount every ten metres.",
#      "I'm going to add the user restictions soon.  I have to workout what they are and the latest tagging for them first.",
#      "I'm going to work out the missing details for this in the next edit..",
#      "I'm not happy with the proportions of this room I think I need to make major readjustments to the base shpes already drawn errors come from offset, confusing roof shapes and hights, and paralax with overhang issues. I can see what happened but its a lot",
#      'Imperica is a digital arts and culture magazine, part of Perini (www.perininetworks.com).',
#      'Inside the bank',
#      'Is signed Broadway, but addresses are The Broadway',
#      'It looks more like a wooden gate you have to climb over (2 rungs) rather than a traditional stile with steps.',
#      u'Kl\xe4ranlage',
#      'Land held by the church',
#      'Monday to Friday in term time only',
#      'National Byway not signposted but deduced from sections either side',
#      'Needs future update',
#      'Not an NCN RR (single-figure), but white-figures-on-a-blue-bg nonetheless; Not signposted beyond Redbridge',
#      'Not signposted',
#      'Not so much a department as a general university building',
#      u'Offizielle Zufahrt zu Kl\xe4ranlage, deshalb als highway=service eingetragen',
#      'On a strip of tactile paving in the "cycles" direction. Inconsistent with signage.',
#      'Only open when University Parks are open',
#      'Open-air river swimming',
#      'Parking for hospital patients and visitors only.',
#      'Part of Magdalen College',
#      'Part of a bike route, but narrow, curving, and with big hints to give way to pedestrians. Thus, "dismount".',
#      "Representing 2 sets, since we don't distringuish lanes on the side roads. They *are* toucans, right?",
#      'Rough trace',
#      'S5 omitted since very infrequent extension',
#      'Saturday opening term time only and subject to staff availability',
#      'Sheffield stands x2',
#      'Sign on gate indicates that the no-bikes by-law will be enforced inside the park for footpaths',
#      "Sign reads 'First Turn Wolvercote'",
#      'Site was part of the large goverment complex and has been used a lot by people working at the buildingsite over the road upto about 2013-2014ish.  Now a partly developed council carpark.',
#      'St Edmund Hall Accomodation',
#      'Steps up to entrance.',
#      'Surveyed at village end and route approximated',
#      'TSRGD 951 (Riding of pedal cycles prohibited) and painted instruction to dismount at both ends 2012-08-28',
#      'Temporary/Experimental closure',
#      'Thames Water',
#      "There's two of them, and that's what they look like.",
#      'These tags are for a advice service that uses this building used also by other organisations. I tied them to a node on the building so they be separately machine read more easily until a scheme for all the users of the building is arranged. pointcan=logo',
#      'They accept males but only between 4 and 8.',
#      'This entrance is for the 2 businesses upstairs',
#      'This outline is a rough sketch; it needs a better match made.',
#      'This region of the road has always been Bartlemas close since the naming of the close.',
#      'This relation is for roadways marked with Historic US 66 shields, whether or not they were actually US 66. If you want to mark that a road was US 66, use the old_ref tag.',
#      'This side is merely a little alphanumeric code sign.',
#      'This was reorganised a few years ago and some cyclepaths removed as they were too confusing and under used',
#      'Unofficial link to Southfield Golf Course diverges here',
#      'Up for sale as of 20090829',
#      'Used to be Clovers',
#      'Wall type in brick pillar',
#      'Ways complete. Stops currently unnumbered and incomplete.',
#      'actually somewhat simplified...',
#      'all details copied from deleted node 27639133',
#      'almost jumpable, but not quite',
#      'annex to other building',
#      'approximate outline only - will need checking',
#      'being rebuilt',
#      'bicycle restriction (but not motorcar restriction) between 10:00 and 18:00 - cannot currently represent this Lorries can run though as part of the Western Zone but due to one way have to leave via the Southern Zone. PSV (local only?) also still run though',
#      'bicycle status is dubious',
#      'bus_stand is like a stop but allows in oxford a bus to park awaiting a later return to service.',
#      'check highest level again',
#      'checked ref it rlates to the whole double sided hoop sign stand.',
#      'closed when dark',
#      'does this stop exist?',
#      "eastside is hidden under tress and may go further than i've shown at present",
#      'entrance level but narrow; needs to be checked',
#      'extra-city exercise route',
#      'former church',
#      'frontof garage point between 40&38',
#      "going to recheck but the speed limit dosen't apply automaticaly on this private road",
#      'has extension over active garage.',
#      'heavily overgrown and impassable - probably supposed to connect with way 35036904',
#      'its been here some months and expanded after a fire broke out during the renovation works.  The hotel never closed and says it will be finshed in the very near future psibly next month.',
#      'line of desire (actually laid like that)',
#      'might just count as track type5',
#      'name /sic/',
#      'no longer served',
#      'no pole; name assumed same as others; services inferred',
#      'not open 24hrs. Gate is locked when all of the health centres are closed.',
#      'note this a covered staircase built outside the building to reach the upstairs front door. another fornt door for the lower property is below upper one.',
#      'only a bashed up pole has remained here.  There was to much illegal parking here that the lorries had to cut this conner to squeeze by parked cars and vans.  The council has been slow to replace the sign an the grass beneath still seems to be being  ',
#      'padlocked open currently',
#      'passage thru',
#      'probably a enclosed corridor between two buildings',
#      'quacks like a roundabout!',
#      'reedbed',
#      u'rela\xe7\xe3o est\xe1 de acordo com a nova lei em vig\xeancia no Estado e que diverge momentaneamente do IBGE, at\xe9 o mesmo se atualizar.',
#      "remove this tag and the interpolated way when road resurveyed - too many houses suggest an 'a' somewhere in the middle.",
#      'road permissions alter in differnt ways between day and night and bulding phases alert road users to look for signs early when headin north - West on B480, A4158 and A420 towards the plain early to look for the small roadside diversion signs.',
#      'route closed along with all upstairs offices',
#      'see other side for info',
#      'serves private yard',
#      'shared escape route.',
#      'side pillers removed and wohle side left open in the last 15 years',
#      'sign marking extent of place',
#      'signpost marking place boundary',
#      'steps from 11 kV (rms, 3 phases) to 415 V (rms, 3 phases or 240 V rms 1 phase)',
#      "there are or have been two 66's this due to accessability issues of the user {numbering has a reflection on owners address in this area.",
#      'this is the first part to get a lot of desktops and was used to lower the noise I think',
#      'this line serve an old postal and freight only platform and is designated in NESA as sidings.  An old freight wagon is in use a store room on the easterly platform but is sue to be removed by plans of chiltern railways.',
#      'this site I think is used by gas and water with other services a few meters away.',
#      'two bus companies, two names...',
#      'unfinished',
#      'user-operated',
#      'was Chelsea bank currently looking to be converted to reastuant under planning permission: 14/01091/FUL its been apprved but may be in an appel phase. Oxford.gov.uk',
#      'was the old bin store'])
#
#
# note:2
# set(['Last night for example west traffic from the A420 was turned @ Dawson Street (made specilly one way);south-east upo the B480 to Circus St {specially one way} then let North west to the plain up the A4158.  Traffic running to the east  along the A420 was',
#      'eroded by bad drivers. there is another sign futher in (up on the right bank) and a lot of new yellow lining.  Police with Council have regulaly allowed permission for obstucting vehicals to be  towed away by garage users with out futher warning..',
#      'so I reversed the changes for now.',
#      'those were mainly on the otherside of the road this divert to rad termination was made the end of the widened pavement stretch and the cycleway_guide added after accidents.'])
#
#
# note:3
# set(['diverted at Stockmore St {specialy one way}dogleged along the B480 and along Jeune St before resumeing to the A420 past the works.  This morning traffic flowed round the junction from all 5 routes with peddestiran diversions close to the junction.'])
#
#
# note:4
# set(["Temple St was used last week to take northbound A4158 traffic via B480. and eralier still traffic was one wayed  though Dawson St and temple street to take trafic Westbound A4158 traffic andtraffic west bound for the B480 and A4158 along withNorthlyB480's"])
#
#
# note:5
# set(['Bus and taxi route equally affected, allowing some unusal scenes of them turning in and out of the small roads {hence parking restictions and one waying}'])
#
#
# note:alt_name
# set(['for spelling only'])
#
#
# note:frequency
# set(['peak only afaics'])
#
#
# note:name
# set(['Maybe Friars Wharf, but no sign', 'both signs say London Place'])
#
#
# note:reply
# set(["j5 dosn't but other moves possible see note:reply on stope j4 to the east of here."])
#
#
# oneway
# set(['no', 'yes'])
#
#
# oneway:bicycle
# set(['no'])
#
#
# oneway:note
# set(['not technically one way, actually'])
#
#
# oneway:reverse
# set(['adjacent', 'block'])
#
#
# opening_hours
# set(['Mo 14:00-18:00; Tu 14:00-16:30; Th 09:30-12:30,14:00-16:30; Fr 09:30-12:30; Sa 09:30-13:30',
#      'Mo-Fr 07:00-17:30; Sa 07:30-12:00',
#      'Mo-Fr 08:30-17:30;Sa 09:00-17:15',
#      'Mo-Fr 08:30-20:30',
#      'Mo-Fr 09:00-17:00; Sa 10:00-14:00',
#      'Mo-Fr 9:00-13:00,14:00-17:00',
#      'Mo-Sa 07:00-19:00; Su 08:00-18:00',
#      'Mo-Sa 07:00-20:00; Su 07:00-18:00',
#      'Mo-Sa 07:00-22:00; Su 10:00-16:00',
#      'Mo-Sa 08:30-17:30; Su 10:00-16:00',
#      'Mo-Su 06:00-18:00',
#      'Mo-Su 07:00-18:00',
#      'Mo-Su 07:00-23:00',
#      'Mo-Su 08:00-24:00',
#      'Mo-Su 12:00-24:00',
#      'Mo-Th 10:00-17:00; Fr-Sa 09:30-17:30; Su 11:00-16:00',
#      'Mo-We 11:00-22:00; Th-Sa 11:00-23:00; Su 11:00-22:00',
#      'Tu-Fr 09:00-17:00; Sa-Su 10:00-15:00',
#      'Tu-Sa 11:00-18:00; Su 12:00-17:00',
#      'Tu-Th 09:30-17:30; Sa 09:30-18:00',
#      'mo-sa 08:00-18:00; su 10:00-16:00'])
#
#
# opening_hours:morning
# set(['yes'])
#
#
# operator
# set(['Ahlul Bayt Centre',
#      'All Souls College',
#      'BLM',
#      'BP / Budgens',
#      'Balliol College',
#      'Barclays Bank PLC',
#      'Block landlord',
#      'Buswell Parks',
#      'Cancer Research UK',
#      'Chiltern Railways',
#      'Christ Church',
#      'Churchill Hospital',
#      'Cooperative',
#      'Corpus Christi College',
#      'DB Bahn Westfalenbus',
#      'Elder Stubbs Charity',
#      'Esso',
#      'European Ramblers Association',
#      "G&D's",
#      'GSBikeshare',
#      'GreenSquare',
#      'Greene King',
#      'Greene King Pub Company',
#      'Halifax',
#      'Hertford College',
#      'Highways Agency',
#      'Jewson',
#      'Jewsons Skoda Oxford',
#      'KFC',
#      'Kellogg College',
#      'Kreis Borken',
#      'Lloyds',
#      'Lloyds Bank',
#      'Londis',
#      'Magdalen College',
#      "McDonald's",
#      'Mercure Eastgate Hotel',
#      'Merton College',
#      'Morrisons',
#      "Nando's",
#      'National Grid',
#      'Naturpark Schwarzwald Mitte/Nord e.V.',
#      'Network Rail',
#      'New College',
#      'Norfolk Southern Railway',
#      'OhreBus Verkehrsgesellschaft mbH',
#      'Old Bakehouse Trust Ltd',
#      'Old Road Campus',
#      'One Stop',
#      'Oxfam',
#      'Oxford Brookes University',
#      'Oxford Bus Company',
#      'Oxford City Council',
#      'Oxford County Council',
#      'Oxford Urban Wildlife Group',
#      'Oxfordshire Blue Plaques Board',
#      'Oxfordshire County Council',
#      'Oxfordshire Mind',
#      'Premier Inn',
#      'RBS',
#      'RBSs',
#      'Royal Mail',
#      'Royal Society of Chemistry',
#      'STAR',
#      "Sainsbury's",
#      'Santander',
#      "Scholars' Semester in Oxford",
#      'Scotish and Southern Electric Plc.',
#      'Shell',
#      'Siga',
#      'Society of the Sacred Heart',
#      'Somerville College',
#      'Southern Electric Company',
#      "St Antony's College",
#      'St Edmund Hall',
#      'Stagecoach',
#      'Thames Travel',
#      'The Hotel Collection',
#      'The Midcounties Co-operative',
#      "The Queen's College",
#      'Turf Tavern',
#      u'UHV 32 Gro\xdfe Aue',
#      'University College',
#      'University of Oxford',
#      'VBN',
#      'Wadham College'])
#
#
# operator:be
# set(['Grote Routepaden'])
#
#
# operator:catagory
# set(['Class 1', 'Class 3', 'class1'])
#
#
# operator:fr
# set([u'F\xe9d\xe9ration Fran\xe7aise de la Randonn\xe9e P\xe9destre'])
#
#
# operator:lux
# set([u'D\xe9partement Du Tourisme'])
#
#
# operator:nl
# set(['Stichting Wandelplatform'])
#
#
# operator:type
# set(['private'])
#
#
# operator:uk
# set(['Long Distance Walkers Association'])
#
#
# parking
# set(['entrance', 'multi-storey', 'space', 'surface', 'underground'])
#
#
# parking:condition:both
# set(['no_stopping'])
#
#
# parking:condition:both:garage_users
# set(['loading_only'])
#
#
# parking:lane:left
# set(['to be completed'])
#
#
# parking:lane:right
# set(['no_parking'])
#
#
# parking:left
# set(['roadside'])
#
#
# parking:note
# set(['left is [DV] on street only'])
#
#
# proposed
# set(['yes'])
#
#
# proposed:electrified
# set(['contact_line'])
#
#
# proposed:frequency
# set(['50'])
#
#
# proposed:voltage
# set(['25000'])
#
#
# public_transport
# set(['pay_scale_area', 'station', 'stop_place'])
#
#
# public_transport:version
# set(['2'])
#
#
# railway
# set(['buffer_stop',
#      'crossing',
#      'disused',
#      'level_crossing',
#      'rail',
#      'station',
#      'subway',
#      'tram'])
#
#
# railway:traffic_mode
# set(['freight'])
#
#
# ref
# set(['11',
#      '12',
#      '124',
#      '13B',
#      '19',
#      '2015',
#      '233',
#      '239',
#      '277',
#      '4B',
#      '4TE',
#      '4TE 27',
#      '5',
#      '503',
#      '6',
#      '66',
#      '69323242',
#      '69325292',
#      '69325428',
#      '69325498',
#      '69325659',
#      '69326469',
#      '69326526',
#      '69327528',
#      '69329287',
#      '69345357',
#      '7',
#      '780',
#      '8',
#      '8S',
#      '9',
#      'A11',
#      'A338',
#      'A34',
#      'A40',
#      'A4074',
#      'A4095',
#      'A4142',
#      'A4144',
#      'A4158',
#      'A4165',
#      'A420',
#      'A421',
#      'A423',
#      'A4260',
#      'A44',
#      'AT',
#      'B 4',
#      'B13',
#      'B4017',
#      'B4027',
#      'B4150',
#      'B4495',
#      'B480',
#      'B5106',
#      'C A-1',
#      'E2',
#      'FORES1ZZ',
#      'G360',
#      'G371',
#      'GA5',
#      'GW200',
#      'GW260',
#      'K 2',
#      'O1',
#      'O3',
#      'O4',
#      'OX1 100',
#      'OX1 118',
#      'OX1 131',
#      'OX1 215',
#      'OX1 319',
#      'OX1 622',
#      'OX2 204',
#      'OX2 234',
#      'OX2 290',
#      'OX2 38',
#      'OX2 443',
#      'OX2 61',
#      'OX2 628',
#      'OX2 65',
#      'OX2 693',
#      'OX29 15',
#      'OX29 400',
#      'OX3 211',
#      'OX3 351',
#      'OX3 41',
#      'OX3 541',
#      'OX3 546',
#      'OX3 576',
#      'OX3 594',
#      'OX3 63',
#      'OX3 662',
#      'OX3 704',
#      'OX3 861',
#      'OX33 209',
#      'OX33 736',
#      'OX4 10',
#      'OX4 195',
#      'OX4 216',
#      'OX4 42',
#      'OX4 50',
#      'OX4 583',
#      'OX4 713',
#      'OX4 802',
#      'OX4 816',
#      'OX5 729',
#      'OX5 758',
#      'OX5 785',
#      'OX5 930',
#      'OXF',
#      'OXFD',
#      'Rymers Ln Allotments *2316534*',
#      'S75',
#      'SOUTHFIELD PARK FLATS 1661',
#      'T94',
#      'X33',
#      u'\u041d4495'])
#
#
# ref:NPLG:UPRN:1
# set(['100120819336', '100120845293'])
#
#
# ref:UAI
# set(['0850818C'])
#
#
# ref:bag
# set(['1883100000060844'])
#
#
# ref:ruian:building
# set(['42133319'])
#
#
# ref:sandre
# set(['O---0100'])
#
#
# ref:woonplaatscode
# set(['3151'])
#
#
# source
# set(['3dShapes',
#      ';Oxford City Council/Oxfordshire County Council Transport publications;site surveys',
#      'BAG',
#      'Bing',
#      'Bing and Local Knowledge',
#      'Bing, 2007/4',
#      'Bing, local knowledge',
#      'Bing; OS_OpenData_StreetView',
#      'Bing; local knowledge',
#      'Bing; survey',
#      'Bing; www.admin.ox.ac.uk',
#      'Bing; www.oxfordshire.gov.uk',
#      'Bing; www.pembrokebridgingcenturies.org',
#      'Bing;OS OpenData StreetView',
#      'Bing;OSM gps point cloud;Oxford City Council/Oxfordshire County Council Transport publications;site surveys',
#      'Bing;OSM_gps_data',
#      'Bing;OS_OpenData_StreetView',
#      'Bing;OS_OpenData_StreetView;yahoo_imagery',
#      'Bing;gps_survey',
#      'Bing;inference',
#      'Bing;local_knowledge',
#      'Bing;local_knowledge;inference',
#      'Bing;local_knowledge;website',
#      'Bing;osm_gps_points',
#      'Bing;osm_gps_points;local_knowledge',
#      'Bing;photograph',
#      'Bing;photograph;local_knowledge',
#      'Bing;survey',
#      'Bing;survey;yahoo_imagery',
#      'CANVEC',
#      'DOP from WMS at geodaten.bayern.de',
#      'GPS',
#      'GPS Survey',
#      'GPS; NPE',
#      'GSI ortorectified',
#      'Geoimage.at MaxRes',
#      "I've used this room since the end of 1999AD",
#      'IBGE',
#      'LPI Base Map December 2015 for some!',
#      'Local Knowledge',
#      'Maps4BW, LGL, www.lgl-bw.de',
#      u'NESA(Supplement No. 20 \u2013 07 September 2013)',
#      'NPE',
#      'NPE;survey;yahoo_imagery',
#      'NPE;yahoo_imagery',
#      'NRCan-CanVec-10.0',
#      'Name plate',
#      'OS OpenData StreetView',
#      'OS OpenData StreetView/survey west end/interpolation',
#      'OS Opendata Streetview',
#      'OS_OpenData_Boundary-Line',
#      'OS_OpenData_BoundaryLine',
#      'OS_OpenData_Locator',
#      'OS_OpenData_StreetView',
#      'OS_OpenData_StreetView;Bing',
#      'OS_OpenData_StreetView;yahoo_imagery;local_knowledge',
#      'OS_OpenData_VectorMapDistrict',
#      'Oxford City Parks Department',
#      'PGS',
#      'Personal knowledge',
#      'RABA-KGZ',
#      'Site visit today.',
#      'Yahoo',
#      'audio+gps_survey;Bing',
#      'bing',
#      'bing;survey',
#      u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Finances Publiques - Cadastre. Mise \xe0 jour : 2016',
#      'cuzk:ruian',
#      u'data.gouv.fr:\xc9ducation Nationale - 04/2014',
#      'gps',
#      'gps_survey',
#      'gps_survey;Bing',
#      'gps_survey;inference',
#      'gps_survey;naptan_import',
#      'gps_survey;photograph',
#      'gps_survey;yahoo_imagery',
#      'gps_trace',
#      'historical',
#      'http://wiki.openstreetmap.org/wiki/Import/Catalogue/Strassen_NRW',
#      'http://www.ratchakitcha.soc.go.th/DATA/PDF/2550/A/031/33.PDF',
#      'inference',
#      'landsat',
#      'landsat,memory',
#      'local knowledge, Bing',
#      'local_knowledge',
#      'local_knowledge;Bing',
#      'naptan_import',
#      'naptan_import;photograph',
#      'naptan_import;survey',
#      'nlc',
#      'npe',
#      'osm_gps_data;Bing',
#      'osm_gps_points;Bing',
#      'photograph',
#      'photograph; gps_survey; photograph',
#      'photograph;Bing',
#      'photograph;NPE;local_knowledge',
#      'photograph;gps_survey',
#      'photograph;local_knowledge',
#      'photograph;yahoo_imagery',
#      "reastaunt's website",
#      'servey; operator website.',
#      'sign at N end, NPE + Yahoo',
#      'site_survey',
#      'sitevisit',
#      'supplied to OSM from Oxford CAB',
#      'survery',
#      'survey',
#      'survey 2/2016',
#      'survey and council',
#      'survey;Bing',
#      'survey;bing',
#      'survey;inference',
#      'survey;photograph',
#      'survey;yahoo_imagery',
#      'surveys;bing',
#      'view.',
#      'visit',
#      'visual survey;bing',
#      'website',
#      'www.npemap.org.uk',
#      'yahoo',
#      'yahoo + gpx',
#      'yahoo;Bing;gps_survey',
#      'yahoo_imagery',
#      'yahoo_imagery;Bing',
#      'yahoo_imagery;OS_OpenData_StreetView',
#      'yahoo_imagery;gps_survey',
#      'yahoo_imagery;inference',
#      'yahoo_imagery;local_knowledge',
#      'yahoo_imagery;photograph',
#      'yahoo_imagery;photograph;inference',
#      'yahoo_imagery;survey;Bing'])
#
#
# source:access
# set(['local_knowledge', 'photograph'])
#
#
# source:addr
# set(['besko.e-mapa.net', 'emuia.gugik.gov.pl', 'survey'])
#
#
# source:addr:housenumber
# set(['survey'])
#
#
# source:addr:postcode
# set(['OS Codepoint'])
#
#
# source:alt_name
# set(['inference, Oxford 20mph zone RTO Schedule 1',
#      'photograph (of bus stop);naptan_import'])
#
#
# source:bicycle
# set(['photograph'])
#
#
# source:building
# set(['Bing', 'OS_OpenData_StreetView', 'bing', 'gps_survey'])
#
#
# source:capacity
# set(['Bing+existing OSM data'])
#
#
# source:covered
# set(['survey'])
#
#
# source:date
# set(['2015-12-31', '2016-02-25', '2016-03-03'])
#
#
# source:designation
# set(['definitive_statement'])
#
#
# source:geometry
# set(['Bing',
#      'geoportal.gov.pl, GPS',
#      'maps4bw (LGL, www.lgl-be.de); Mapbox Satellite',
#      'survey'])
#
#
# source:highway
# set(['photograph', 'signpost'])
#
#
# source:maxspeed
# set(['GB:nsl_dual',
#      'GB:nsl_single',
#      'Stats19/interpolation',
#      'UK:nsl_dual',
#      'UK:nsl_single',
#      'sign'])
#
#
# source:name
# set(['ITO OSL',
#      'MT 2014 Staff newsletter and http://beomino.blogspot.co.uk/2010/01/getting-sorted.html',
#      'NPE',
#      'OS Locator',
#      'OSL',
#      'OS_OpenData_Locator',
#      'OS_OpenData_StreetView',
#      'OS_OpenData_Streetview',
#      'gps_survey',
#      'inference, Oxford 20mph zone RTO Schedule 1',
#      'landsat',
#      'local knowledge',
#      'local_knowledge',
#      'photograph',
#      'photograph (street name sign)',
#      'photograph;memory of an oddly-spelled name',
#      'road sign'])
#
#
# source:oneway
# set(['photograph'])
#
#
# source:operator
# set(['photograph'])
#
#
# source:position
# set(['Bing'])
#
#
# source:postcode
# set(['Codepoint', 'OS_OpenData_CodePoint'])
#
#
# source:ref
# set(['OS OpenData StreetView',
#      'definitive_statement',
#      'inference, Oxford 20mph zone RTO Schedule 1',
#      'local knowledge'])
#
#
# tourist_bus
# set(['destination', 'no'])
#
#
# tourist_bus:conditional
# set(['no @ (10:00-18:00 AND occupants>8)'])
#
#
# traffic_sign
# set(['Text', 'UK:610', 'yes'])
#
#
# traffic_sign:2
# set(['UK:610'])
#
#
# wheelchair
# set(['limited', 'no', 'on request', 'yes'])
#
#
# wheelchair:description
# set(['Automatic doors. Accessible toilet on main level, other toilets downstairs.'])

# %% [markdown]
# ### 2. Multiple colons

# %% [markdown]
# There are also some "k" values that contain more than one colon. Some resolution is necessary here too. As before, let's check all values that are subject to this problem. Since many of such "k" values appear in the list above (of those with multilevel appearance), we can focus only on the non-overlapping values.

# %%
# Getting "k" values that contain more than one colon

lower_many_colons = re.compile(r'^([a-z]|_)*:([a-z]|_)*:')

k_many_colons = []
for key in all_k_list:
    if lower_many_colons.search(key) \
            and key not in k_multilevel:  # To prevent redundancy in correction
        k_many_colons.append(key)
k_many_colons.sort()
k_many_colons
# Out:
# ['addr:city:simc',
#  'addr:substreet:1',
#  'addr:substreet:2',
#  'not:name:note',
#  'organisation:affiliation:National',
#  'organisation:affiliation:region']

# %% [markdown]
# Thankfully, there remain just a handful of problem values. Let's take a look at what "v" values each of these problem "k" values contains.

# %%
k_many_colons.sort()

for problem_key in k_many_colons:
    print problem_key
    pprint.pprint( all_k_v_dict[problem_key] )
    print "\n"
# Out:
# addr:city:simc
# set(['0440325'])
#
#
# addr:substreet:1
# set(['12', 'Hilltop Court', 'York Place'])
#
#
# addr:substreet:2
# set(['Anchor Court'])
#
#
# not:name:note
# set(['looks a lot like a typo, not c100% confirmed'])
#
#
# organisation:affiliation:National
# set(['The Citizens Advice service/Mae gwasanaeth Cyngor ar Bopeth'])
#
#
# organisation:affiliation:region
# set(['Consortium of Oxfordshire CAB'])

# %% [markdown]
# ## Classifying Problem "k" Values

# %% [markdown]
# It would be ideal to individually audit all these problem "k" values and their corresponding "v" values, and come up with new, more efficient labeling/classification schemes (ideally, of two-level since this seems to the standard followed and suggested by OpenStreetMap). But for actual implementation, we need a programmatic default method to resolve these problems. After all, the list of problem "k" values we see here is derived from a *sample* of the original data set, and we cannot be certain that it is exhaustive - hence the need for a programmatic solution.
#
# In order to retain as much information in the original data set as possible, we need to deploy a data model/structure that is flexibly nest-able. With a flexible data model that (almost) fully captures information in the original data set, we can later resume our data cleaning if needed. The first step to developing such a flexible data model is to further classify the problem "k" values so that a solution can be devised for each category.

# %%
# Writing a function that classifies problem "k" values


def classify_k_multilevel(file_name):
    
    # Get the list of all unique "k" values
    all_k_v_dict = audit_k_v(file_name, ["node", "way", "relation"])
    all_k_list = all_k_v_dict.keys()
    
    # Classify "k" values according to colon inclusion
    k_lower = list()
    k_lower_colon = list()
    k_lower_colon_colon = list()
    for key in all_k_list:
        if lower.search(key):
            k_lower.append(key)
        elif lower_colon.search(key):
            k_lower_colon.append(key)
        elif lower_colon_colon.search(key):
            k_lower_colon_colon.append(key)
    
    ## Identify "k" values with no colon that appear 
    ## in other "k" values with a colon or two
    k_multilevel_one = set()
    for key_one in k_lower:
        key_single_colon = key_one + ":"
        for key_two in k_lower_colon:
            if key_two.startswith(key_single_colon):
                k_multilevel_one.add(key_one)
                break
        for key_three in k_lower_colon_colon:
            if key_three.startswith(key_single_colon):
                k_multilevel_one.add(key_one)
                break
    
    ## Identify "k" values with one colon that appear 
    ## in other "k" values with two colons
    k_multilevel_two = set()
    for key_two in k_lower_colon:
        key_double_colon = key_two + ":"
        for key_three in k_lower_colon_colon:
            if key_three.startswith(key_double_colon):
                k_multilevel_two.add(key_two)
                break
    
    return (k_multilevel_one, k_multilevel_two)

# %%
k_multilevel_one, k_multilevel_two = classify_k_multilevel(SAMPLE)

# %%
# "k" values with no colon that appear in other "k" values with a colon or two
k_multilevel_one
# Out:
# {'access',
#  'amenity',
#  'area',
#  'bicycle',
#  'building',
#  'bus',
#  'capacity',
#  'colour',
#  'cycleway',
#  'disused',
#  'footway',
#  'garden',
#  'is_in',
#  'landuse',
#  'lanes',
#  'lcn',
#  'level',
#  'maxspeed',
#  'maxweight',
#  'motor_vehicle',
#  'name',
#  'note',
#  'oneway',
#  'opening_hours',
#  'operator',
#  'parking',
#  'proposed',
#  'public_transport',
#  'railway',
#  'ref',
#  'source',
#  'tourist_bus',
#  'wheelchair'}

# %%
# "k" values with one colon that appear in other "k" values with two colons
k_multilevel_two
# Out:
# {'addr:city',
#  'building:levels',
#  'cycleway:left',
#  'cycleway:right',
#  'not:name',
#  'source:addr'}
