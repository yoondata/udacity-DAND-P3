# %%
import os
os.chdir("..")

# %%
import xml.etree.cElementTree as ET
import audit as AD
import transform as TF
import pprint
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
lower_colon_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SAMPLE = "oxford_sample.osm"
CREATED = [ "version", "changeset", "timestamp", "user", "uid" ]

k_multilevel_one, k_multilevel_two = AD.classify_k_multilevel(SAMPLE)

# %%
## Defining a new class for the deeper nested structure 
## of the output dictionary ("document" in MongoDB)


class AutoVivification(dict):
    '''
    Implementation of perl's autovivification feature
    
    Reference:
    http://stackoverflow.com/questions/2600790/multiple-levels-of-collection-defaultdict-in-python
    '''
    def __getitem__(self, item):
        try:
            return dict.__getitem__(self, item)
        except KeyError:
            value = self[item] = type(self)()
            return value

# %%
def shape_element(element):
    doc = AutoVivification()
    if element.tag in ["node", "way", "relation"]:
        
        # Identify the category
        doc["category"] = element.tag
        
        # Check if the "pos" key should be created
        if "lat" in element.keys():
            doc["pos"] = [0, 0]
        
        # Process same-level attributes
        for attrib_name in element.keys():
            if attrib_name in CREATED:
                doc["created"][attrib_name] = element.attrib[attrib_name]
            elif (attrib_name == "lat"):
                doc["pos"][0] = float( element.attrib[attrib_name] )
            elif (attrib_name == "lon"):
                doc["pos"][1] = float( element.attrib[attrib_name] )                
            else:
                doc[attrib_name] = element.attrib[attrib_name]
        
        # Process lower-level "tag" attributes
        if (element.find("tag") != None):
            
            # Make modifications
            for tag in element.iter("tag"):
                key = tag.attrib["k"]
                value = tag.attrib["v"]
                if not problemchars.search(key):
                    
                    # Clean and shape data related to address
                    if key.startswith("addr:"):
                        addr_key, addr_val = TF.transform_address_k_v(key, value)
                        doc["address"][addr_key] = addr_val
                    
                    # Clean and shape data related to amenity
                    elif key.startswith("amenity"):
                        amenity_key, amenity_val = TF.transform_amenity_k_v(key, value)
                        if (key == "amenity:disused"):
                            doc["disused"][amenity_key] = amenity_val
                        else:
                            doc[amenity_key] = amenity_val
                    
                    
                    ########################################################
                    #####  (Add more field-specific transformations!)  #####
                    ########################################################
                    
                    
                    # Shape other data into default model
                    elif lower.search(key):
                        if key in k_multilevel_one:
                            doc[key]["basic_info"] = value
                        else:
                            doc[key] = value                    
                    elif lower_colon.search(key):
                        key_upper = key.split(":")[0]
                        key_lower = key.split(":")[1]
                        if key in k_multilevel_two:
                            doc[key_upper][key_lower]["basic_info"] = value
                        else:
                            doc[key_upper][key_lower] = value
                    elif lower_colon_colon.search(key):
                        key_upper = key.split(":")[0]
                        key_middle = key.split(":")[1]
                        key_lower = key.split(":")[2]
                        doc[key_upper][key_middle][key_lower] = value
        
        # Process lower-level "nd" attributes
        if (element.find("nd") != None):
            doc["node_refs"] = []
            for nd in element.iter("nd"):
                ref_num = nd.attrib["ref"]
                doc["node_refs"].append(ref_num)
        
        # Process lower-level "member" attributes
        if (element.find("member") != None):
            doc["member"] = []
            for mb in element.iter("member"):
                mb_dict = {}
                mb_dict["ref"] = mb.attrib["ref"]
                mb_dict["type"] = mb.attrib["type"]
                # Some members do not have a value for "role"
                if (mb.attrib["role"] != ""):
                    mb_dict["role"] = mb.attrib["role"]
                doc["member"].append(mb_dict)
        
        return doc
    
    else:
        return None

# %% [markdown]
# ### Testing the shaping process

# %%
# Writing a function that turns an OSM file into a list of Python dictionaries


def make_dict(osm_file):
    
    events = ET.iterparse(osm_file, events=("start",))
    _, root = next(events)  # Grabbing the root element
    
    data = []
    for _, element in events:
        el = shape_element(element)
        if el:
            data.append(el)
            root.clear()  # Freeing up memory by clearing the root element
    
    return data

# %%
data = make_dict(SAMPLE)

# %%
len(data)
# Out:
# 32455

# %%
# Audit dictionary entries (or "documents" in MongoDB)
pprint.pprint(data[30000:30050])
# Out:
# [{'barrier': 'hedge',
#   'created': {'changeset': '13937575',
#               'timestamp': '2012-11-19T20:53:21Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '191626788',
#   'node_refs': ['2018439996', '2022094208', '2022094210', '2022094212'],
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '13937575',
#               'timestamp': '2012-11-19T20:59:01Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '191627468',
#   'node_refs': ['2022102649', '2022099932'],
#   'type': 'way'},
#  {'barrier': 'wire_fence',
#   'created': {'changeset': '13947869',
#               'timestamp': '2012-11-20T17:28:50Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '191749080',
#   'node_refs': ['2023296845',
#                 '2023296859',
#                 '2023296867',
#                 '2023296862',
#                 '2023296866',
#                 '2023296870',
#                 '2017335810'],
#   'type': 'way'},
#  {'created': {'changeset': '15771456',
#               'timestamp': '2013-04-18T09:50:31Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '3'},
#   'id': '191750258',
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '13952089',
#               'timestamp': '2012-11-20T23:12:32Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '191827958',
#   'node_refs': ['2023932758', '2023932751', '2023932752'],
#   'type': 'way'},
#  {'created': {'changeset': '13984612',
#               'timestamp': '2012-11-22T11:47:56Z',
#               'uid': '74570',
#               'user': 'Richard Mann',
#               'version': '1'},
#   'highway': 'trunk',
#   'id': '192071424',
#   'lanes': {'basic_info': '2'},
#   'lit': 'yes',
#   'maxspeed': {'basic_info': '70 mph'},
#   'node_refs': ['2026274368',
#                 '1549114490',
#                 '1549114494',
#                 '1549114506',
#                 '1549114508',
#                 '1549114510',
#                 '1549114512',
#                 '1549114514',
#                 '1549114517',
#                 '1549114519'],
#   'oneway': {'basic_info': 'yes'},
#   'ref': {'basic_info': 'A40'},
#   'type': 'way'},
#  {'created': {'changeset': '20690715',
#               'timestamp': '2014-02-21T10:27:53Z',
#               'uid': '69984',
#               'user': 'richardwest',
#               'version': '5'},
#   'id': '192155816',
#   'landuse': {'basic_info': 'meadow'},
#   'node_refs': ['1052479060',
#                 '2683252834',
#                 '1052480727',
#                 '1052482017',
#                 '1052481496',
#                 '1052482625',
#                 '1052479395',
#                 '1052481072',
#                 '2683252739',
#                 '1052480334',
#                 '2683252649',
#                 '1052481783',
#                 '2683252628',
#                 '1052482923',
#                 '1052479872',
#                 '2683252637',
#                 '2683252647',
#                 '1052479141',
#                 '1052480793',
#                 '1052482099',
#                 '2683252754',
#                 '2683252717',
#                 '1052478848',
#                 '2683252662',
#                 '1052481947',
#                 '2683252608',
#                 '1052478733',
#                 '1052480177',
#                 '2027156290',
#                 '2027156302',
#                 '2027156286',
#                 '2027159419',
#                 '2027159417',
#                 '2027159411',
#                 '2027159407',
#                 '2027159409',
#                 '2027159413',
#                 '2027159415',
#                 '2027156322',
#                 '2027156316',
#                 '2027156324',
#                 '1052479060'],
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '14013769',
#               'timestamp': '2012-11-24T15:08:36Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '192460612',
#   'node_refs': ['2030142439', '2030142441'],
#   'type': 'way'},
#  {'created': {'changeset': '15771456',
#               'timestamp': '2013-04-18T09:53:15Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '4'},
#   'id': '192462340',
#   'landuse': {'basic_info': 'farmland'},
#   'node_refs': ['2022102651',
#                 '2030155170',
#                 '2030155166',
#                 '2030156583',
#                 '2030155167',
#                 '2030155160',
#                 '2030155146',
#                 '2030155147',
#                 '2030155142',
#                 '2022099987',
#                 '2022100001',
#                 '2022099932',
#                 '2022102649',
#                 '2022102653',
#                 '2022099962',
#                 '2022102652',
#                 '2022102648',
#                 '2022102651'],
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '14014147',
#               'timestamp': '2012-11-24T15:33:45Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '192464296',
#   'node_refs': ['2030173581', '2030175394'],
#   'type': 'way'},
#  {'barrier': 'wire_fence',
#   'created': {'changeset': '14016716',
#               'timestamp': '2012-11-24T18:15:06Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '192497117',
#   'node_refs': ['2030491728', '2030491729', '2030491727', '2030489232'],
#   'type': 'way'},
#  {'created': {'changeset': '14020812',
#               'timestamp': '2012-11-24T22:38:15Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '192548215',
#   'natural': 'wood',
#   'node_refs': ['2017331635',
#                 '412358751',
#                 '412358750',
#                 '2030994878',
#                 '2030994881',
#                 '2030994882',
#                 '412358742',
#                 '2030994880',
#                 '2030994879',
#                 '2017331640',
#                 '2017331635'],
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '26310101',
#               'timestamp': '2014-10-24T21:44:47Z',
#               'uid': '34555',
#               'user': 'Max--',
#               'version': '3'},
#   'id': '192607216',
#   'node_refs': ['2031554351',
#                 '2031554335',
#                 '2031554349',
#                 '2031554322',
#                 '2031554331',
#                 '2031571392',
#                 '2031554325',
#                 '2031554338'],
#   'type': 'way'},
#  {'created': {'changeset': '15746962',
#               'timestamp': '2013-04-16T09:12:12Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '3'},
#   'id': '192607831',
#   'landuse': {'basic_info': 'farmland'},
#   'node_refs': ['697109929',
#                 '2027156296',
#                 '2031561410',
#                 '2031561412',
#                 '2031561409',
#                 '2031561411',
#                 '158700241',
#                 '158700240',
#                 '697109929'],
#   'type': 'way'},
#  {'created': {'changeset': '34063288',
#               'timestamp': '2015-09-16T13:53:30Z',
#               'uid': '74570',
#               'user': 'Richard Mann',
#               'version': '3'},
#   'highway': 'residential',
#   'id': '192636560',
#   'maxspeed': {'basic_info': '30 mph'},
#   'name': {'basic_info': 'Seven Sisters Way'},
#   'node_refs': ['2031829054', '2031829055', '1952748410'],
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '14038683',
#               'timestamp': '2012-11-25T23:14:44Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '192796127',
#   'node_refs': ['2033296572', '2033296570'],
#   'type': 'way'},
#  {'created': {'changeset': '14047187',
#               'timestamp': '2012-11-26T16:49:56Z',
#               'uid': '30587',
#               'user': 'IknowJoseph',
#               'version': '1'},
#   'highway': 'service',
#   'id': '192962530',
#   'node_refs': ['2034951344', '2034951349'],
#   'oneway': {'basic_info': 'yes'},
#   'service': 'parking_aisle',
#   'source': {'basic_info': 'Bing'},
#   'type': 'way'},
#  {'address': {'housenumber': ['15'], 'street': "St Giles'"},
#   'building': {'basic_info': 'yes'},
#   'created': {'changeset': '14121062',
#               'timestamp': '2012-12-02T08:33:47Z',
#               'uid': '55782',
#               'user': '0123456789',
#               'version': '1'},
#   'id': '194064130',
#   'node_refs': ['2045774762',
#                 '1993430826',
#                 '1993430827',
#                 '1993430837',
#                 '1993430832',
#                 '1993430822',
#                 '1993430823',
#                 '2045774762'],
#   'source': {'basic_info': 'Bing'},
#   'type': 'way'},
#  {'access': {'basic_info': 'private'},
#   'amenity': 'parking',
#   'created': {'changeset': '16823996',
#               'timestamp': '2013-07-04T14:51:43Z',
#               'uid': '1555208',
#               'user': 'VJA1602',
#               'version': '2'},
#   'id': '194066167',
#   'node_refs': ['2045785971',
#                 '1057697482',
#                 '2045785959',
#                 '2045785967',
#                 '316048028',
#                 '1052886928',
#                 '1993426609',
#                 '1993426611',
#                 '2045785932',
#                 '2045785968',
#                 '1954346284',
#                 '316048235',
#                 '2045785971'],
#   'type': 'way'},
#  {'address': {'housename': 'Edith Road Workshops'},
#   'building': {'basic_info': 'yes'},
#   'created': {'changeset': '18503574',
#               'timestamp': '2013-10-23T14:04:03Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '2'},
#   'id': '194067710',
#   'name': {'basic_info': 'Edith Road Workshops'},
#   'node_refs': ['2045801934',
#                 '2045801933',
#                 '2045801936',
#                 '2045801932',
#                 '2045801931',
#                 '2045801935',
#                 '2045801934'],
#   'type': 'way'},
#  {'created': {'changeset': '24215777',
#               'timestamp': '2014-07-18T08:24:06Z',
#               'uid': '84263',
#               'user': 'Robert Whittaker',
#               'version': '2'},
#   'foot': 'designated',
#   'highway': 'service',
#   'id': '194087989',
#   'node_refs': ['1505749926',
#                 '2045985161',
#                 '2045985159',
#                 '2045985157',
#                 '2045985155',
#                 '2045985154'],
#   'prow': {'ref': '265/14'},
#   'source': {'geometry': 'Bing', 'ref': 'definitive_statement'},
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '14154208',
#               'timestamp': '2012-12-04T17:15:36Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '3'},
#   'id': '194449308',
#   'node_refs': ['2049540267',
#                 '2050008655',
#                 '2049540259',
#                 '2049540250',
#                 '2049540254',
#                 '2050008619',
#                 '2049542341',
#                 '2049540252'],
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '14154208',
#               'timestamp': '2012-12-04T17:17:37Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '194492353',
#   'node_refs': ['2050014413', '2050008599'],
#   'type': 'way'},
#  {'created': {'changeset': '25999447',
#               'timestamp': '2014-10-11T09:17:54Z',
#               'uid': '34555',
#               'user': 'Max--',
#               'version': '2'},
#   'id': '194542684',
#   'natural': 'wood',
#   'node_refs': ['1249902686',
#                 '1249902803',
#                 '335696423',
#                 '335696424',
#                 '335696425',
#                 '335696426',
#                 '2050440602',
#                 '2050440597',
#                 '2050440583',
#                 '2050440601',
#                 '2050440591',
#                 '2050440590',
#                 '2050440608',
#                 '2050440592',
#                 '2050440607',
#                 '2050440594',
#                 '2050440604',
#                 '2050440584',
#                 '2050440605',
#                 '2050440587',
#                 '2050440586',
#                 '2050440598',
#                 '3123630165',
#                 '2050440585',
#                 '2050440609',
#                 '2050440603',
#                 '2050440589',
#                 '2050440599',
#                 '2050440596',
#                 '2050440600',
#                 '2050440593',
#                 '2050440595',
#                 '2050440588',
#                 '2050440606',
#                 '1249902686'],
#   'type': 'way'},
#  {'created': {'changeset': '14231275',
#               'timestamp': '2012-12-10T21:03:34Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '6'},
#   'id': '194555966',
#   'natural': 'wood',
#   'node_refs': ['2050570288',
#                 '2052623410',
#                 '2052623421',
#                 '2052623418',
#                 '2050570296',
#                 '2052623395',
#                 '2050570239',
#                 '2050570274',
#                 '2050570230',
#                 '2050570256',
#                 '2050570268',
#                 '2050570241',
#                 '2052624526',
#                 '2052624528',
#                 '2052624539',
#                 '2052624541',
#                 '2052624530',
#                 '2052624543',
#                 '2052624535',
#                 '2052624537',
#                 '472983093',
#                 '2050570228',
#                 '2050570246',
#                 '2050570270',
#                 '2050570295',
#                 '2060667563',
#                 '2050570278',
#                 '2050570272',
#                 '2050570284',
#                 '2050570286',
#                 '2050570276',
#                 '2050570297',
#                 '2050570260',
#                 '2050570252',
#                 '2050570254',
#                 '2050570258',
#                 '2050570248',
#                 '2050570237',
#                 '2050570233',
#                 '2052098894',
#                 '2050570235',
#                 '2050570264',
#                 '2052095958',
#                 '2050570288'],
#   'type': 'way'},
#  {'building': {'basic_info': 'commercial'},
#   'created': {'changeset': '14170194',
#               'timestamp': '2012-12-06T01:09:44Z',
#               'uid': '10136',
#               'user': 'Duncan Parkes',
#               'version': '2'},
#   'id': '194620842',
#   'node_refs': ['2051241413',
#                 '2051241410',
#                 '2051241411',
#                 '2052205350',
#                 '2051241407',
#                 '2051241413'],
#   'type': 'way'},
#  {'created': {'changeset': '17655985',
#               'timestamp': '2013-09-03T15:26:00Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '4'},
#   'id': '194706699',
#   'landuse': {'basic_info': 'meadow'},
#   'node_refs': ['286298652',
#                 '697104481',
#                 '697104482',
#                 '697104483',
#                 '697104484',
#                 '697104485',
#                 '697104486',
#                 '2052095408',
#                 '2052101206',
#                 '2052095836',
#                 '2052095820',
#                 '2052095824',
#                 '2052095837',
#                 '2052095822',
#                 '2052095831',
#                 '2052095830',
#                 '2052095833',
#                 '2052095829',
#                 '2052095827',
#                 '2052095819',
#                 '2052095826',
#                 '2052101204',
#                 '2052095959',
#                 '2052095961',
#                 '2052095960',
#                 '2050570264',
#                 '2050570235',
#                 '2052098894',
#                 '2052098903',
#                 '2052098899',
#                 '2052098900',
#                 '2052098898',
#                 '2052098902',
#                 '286298652'],
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '14174033',
#               'timestamp': '2012-12-06T11:29:15Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '194753926',
#   'node_refs': ['2052620651',
#                 '2052620654',
#                 '2052620653',
#                 '2052620650',
#                 '2052620662',
#                 '2052620657',
#                 '2052620649',
#                 '2052620652',
#                 '2052620658'],
#   'type': 'way'},
#  {'access': {'basic_info': 'private'},
#   'created': {'changeset': '14174362',
#               'timestamp': '2012-12-06T12:01:06Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '2'},
#   'highway': 'track',
#   'id': '194755113',
#   'node_refs': ['2052628758',
#                 '2052628756',
#                 '2052628754',
#                 '2052628759',
#                 '2052628760',
#                 '2052628753',
#                 '2052628752',
#                 '2052628757',
#                 '2052628751',
#                 '2052628755',
#                 '697150390'],
#   'type': 'way'},
#  {'created': {'changeset': '15770630',
#               'timestamp': '2013-04-18T08:24:33Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '3'},
#   'id': '194757863',
#   'landuse': {'basic_info': 'farmland'},
#   'node_refs': ['213413091',
#                 '213413092',
#                 '2052659158',
#                 '2052659155',
#                 '2052659124',
#                 '2052659131',
#                 '2052659141',
#                 '2052659143',
#                 '2052659127',
#                 '2052659146',
#                 '2052659144',
#                 '2052659132',
#                 '2052659152',
#                 '2052659142',
#                 '2052659137',
#                 '2052659153',
#                 '2052655537',
#                 '2052659126',
#                 '213413078',
#                 '213413079',
#                 '213413080',
#                 '213413084',
#                 '213413085',
#                 '213413086',
#                 '213413088',
#                 '213413090',
#                 '213413091'],
#   'type': 'way'},
#  {'created': {'changeset': '14189575',
#               'timestamp': '2012-12-07T16:13:10Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '194947354',
#   'natural': 'water',
#   'node_refs': ['2054620080',
#                 '2054620078',
#                 '2054620076',
#                 '2054620084',
#                 '2054620082',
#                 '2054620083',
#                 '2054620081',
#                 '2054620080'],
#   'type': 'way'},
#  {'created': {'changeset': '28630686',
#               'timestamp': '2015-02-05T13:42:30Z',
#               'uid': '890751',
#               'user': 'extua',
#               'version': '5'},
#   'id': '194998320',
#   'landuse': {'basic_info': 'farmland'},
#   'node_refs': ['2050576634',
#                 '2055030526',
#                 '2055030523',
#                 '2055030529',
#                 '2055036640',
#                 '2055036638',
#                 '2050576638',
#                 '2050576624',
#                 '2050576631',
#                 '3148176564',
#                 '2050576622',
#                 '2055036639',
#                 '2050576626',
#                 '2050576628',
#                 '3148176576',
#                 '2050576632',
#                 '2050576623',
#                 '2050576634'],
#   'type': 'way'},
#  {'created': {'changeset': '14193493',
#               'timestamp': '2012-12-07T21:41:36Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '195015254',
#   'landuse': {'basic_info': 'farmland'},
#   'node_refs': ['432571243',
#                 '2055183284',
#                 '2055183277',
#                 '2055183286',
#                 '432571240',
#                 '432571242',
#                 '432571243'],
#   'type': 'way'},
#  {'created': {'changeset': '17655985',
#               'timestamp': '2013-09-03T15:27:54Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '6'},
#   'id': '195016392',
#   'landuse': {'basic_info': 'meadow'},
#   'node_refs': ['2055193322',
#                 '2055193358',
#                 '2055193338',
#                 '2055193320',
#                 '2055193349',
#                 '2055196761',
#                 '2055193360',
#                 '2055193318',
#                 '2055193314',
#                 '2055189315',
#                 '2055189316',
#                 '2055189317',
#                 '2055189318',
#                 '2055189321',
#                 '2055189324',
#                 '2055193312',
#                 '2055193342',
#                 '2055046683',
#                 '2055046710',
#                 '2055046714',
#                 '2055046721',
#                 '2055193347',
#                 '2055193324',
#                 '2055193326',
#                 '2055188464',
#                 '2055193310',
#                 '2055193308',
#                 '2055193334',
#                 '2055193332',
#                 '2055193357',
#                 '2055193336',
#                 '2055196636',
#                 '2055193351',
#                 '2055193345',
#                 '2055193322'],
#   'type': 'way'},
#  {'created': {'changeset': '14194272',
#               'timestamp': '2012-12-07T23:04:28Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '195030383',
#   'node_refs': ['2055291938',
#                 '2055291925',
#                 '2055291924',
#                 '2055291921',
#                 '2055291936',
#                 '2055291929',
#                 '1189723146',
#                 '1189723170',
#                 '460048919'],
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '14461352',
#               'timestamp': '2012-12-30T10:00:49Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '2'},
#   'id': '195411044',
#   'node_refs': ['2058561498',
#                 '1983449536',
#                 '1983449522',
#                 '1983449562',
#                 '1983449527',
#                 '1983449526',
#                 '2088198944',
#                 '1983449528',
#                 '1983449533',
#                 '1983449524'],
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '16025865',
#               'timestamp': '2013-05-08T09:59:34Z',
#               'uid': '24334',
#               'user': 'jochta',
#               'version': '3'},
#   'id': '195412823',
#   'node_refs': ['2058586315',
#                 '1976661605',
#                 '2295652613',
#                 '2295652622',
#                 '2058599028',
#                 '1141972956'],
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '14231275',
#               'timestamp': '2012-12-10T21:03:33Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '195638683',
#   'node_refs': ['2050573789',
#                 '2060667568',
#                 '2060667550',
#                 '2060667554',
#                 '2050573999'],
#   'type': 'way'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '14231275',
#               'timestamp': '2012-12-10T21:11:09Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '195642794',
#   'node_refs': ['2050572314',
#                 '2050572316',
#                 '2050572318',
#                 '2050572312',
#                 '2050572315'],
#   'type': 'way'},
#  {'created': {'changeset': '26310101',
#               'timestamp': '2014-10-24T21:44:49Z',
#               'uid': '34555',
#               'user': 'Max--',
#               'version': '4'},
#   'id': '195646548',
#   'landuse': {'basic_info': 'farmland'},
#   'node_refs': ['2031554362',
#                 '2031554360',
#                 '2031554327',
#                 '2031554357',
#                 '2031554329',
#                 '2031554346',
#                 '2060713172',
#                 '2031558118',
#                 '2031554353',
#                 '2031565865',
#                 '2031554363',
#                 '2031554333',
#                 '2031554355',
#                 '2031554341',
#                 '2031554336',
#                 '2031554344',
#                 '2031554362'],
#   'type': 'way'},
#  {'address': {'city': 'Oxford',
#               'housenumber': ['1'],
#               'postcode': 'OX4 3ER',
#               'street': 'Lawrence Road'},
#   'building': {'basic_info': 'house'},
#   'created': {'changeset': '16690910',
#               'timestamp': '2013-06-24T21:02:28Z',
#               'uid': '57884',
#               'user': 'EdLoach',
#               'version': '2'},
#   'id': '196109122',
#   'node_refs': ['2064765000',
#                 '2064765007',
#                 '2064764984',
#                 '2064764982',
#                 '2064764998',
#                 '2064764975',
#                 '2064765000'],
#   'source': {'basic_info': 'Bing'},
#   'type': 'way'},
#  {'address': {'housenumber': ['4'], 'street': 'James Street'},
#   'building': {'basic_info': 'house'},
#   'created': {'changeset': '14272259',
#               'timestamp': '2012-12-14T14:57:19Z',
#               'uid': '30587',
#               'user': 'IknowJoseph',
#               'version': '1'},
#   'id': '196311555',
#   'node_refs': ['2066547111',
#                 '2066457449',
#                 '2066457447',
#                 '2066547117',
#                 '2066547114',
#                 '2066547110',
#                 '2066547111'],
#   'source': {'basic_info': 'Bing'},
#   'type': 'way'},
#  {'address': {'city': 'Oxford',
#               'housenumber': ['41a'],
#               'postcode': 'OX4 1RB',
#               'street': 'Magdalen Road'},
#   'amenity': 'place_of_worship',
#   'building': {'basic_info': 'yes'},
#   'created': {'changeset': '37430573',
#               'timestamp': '2016-02-25T09:11:47Z',
#               'uid': '3624613',
#               'user': 'Peter Leaver',
#               'version': '2'},
#   'denomination': 'evangelical',
#   'id': '196608738',
#   'name': {'basic_info': 'Magdalen Road Church'},
#   'node_refs': ['2069237289',
#                 '251606361',
#                 '2069237285',
#                 '2069237288',
#                 '2069237289'],
#   'phone': '01865 245887',
#   'religion': 'christian',
#   'type': 'way',
#   'website': 'http://mrc-oxford.org'},
#  {'barrier': 'hedge',
#   'created': {'changeset': '14294815',
#               'timestamp': '2012-12-16T15:45:18Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '1'},
#   'id': '196694615',
#   'node_refs': ['2069918738', '2069918735', '374839297'],
#   'type': 'way'},
#  {'created': {'changeset': '14299476',
#               'timestamp': '2012-12-16T21:33:41Z',
#               'uid': '782788',
#               'user': 'GordonFS',
#               'version': '3'},
#   'id': '196774002',
#   'landuse': {'basic_info': 'farmland'},
#   'node_refs': ['2055184343',
#                 '2070646128',
#                 '2070646121',
#                 '2070646178',
#                 '2070646155',
#                 '2070646147',
#                 '2070646188',
#                 '2070646182',
#                 '2070646186',
#                 '2070646138',
#                 '2070646131',
#                 '2070646125',
#                 '2070646110',
#                 '2070646152',
#                 '2070646114',
#                 '2070646159',
#                 '2070646118',
#                 '2070646164',
#                 '2070646140',
#                 '2070646180',
#                 '2070646175',
#                 '2070646184',
#                 '2070649182',
#                 '2070646168',
#                 '2070646142',
#                 '2070651187',
#                 '2070646134',
#                 '2070646161',
#                 '2070646144',
#                 '2070646150',
#                 '2070646171',
#                 '2055184340',
#                 '2055184344',
#                 '2055184341',
#                 '2055184342',
#                 '2055184343'],
#   'type': 'way'},
#  {'created': {'changeset': '14307171',
#               'timestamp': '2012-12-17T15:04:45Z',
#               'uid': '74570',
#               'user': 'Richard Mann',
#               'version': '1'},
#   'highway': 'footway',
#   'id': '196864821',
#   'node_refs': ['2071564655',
#                 '2071564650',
#                 '2071564653',
#                 '2071564660',
#                 '2071564652'],
#   'type': 'way'},
#  {'created': {'changeset': '14319974',
#               'timestamp': '2012-12-18T15:45:51Z',
#               'uid': '114436',
#               'user': 'Alexander Dutton',
#               'version': '1'},
#   'highway': 'footway',
#   'id': '197021483',
#   'node_refs': ['1672856666', '1672856670'],
#   'type': 'way'},
#  {'created': {'changeset': '14319974',
#               'timestamp': '2012-12-18T15:45:52Z',
#               'uid': '114436',
#               'user': 'Alexander Dutton',
#               'version': '1'},
#   'highway': 'steps',
#   'id': '197021495',
#   'node_refs': ['2073080885', '1672856666'],
#   'step_count': '2',
#   'type': 'way'},
#  {'address': {'housenumber': ['9'],
#               'postcode': 'OX3 8AN',
#               'street': 'Wharton Road'},
#   'building': {'basic_info': 'residential'},
#   'created': {'changeset': '14539817',
#               'timestamp': '2013-01-05T17:53:45Z',
#               'uid': '2997',
#               'user': 'magnayn',
#               'version': '2'},
#   'id': '197053113',
#   'node_refs': ['2073428512',
#                 '2073428572',
#                 '2073428550',
#                 '2073428540',
#                 '2073428512'],
#   'type': 'way'},
#  {'address': {'housenumber': ['12'],
#               'postcode': 'OX3 8AN',
#               'street': 'Burrows Close'},
#   'building': {'basic_info': 'residential'},
#   'created': {'changeset': '14322545',
#               'timestamp': '2012-12-18T19:25:45Z',
#               'uid': '2997',
#               'user': 'magnayn',
#               'version': '1'},
#   'id': '197053137',
#   'node_refs': ['2073428664',
#                 '2073428570',
#                 '2073428666',
#                 '2073428594',
#                 '2073428664'],
#   'type': 'way'}]

# %% [markdown]
# ### Saving into a JSON file

# %%
import codecs
import json


def process_map(file_in, pretty=False):
    file_out = "{0}.json".format(file_in)
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")

# %%
# Transform and save into JSON
process_map(SAMPLE)
